# %%
# Human Interpreted coordination numbers can be analyzed along with other methods
# %matplotlib inline
from materialscoord.cn_methods import TestECoN, TestVoronoiCoordFinder, HumanInterpreter, TestVoronoiCoordFinder_mod
from materialscoord.core import Benchmark

methods = [HumanInterpreter(), TestECoN(), TestVoronoiCoordFinder(), TestVoronoiCoordFinder_mod()]
bm = Benchmark(methods, structure_groups=["common_binaries"], nround=2)
bm.benchmark()
# Out:
# Initialization successful.

# %%
import pandas as pd
pd.set_option('max_colwidth',200)
bm.report(totals=True)
# Out:
#                                 HumanInterpreter  \
# Al2O3_corundum             [(Al, 6.0), (O, 3.0)]
# CaF2_fluorite              [(Ca, 8.0), (F, 4.0)]
# CsCl                      [(Cs, 8.0), (Cl, 8.0)]
# Fe3O4_spinel    [(Fe, 6.0), (Fe, 4.0), (O, 4.0)]
# MgAl2O4_spinel  [(Mg, 4.0), (Al, 6.0), (O, 4.0)]
# NaCl_rocksalt             [(Na, 4.0), (Cl, 6.0)]
# TiO2_anatase               [(Ti, 6.0), (O, 3.0)]
# ZnS_wurtzite               [(Zn, 4.0), (S, 4.0)]
# ZnS_zincblende             [(Zn, 4.0), (S, 4.0)]
#
#                                           TestECoN  \
# Al2O3_corundum             [(Al, 5.79), (O, 3.92)]
# CaF2_fluorite               [(Ca, 8.0), (F, 7.57)]
# CsCl                    [(Cs, 11.28), (Cl, 11.28)]
# Fe3O4_spinel    [(Fe, 6.01), (Fe, 4.0), (O, 3.67)]
# MgAl2O4_spinel    [(Mg, 4.0), (Al, 6.0), (O, 4.1)]
# NaCl_rocksalt             [(Na, 6.04), (Cl, 6.04)]
# TiO2_anatase               [(Ti, 5.96), (O, 3.23)]
# ZnS_wurtzite                 [(Zn, 4.0), (S, 4.0)]
# ZnS_zincblende               [(Zn, 4.0), (S, 4.0)]
#
#                             TestVoronoiCoordFinder  \
# Al2O3_corundum             [(Al, 5.29), (O, 5.29)]
# CaF2_fluorite                [(Ca, 8.0), (F, 8.0)]
# CsCl                    [(Cs, 10.16), (Cl, 10.16)]
# Fe3O4_spinel    [(Fe, 6.0), (Fe, 4.36), (O, 4.36)]
# MgAl2O4_spinel  [(Mg, 4.56), (Al, 6.0), (O, 4.56)]
# NaCl_rocksalt               [(Na, 6.0), (Cl, 6.0)]
# TiO2_anatase               [(Ti, 5.82), (O, 5.82)]
# ZnS_wurtzite               [(Zn, 4.28), (S, 4.28)]
# ZnS_zincblende             [(Zn, 4.54), (S, 4.54)]
#
#                       TestVoronoiCoordFinder_mod
# Al2O3_corundum             [(Al, 6.0), (O, 4.0)]
# CaF2_fluorite             [(Ca, 8.0), (F, 10.0)]
# CsCl                      [(Cs, 8.0), (Cl, 8.0)]
# Fe3O4_spinel    [(Fe, 6.0), (Fe, 4.0), (O, 4.0)]
# MgAl2O4_spinel  [(Mg, 4.0), (Al, 6.0), (O, 4.0)]
# NaCl_rocksalt             [(Na, 6.0), (Cl, 6.0)]
# TiO2_anatase               [(Ti, 6.0), (O, 3.0)]
# ZnS_wurtzite               [(Zn, 4.0), (S, 4.0)]
# ZnS_zincblende             [(Zn, 4.0), (S, 4.0)]

# %%
# Here is an example for plotting deviation of CNs for unique sites in our test structures 
# from the Human Interpreter.

p = bm.report(totals=True, separate_columns=True, max_sites=3)
ax = None
sub_p = None

for i in range(3):
    a = p[ ["TestECoN"+str(i), "TestVoronoiCoordFinder"+str(i), "TestVoronoiCoordFinder_mod"+str(i)] ]
    b = p["HumanInterpreter"+str(i)]
    c = a.sub(b, axis='rows')

    if not isinstance(sub_p, pd.DataFrame):
        sub_p = c
    else:
        sub_p = pd.concat([sub_p, c], axis=1)
    
    if ax:
        c.T.plot(legend=False, ax=ax)
    else:
        ax=c.T.plot(legend=False)
ax.set_xlabel("CN method")
ax.set_ylabel("Deviation from Human Interpreter")

# %%
sub_p
# Out:
#                 TestECoN0  TestVoronoiCoordFinder0  \
# Al2O3_corundum      -0.21                    -0.71
# CaF2_fluorite        0.00                     0.00
# CsCl                 3.28                     2.16
# Fe3O4_spinel         0.01                     0.00
# MgAl2O4_spinel       0.00                     0.56
# NaCl_rocksalt        2.04                     2.00
# TiO2_anatase        -0.04                    -0.18
# ZnS_wurtzite         0.00                     0.28
# ZnS_zincblende       0.00                     0.54
#
#                 TestVoronoiCoordFinder_mod0  TestECoN1  \
# Al2O3_corundum                          0.0       0.92
# CaF2_fluorite                           0.0       3.57
# CsCl                                    0.0       3.28
# Fe3O4_spinel                            0.0       0.00
# MgAl2O4_spinel                          0.0       0.00
# NaCl_rocksalt                           2.0       0.04
# TiO2_anatase                            0.0       0.23
# ZnS_wurtzite                            0.0       0.00
# ZnS_zincblende                          0.0       0.00
#
#                 TestVoronoiCoordFinder1  TestVoronoiCoordFinder_mod1  \
# Al2O3_corundum                     2.29                          1.0
# CaF2_fluorite                      4.00                          6.0
# CsCl                               2.16                          0.0
# Fe3O4_spinel                       0.36                          0.0
# MgAl2O4_spinel                     0.00                          0.0
# NaCl_rocksalt                      0.00                          0.0
# TiO2_anatase                       2.82                          0.0
# ZnS_wurtzite                       0.28                          0.0
# ZnS_zincblende                     0.54                          0.0
#
#                 TestECoN2  TestVoronoiCoordFinder2  \
# Al2O3_corundum       0.00                     0.00
# CaF2_fluorite        0.00                     0.00
# CsCl                 0.00                     0.00
# Fe3O4_spinel        -0.33                     0.36
# MgAl2O4_spinel       0.10                     0.56
# NaCl_rocksalt        0.00                     0.00
# TiO2_anatase         0.00                     0.00
# ZnS_wurtzite         0.00                     0.00
# ZnS_zincblende       0.00                     0.00
#
#                 TestVoronoiCoordFinder_mod2
# Al2O3_corundum                          0.0
# CaF2_fluorite                           0.0
# CsCl                                    0.0
# Fe3O4_spinel                            0.0
# MgAl2O4_spinel                          0.0
# NaCl_rocksalt                           0.0
# TiO2_anatase                            0.0
# ZnS_wurtzite                            0.0
# ZnS_zincblende                          0.0
