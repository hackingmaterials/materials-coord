# %%
import pandas as pd
pd.set_option("display.max_columns",999) # display all columns
pd.set_option("display.max_rows", 999)

from pymatgen.analysis.local_env import BrunnerNN_reciprocal, BrunnerNN_relative, BrunnerNN_real, EconNN, JMolNN, \
                                        MinimumDistanceNN, MinimumOKeeffeNN, MinimumVIRENN, \
                                        VoronoiNN, VoronoiNN_modified, CrystalNN
from materialscoord.core import Benchmark, HumanInterpreter, NbFuncs

methods = [BrunnerNN_reciprocal(), EconNN(), JMolNN(), MinimumDistanceNN(), MinimumOKeeffeNN(), 
           HumanInterpreter()]
structure_groups = ["clusters"]
bm = Benchmark(methods=methods, structure_groups=structure_groups, unique_sites=True,
               use_weights=False, cation_anion=True, anion_cation=False)
bm.benchmark()
# Out:
# /Users/hillarypan/AJResearch/cn_routines/codes/pymatgen/pymatgen/__init__.py:89: UserWarning:
# Pymatgen will drop Py2k support from v2019.1.1. Pls consult the documentation
# at https://www.pymatgen.org for more details.
#   at https://www.pymatgen.org for more details.""")
# Initialization successful.

# %%
report = bm.report()
report
# Out:
#                        BrunnerNN_reciprocal0    BrunnerNN_reciprocal1  \
# cluster_Al10H54O38               {u'O': 6.0}              {u'O': 6.0}
# cluster_Al11H54O38               {u'O': 6.0}              {u'O': 6.0}
# cluster_Al12H54O38               {u'O': 6.0}              {u'O': 6.0}
# cluster_Al13H48O40               {u'O': 4.0}              {u'O': 6.0}
# cluster_Al13H51O41               {u'O': 4.0}              {u'O': 6.0}
# cluster_Al13H66O48               {u'O': 6.0}              {u'O': 6.0}
# cluster_Al13H72O48               {u'O': 6.0}              {u'O': 6.0}
# cluster_Al14H66O48               {u'O': 6.0}              {u'O': 6.0}
# cluster_Al15H66O48               {u'O': 6.0}              {u'O': 4.0}
# cluster_Al16H78O58               {u'O': 6.0}              {u'O': 6.0}
# cluster_Al1H10O5                 {u'O': 5.0}                       {}
# cluster_Al1H12O6                 {u'O': 6.0}                       {}
# cluster_Al20H96O72               {u'O': 6.0}              {u'O': 6.0}
# cluster_Al26H132O92              {u'O': 6.0}              {u'O': 6.0}
# cluster_Al26H90O78               {u'O': 6.0}              {u'O': 6.0}
# cluster_Al2H18O10                {u'O': 6.0}                       {}
# cluster_Al3H24O14                {u'O': 6.0}              {u'O': 6.0}
# cluster_Al3H27O15    {u'H': 10.0, u'O': 6.0}  {u'H': 10.0, u'O': 6.0}
# cluster_Al4H26O16                {u'O': 6.0}              {u'O': 6.0}
# cluster_Al4H30O18     {u'H': 9.0, u'O': 6.0}   {u'H': 9.0, u'O': 6.0}
# cluster_Al4H30O19                {u'O': 7.0}              {u'O': 7.0}
# cluster_Al5H36O22                {u'O': 6.0}              {u'O': 6.0}
# cluster_Al6H24O18                {u'O': 5.0}              {u'O': 5.0}
# cluster_Al6H32O22                {u'O': 5.0}              {u'O': 6.0}
# cluster_Al6H36O24                {u'O': 6.0}              {u'O': 6.0}
# cluster_Al7H36O24                {u'O': 6.0}              {u'O': 6.0}
# cluster_Al8H42O28                {u'O': 6.0}              {u'O': 6.0}
# cluster_Al8H50O32                {u'O': 6.0}              {u'O': 6.0}
#
#                     BrunnerNN_reciprocal10 BrunnerNN_reciprocal11  \
# cluster_Al10H54O38                      {}                     {}
# cluster_Al11H54O38             {u'O': 6.0}                     {}
# cluster_Al12H54O38             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al13H48O40             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al13H51O41             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al13H66O48             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al13H72O48             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al14H66O48             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al15H66O48             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al16H78O58             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al1H10O5                        {}                     {}
# cluster_Al1H12O6                        {}                     {}
# cluster_Al20H96O72             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al26H132O92            {u'O': 6.0}            {u'O': 6.0}
# cluster_Al26H90O78             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al2H18O10                       {}                     {}
# cluster_Al3H24O14                       {}                     {}
# cluster_Al3H27O15                       {}                     {}
# cluster_Al4H26O16                       {}                     {}
# cluster_Al4H30O18                       {}                     {}
# cluster_Al4H30O19                       {}                     {}
# cluster_Al5H36O22                       {}                     {}
# cluster_Al6H24O18                       {}                     {}
# cluster_Al6H32O22                       {}                     {}
# cluster_Al6H36O24                       {}                     {}
# cluster_Al7H36O24                       {}                     {}
# cluster_Al8H42O28                       {}                     {}
# cluster_Al8H50O32                       {}                     {}
#
#                     BrunnerNN_reciprocal12 BrunnerNN_reciprocal13  \
# cluster_Al10H54O38                      {}                     {}
# cluster_Al11H54O38                      {}                     {}
# cluster_Al12H54O38                      {}                     {}
# cluster_Al13H48O40             {u'O': 6.0}                     {}
# cluster_Al13H51O41             {u'O': 6.0}                     {}
# cluster_Al13H66O48             {u'O': 6.0}                     {}
# cluster_Al13H72O48             {u'O': 6.0}                     {}
# cluster_Al14H66O48             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al15H66O48             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al16H78O58             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al1H10O5                        {}                     {}
# cluster_Al1H12O6                        {}                     {}
# cluster_Al20H96O72             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al26H132O92            {u'O': 6.0}            {u'O': 6.0}
# cluster_Al26H90O78             {u'O': 4.0}            {u'O': 6.0}
# cluster_Al2H18O10                       {}                     {}
# cluster_Al3H24O14                       {}                     {}
# cluster_Al3H27O15                       {}                     {}
# cluster_Al4H26O16                       {}                     {}
# cluster_Al4H30O18                       {}                     {}
# cluster_Al4H30O19                       {}                     {}
# cluster_Al5H36O22                       {}                     {}
# cluster_Al6H24O18                       {}                     {}
# cluster_Al6H32O22                       {}                     {}
# cluster_Al6H36O24                       {}                     {}
# cluster_Al7H36O24                       {}                     {}
# cluster_Al8H42O28                       {}                     {}
# cluster_Al8H50O32                       {}                     {}
#
#                     BrunnerNN_reciprocal14 BrunnerNN_reciprocal15  \
# cluster_Al10H54O38                      {}                     {}
# cluster_Al11H54O38                      {}                     {}
# cluster_Al12H54O38                      {}                     {}
# cluster_Al13H48O40                      {}                     {}
# cluster_Al13H51O41                      {}                     {}
# cluster_Al13H66O48                      {}                     {}
# cluster_Al13H72O48                      {}                     {}
# cluster_Al14H66O48                      {}                     {}
# cluster_Al15H66O48             {u'O': 6.0}                     {}
# cluster_Al16H78O58             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al1H10O5                        {}                     {}
# cluster_Al1H12O6                        {}                     {}
# cluster_Al20H96O72             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al26H132O92            {u'O': 6.0}            {u'O': 6.0}
# cluster_Al26H90O78             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al2H18O10                       {}                     {}
# cluster_Al3H24O14                       {}                     {}
# cluster_Al3H27O15                       {}                     {}
# cluster_Al4H26O16                       {}                     {}
# cluster_Al4H30O18                       {}                     {}
# cluster_Al4H30O19                       {}                     {}
# cluster_Al5H36O22                       {}                     {}
# cluster_Al6H24O18                       {}                     {}
# cluster_Al6H32O22                       {}                     {}
# cluster_Al6H36O24                       {}                     {}
# cluster_Al7H36O24                       {}                     {}
# cluster_Al8H42O28                       {}                     {}
# cluster_Al8H50O32                       {}                     {}
#
#                     BrunnerNN_reciprocal16 BrunnerNN_reciprocal17  \
# cluster_Al10H54O38                      {}                     {}
# cluster_Al11H54O38                      {}                     {}
# cluster_Al12H54O38                      {}                     {}
# cluster_Al13H48O40                      {}                     {}
# cluster_Al13H51O41                      {}                     {}
# cluster_Al13H66O48                      {}                     {}
# cluster_Al13H72O48                      {}                     {}
# cluster_Al14H66O48                      {}                     {}
# cluster_Al15H66O48                      {}                     {}
# cluster_Al16H78O58                      {}                     {}
# cluster_Al1H10O5                        {}                     {}
# cluster_Al1H12O6                        {}                     {}
# cluster_Al20H96O72             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al26H132O92            {u'O': 6.0}            {u'O': 6.0}
# cluster_Al26H90O78             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al2H18O10                       {}                     {}
# cluster_Al3H24O14                       {}                     {}
# cluster_Al3H27O15                       {}                     {}
# cluster_Al4H26O16                       {}                     {}
# cluster_Al4H30O18                       {}                     {}
# cluster_Al4H30O19                       {}                     {}
# cluster_Al5H36O22                       {}                     {}
# cluster_Al6H24O18                       {}                     {}
# cluster_Al6H32O22                       {}                     {}
# cluster_Al6H36O24                       {}                     {}
# cluster_Al7H36O24                       {}                     {}
# cluster_Al8H42O28                       {}                     {}
# cluster_Al8H50O32                       {}                     {}
#
#                     BrunnerNN_reciprocal18 BrunnerNN_reciprocal19  \
# cluster_Al10H54O38                      {}                     {}
# cluster_Al11H54O38                      {}                     {}
# cluster_Al12H54O38                      {}                     {}
# cluster_Al13H48O40                      {}                     {}
# cluster_Al13H51O41                      {}                     {}
# cluster_Al13H66O48                      {}                     {}
# cluster_Al13H72O48                      {}                     {}
# cluster_Al14H66O48                      {}                     {}
# cluster_Al15H66O48                      {}                     {}
# cluster_Al16H78O58                      {}                     {}
# cluster_Al1H10O5                        {}                     {}
# cluster_Al1H12O6                        {}                     {}
# cluster_Al20H96O72             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al26H132O92            {u'O': 6.0}            {u'O': 6.0}
# cluster_Al26H90O78             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al2H18O10                       {}                     {}
# cluster_Al3H24O14                       {}                     {}
# cluster_Al3H27O15                       {}                     {}
# cluster_Al4H26O16                       {}                     {}
# cluster_Al4H30O18                       {}                     {}
# cluster_Al4H30O19                       {}                     {}
# cluster_Al5H36O22                       {}                     {}
# cluster_Al6H24O18                       {}                     {}
# cluster_Al6H32O22                       {}                     {}
# cluster_Al6H36O24                       {}                     {}
# cluster_Al7H36O24                       {}                     {}
# cluster_Al8H42O28                       {}                     {}
# cluster_Al8H50O32                       {}                     {}
#
#                        BrunnerNN_reciprocal2 BrunnerNN_reciprocal20  \
# cluster_Al10H54O38               {u'O': 6.0}                     {}
# cluster_Al11H54O38               {u'O': 6.0}                     {}
# cluster_Al12H54O38               {u'O': 6.0}                     {}
# cluster_Al13H48O40               {u'O': 6.0}                     {}
# cluster_Al13H51O41               {u'O': 6.0}                     {}
# cluster_Al13H66O48               {u'O': 6.0}                     {}
# cluster_Al13H72O48               {u'O': 6.0}                     {}
# cluster_Al14H66O48               {u'O': 6.0}                     {}
# cluster_Al15H66O48               {u'O': 6.0}                     {}
# cluster_Al16H78O58               {u'O': 6.0}                     {}
# cluster_Al1H10O5                          {}                     {}
# cluster_Al1H12O6                          {}                     {}
# cluster_Al20H96O72               {u'O': 6.0}                     {}
# cluster_Al26H132O92              {u'O': 6.0}            {u'O': 6.0}
# cluster_Al26H90O78               {u'O': 6.0}            {u'O': 6.0}
# cluster_Al2H18O10                         {}                     {}
# cluster_Al3H24O14                {u'O': 6.0}                     {}
# cluster_Al3H27O15    {u'H': 10.0, u'O': 6.0}                     {}
# cluster_Al4H26O16                         {}                     {}
# cluster_Al4H30O18     {u'H': 9.0, u'O': 6.0}                     {}
# cluster_Al4H30O19                {u'O': 7.0}                     {}
# cluster_Al5H36O22                {u'O': 6.0}                     {}
# cluster_Al6H24O18                {u'O': 5.0}                     {}
# cluster_Al6H32O22                {u'O': 5.0}                     {}
# cluster_Al6H36O24                {u'O': 6.0}                     {}
# cluster_Al7H36O24                {u'O': 6.0}                     {}
# cluster_Al8H42O28                {u'O': 6.0}                     {}
# cluster_Al8H50O32                {u'O': 6.0}                     {}
#
#                     BrunnerNN_reciprocal21 BrunnerNN_reciprocal22  \
# cluster_Al10H54O38                      {}                     {}
# cluster_Al11H54O38                      {}                     {}
# cluster_Al12H54O38                      {}                     {}
# cluster_Al13H48O40                      {}                     {}
# cluster_Al13H51O41                      {}                     {}
# cluster_Al13H66O48                      {}                     {}
# cluster_Al13H72O48                      {}                     {}
# cluster_Al14H66O48                      {}                     {}
# cluster_Al15H66O48                      {}                     {}
# cluster_Al16H78O58                      {}                     {}
# cluster_Al1H10O5                        {}                     {}
# cluster_Al1H12O6                        {}                     {}
# cluster_Al20H96O72                      {}                     {}
# cluster_Al26H132O92            {u'O': 6.0}            {u'O': 6.0}
# cluster_Al26H90O78             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al2H18O10                       {}                     {}
# cluster_Al3H24O14                       {}                     {}
# cluster_Al3H27O15                       {}                     {}
# cluster_Al4H26O16                       {}                     {}
# cluster_Al4H30O18                       {}                     {}
# cluster_Al4H30O19                       {}                     {}
# cluster_Al5H36O22                       {}                     {}
# cluster_Al6H24O18                       {}                     {}
# cluster_Al6H32O22                       {}                     {}
# cluster_Al6H36O24                       {}                     {}
# cluster_Al7H36O24                       {}                     {}
# cluster_Al8H42O28                       {}                     {}
# cluster_Al8H50O32                       {}                     {}
#
#                     BrunnerNN_reciprocal23 BrunnerNN_reciprocal24  \
# cluster_Al10H54O38                      {}                     {}
# cluster_Al11H54O38                      {}                     {}
# cluster_Al12H54O38                      {}                     {}
# cluster_Al13H48O40                      {}                     {}
# cluster_Al13H51O41                      {}                     {}
# cluster_Al13H66O48                      {}                     {}
# cluster_Al13H72O48                      {}                     {}
# cluster_Al14H66O48                      {}                     {}
# cluster_Al15H66O48                      {}                     {}
# cluster_Al16H78O58                      {}                     {}
# cluster_Al1H10O5                        {}                     {}
# cluster_Al1H12O6                        {}                     {}
# cluster_Al20H96O72                      {}                     {}
# cluster_Al26H132O92            {u'O': 6.0}            {u'O': 6.0}
# cluster_Al26H90O78             {u'O': 6.0}            {u'O': 6.0}
# cluster_Al2H18O10                       {}                     {}
# cluster_Al3H24O14                       {}                     {}
# cluster_Al3H27O15                       {}                     {}
# cluster_Al4H26O16                       {}                     {}
# cluster_Al4H30O18                       {}                     {}
# cluster_Al4H30O19                       {}                     {}
# cluster_Al5H36O22                       {}                     {}
# cluster_Al6H24O18                       {}                     {}
# cluster_Al6H32O22                       {}                     {}
# cluster_Al6H36O24                       {}                     {}
# cluster_Al7H36O24                       {}                     {}
# cluster_Al8H42O28                       {}                     {}
# cluster_Al8H50O32                       {}                     {}
#
#                     BrunnerNN_reciprocal25   BrunnerNN_reciprocal3  \
# cluster_Al10H54O38                      {}             {u'O': 6.0}
# cluster_Al11H54O38                      {}             {u'O': 6.0}
# cluster_Al12H54O38                      {}             {u'O': 6.0}
# cluster_Al13H48O40                      {}             {u'O': 6.0}
# cluster_Al13H51O41                      {}             {u'O': 6.0}
# cluster_Al13H66O48                      {}             {u'O': 6.0}
# cluster_Al13H72O48                      {}             {u'O': 6.0}
# cluster_Al14H66O48                      {}             {u'O': 6.0}
# cluster_Al15H66O48                      {}             {u'O': 6.0}
# cluster_Al16H78O58                      {}             {u'O': 6.0}
# cluster_Al1H10O5                        {}                      {}
# cluster_Al1H12O6                        {}                      {}
# cluster_Al20H96O72                      {}             {u'O': 6.0}
# cluster_Al26H132O92            {u'O': 6.0}             {u'O': 6.0}
# cluster_Al26H90O78             {u'O': 4.0}             {u'O': 6.0}
# cluster_Al2H18O10                       {}                      {}
# cluster_Al3H24O14                       {}                      {}
# cluster_Al3H27O15                       {}                      {}
# cluster_Al4H26O16                       {}                      {}
# cluster_Al4H30O18                       {}  {u'H': 9.0, u'O': 6.0}
# cluster_Al4H30O19                       {}             {u'O': 7.0}
# cluster_Al5H36O22                       {}             {u'O': 6.0}
# cluster_Al6H24O18                       {}                      {}
# cluster_Al6H32O22                       {}             {u'O': 6.0}
# cluster_Al6H36O24                       {}                      {}
# cluster_Al7H36O24                       {}             {u'O': 6.0}
# cluster_Al8H42O28                       {}             {u'O': 6.0}
# cluster_Al8H50O32                       {}             {u'O': 6.0}
#
#                     BrunnerNN_reciprocal4 BrunnerNN_reciprocal5  \
# cluster_Al10H54O38            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al11H54O38            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al12H54O38            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al13H48O40            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al13H51O41            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al13H66O48            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al13H72O48            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al14H66O48            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al15H66O48            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al16H78O58            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al1H10O5                       {}                    {}
# cluster_Al1H12O6                       {}                    {}
# cluster_Al20H96O72            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al26H132O92           {u'O': 6.0}           {u'O': 6.0}
# cluster_Al26H90O78            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al2H18O10                      {}                    {}
# cluster_Al3H24O14                      {}                    {}
# cluster_Al3H27O15                      {}                    {}
# cluster_Al4H26O16                      {}                    {}
# cluster_Al4H30O18                      {}                    {}
# cluster_Al4H30O19                      {}                    {}
# cluster_Al5H36O22             {u'O': 6.0}                    {}
# cluster_Al6H24O18                      {}                    {}
# cluster_Al6H32O22             {u'O': 6.0}           {u'O': 6.0}
# cluster_Al6H36O24                      {}                    {}
# cluster_Al7H36O24             {u'O': 6.0}           {u'O': 6.0}
# cluster_Al8H42O28             {u'O': 6.0}           {u'O': 6.0}
# cluster_Al8H50O32                      {}                    {}
#
#                     BrunnerNN_reciprocal6 BrunnerNN_reciprocal7  \
# cluster_Al10H54O38            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al11H54O38            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al12H54O38            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al13H48O40            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al13H51O41            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al13H66O48            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al13H72O48            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al14H66O48            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al15H66O48            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al16H78O58            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al1H10O5                       {}                    {}
# cluster_Al1H12O6                       {}                    {}
# cluster_Al20H96O72            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al26H132O92           {u'O': 6.0}           {u'O': 6.0}
# cluster_Al26H90O78            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al2H18O10                      {}                    {}
# cluster_Al3H24O14                      {}                    {}
# cluster_Al3H27O15                      {}                    {}
# cluster_Al4H26O16                      {}                    {}
# cluster_Al4H30O18                      {}                    {}
# cluster_Al4H30O19                      {}                    {}
# cluster_Al5H36O22                      {}                    {}
# cluster_Al6H24O18                      {}                    {}
# cluster_Al6H32O22                      {}                    {}
# cluster_Al6H36O24                      {}                    {}
# cluster_Al7H36O24             {u'O': 6.0}                    {}
# cluster_Al8H42O28             {u'O': 6.0}           {u'O': 6.0}
# cluster_Al8H50O32                      {}                    {}
#
#                     BrunnerNN_reciprocal8 BrunnerNN_reciprocal9  \
# cluster_Al10H54O38            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al11H54O38            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al12H54O38            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al13H48O40            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al13H51O41            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al13H66O48            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al13H72O48            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al14H66O48            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al15H66O48            {u'O': 6.0}           {u'O': 4.0}
# cluster_Al16H78O58            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al1H10O5                       {}                    {}
# cluster_Al1H12O6                       {}                    {}
# cluster_Al20H96O72            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al26H132O92           {u'O': 6.0}           {u'O': 6.0}
# cluster_Al26H90O78            {u'O': 6.0}           {u'O': 6.0}
# cluster_Al2H18O10                      {}                    {}
# cluster_Al3H24O14                      {}                    {}
# cluster_Al3H27O15                      {}                    {}
# cluster_Al4H26O16                      {}                    {}
# cluster_Al4H30O18                      {}                    {}
# cluster_Al4H30O19                      {}                    {}
# cluster_Al5H36O22                      {}                    {}
# cluster_Al6H24O18                      {}                    {}
# cluster_Al6H32O22                      {}                    {}
# cluster_Al6H36O24                      {}                    {}
# cluster_Al7H36O24                      {}                    {}
# cluster_Al8H42O28                      {}                    {}
# cluster_Al8H50O32                      {}                    {}
#
#                                      EconNN0                  EconNN1  \
# cluster_Al10H54O38    {u'H': 8.0, u'O': 6.0}   {u'H': 8.0, u'O': 6.0}
# cluster_Al11H54O38    {u'H': 8.0, u'O': 6.0}   {u'H': 8.0, u'O': 6.0}
# cluster_Al12H54O38    {u'H': 8.0, u'O': 6.0}   {u'H': 8.0, u'O': 6.0}
# cluster_Al13H48O40               {u'O': 4.0}   {u'H': 6.0, u'O': 6.0}
# cluster_Al13H51O41               {u'O': 4.0}   {u'H': 6.0, u'O': 6.0}
# cluster_Al13H66O48    {u'H': 8.0, u'O': 6.0}   {u'H': 8.0, u'O': 6.0}
# cluster_Al13H72O48    {u'H': 6.0, u'O': 6.0}   {u'H': 6.0, u'O': 6.0}
# cluster_Al14H66O48    {u'H': 6.0, u'O': 6.0}   {u'H': 6.0, u'O': 6.0}
# cluster_Al15H66O48    {u'H': 6.0, u'O': 6.0}   {u'H': 5.0, u'O': 6.0}
# cluster_Al16H78O58    {u'H': 8.0, u'O': 6.0}   {u'H': 8.0, u'O': 6.0}
# cluster_Al1H10O5     {u'H': 10.0, u'O': 5.0}                       {}
# cluster_Al1H12O6     {u'H': 12.0, u'O': 6.0}                       {}
# cluster_Al20H96O72    {u'H': 8.0, u'O': 6.0}   {u'H': 8.0, u'O': 6.0}
# cluster_Al26H132O92   {u'H': 6.0, u'O': 6.0}   {u'H': 6.0, u'O': 6.0}
# cluster_Al26H90O78    {u'H': 5.0, u'O': 6.0}   {u'H': 6.0, u'O': 6.0}
# cluster_Al2H18O10    {u'H': 10.0, u'O': 6.0}                       {}
# cluster_Al3H24O14    {u'H': 10.0, u'O': 6.0}   {u'H': 8.0, u'O': 6.0}
# cluster_Al3H27O15    {u'H': 10.0, u'O': 6.0}  {u'H': 10.0, u'O': 6.0}
# cluster_Al4H26O16     {u'H': 8.0, u'O': 6.0}   {u'H': 9.0, u'O': 6.0}
# cluster_Al4H30O18     {u'H': 9.0, u'O': 6.0}   {u'H': 9.0, u'O': 6.0}
# cluster_Al4H30O19     {u'H': 9.0, u'O': 7.0}   {u'H': 9.0, u'O': 7.0}
# cluster_Al5H36O22     {u'H': 8.0, u'O': 6.0}  {u'H': 10.0, u'O': 6.0}
# cluster_Al6H24O18     {u'H': 6.0, u'O': 5.0}   {u'H': 6.0, u'O': 5.0}
# cluster_Al6H32O22     {u'H': 6.0, u'O': 5.0}   {u'H': 8.0, u'O': 6.0}
# cluster_Al6H36O24     {u'H': 8.0, u'O': 6.0}   {u'H': 8.0, u'O': 6.0}
# cluster_Al7H36O24     {u'H': 6.0, u'O': 6.0}   {u'H': 8.0, u'O': 6.0}
# cluster_Al8H42O28     {u'H': 6.0, u'O': 6.0}   {u'H': 8.0, u'O': 6.0}
# cluster_Al8H50O32     {u'H': 6.0, u'O': 6.0}   {u'H': 7.0, u'O': 6.0}
#
#                                     EconNN10                 EconNN11  \
# cluster_Al10H54O38                        {}                       {}
# cluster_Al11H54O38    {u'H': 6.0, u'O': 6.0}                       {}
# cluster_Al12H54O38    {u'H': 6.0, u'O': 6.0}   {u'H': 6.0, u'O': 6.0}
# cluster_Al13H48O40    {u'H': 6.0, u'O': 6.0}   {u'H': 6.0, u'O': 6.0}
# cluster_Al13H51O41    {u'H': 6.0, u'O': 6.0}   {u'H': 6.0, u'O': 6.0}
# cluster_Al13H66O48    {u'H': 8.0, u'O': 6.0}   {u'H': 8.0, u'O': 6.0}
# cluster_Al13H72O48   {u'H': 10.0, u'O': 6.0}  {u'H': 10.0, u'O': 6.0}
# cluster_Al14H66O48    {u'H': 8.0, u'O': 6.0}   {u'H': 8.0, u'O': 6.0}
# cluster_Al15H66O48    {u'H': 8.0, u'O': 6.0}   {u'H': 8.0, u'O': 6.0}
# cluster_Al16H78O58    {u'H': 8.0, u'O': 6.0}   {u'H': 8.0, u'O': 6.0}
# cluster_Al1H10O5                          {}                       {}
# cluster_Al1H12O6                          {}                       {}
# cluster_Al20H96O72    {u'H': 6.0, u'O': 6.0}   {u'H': 6.0, u'O': 6.0}
# cluster_Al26H132O92  {u'H': 10.0, u'O': 6.0}   {u'H': 8.0, u'O': 6.0}
# cluster_Al26H90O78    {u'H': 6.0, u'O': 6.0}   {u'H': 6.0, u'O': 6.0}
# cluster_Al2H18O10                         {}                       {}
# cluster_Al3H24O14                         {}                       {}
# cluster_Al3H27O15                         {}                       {}
# cluster_Al4H26O16                         {}                       {}
# cluster_Al4H30O18                         {}                       {}
# cluster_Al4H30O19                         {}                       {}
# cluster_Al5H36O22                         {}                       {}
# cluster_Al6H24O18                         {}                       {}
# cluster_Al6H32O22                         {}                       {}
# cluster_Al6H36O24                         {}                       {}
# cluster_Al7H36O24                         {}                       {}
# cluster_Al8H42O28                         {}                       {}
# cluster_Al8H50O32                         {}                       {}
#
#                                     EconNN12                EconNN13  \
# cluster_Al10H54O38                        {}                      {}
# cluster_Al11H54O38                        {}                      {}
# cluster_Al12H54O38                        {}                      {}
# cluster_Al13H48O40    {u'H': 6.0, u'O': 6.0}                      {}
# cluster_Al13H51O41    {u'H': 6.0, u'O': 6.0}                      {}
# cluster_Al13H66O48    {u'H': 8.0, u'O': 6.0}                      {}
# cluster_Al13H72O48   {u'H': 10.0, u'O': 6.0}                      {}
# cluster_Al14H66O48    {u'H': 8.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al15H66O48    {u'H': 8.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al16H78O58    {u'H': 6.0, u'O': 6.0}  {u'H': 8.0, u'O': 6.0}
# cluster_Al1H10O5                          {}                      {}
# cluster_Al1H12O6                          {}                      {}
# cluster_Al20H96O72    {u'H': 8.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al26H132O92   {u'H': 8.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al26H90O78               {u'O': 4.0}  {u'H': 5.0, u'O': 6.0}
# cluster_Al2H18O10                         {}                      {}
# cluster_Al3H24O14                         {}                      {}
# cluster_Al3H27O15                         {}                      {}
# cluster_Al4H26O16                         {}                      {}
# cluster_Al4H30O18                         {}                      {}
# cluster_Al4H30O19                         {}                      {}
# cluster_Al5H36O22                         {}                      {}
# cluster_Al6H24O18                         {}                      {}
# cluster_Al6H32O22                         {}                      {}
# cluster_Al6H36O24                         {}                      {}
# cluster_Al7H36O24                         {}                      {}
# cluster_Al8H42O28                         {}                      {}
# cluster_Al8H50O32                         {}                      {}
#
#                                    EconNN14                EconNN15  \
# cluster_Al10H54O38                       {}                      {}
# cluster_Al11H54O38                       {}                      {}
# cluster_Al12H54O38                       {}                      {}
# cluster_Al13H48O40                       {}                      {}
# cluster_Al13H51O41                       {}                      {}
# cluster_Al13H66O48                       {}                      {}
# cluster_Al13H72O48                       {}                      {}
# cluster_Al14H66O48                       {}                      {}
# cluster_Al15H66O48   {u'H': 6.0, u'O': 6.0}                      {}
# cluster_Al16H78O58   {u'H': 8.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al1H10O5                         {}                      {}
# cluster_Al1H12O6                         {}                      {}
# cluster_Al20H96O72   {u'H': 6.0, u'O': 6.0}  {u'H': 8.0, u'O': 6.0}
# cluster_Al26H132O92  {u'H': 6.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al26H90O78   {u'H': 6.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al2H18O10                        {}                      {}
# cluster_Al3H24O14                        {}                      {}
# cluster_Al3H27O15                        {}                      {}
# cluster_Al4H26O16                        {}                      {}
# cluster_Al4H30O18                        {}                      {}
# cluster_Al4H30O19                        {}                      {}
# cluster_Al5H36O22                        {}                      {}
# cluster_Al6H24O18                        {}                      {}
# cluster_Al6H32O22                        {}                      {}
# cluster_Al6H36O24                        {}                      {}
# cluster_Al7H36O24                        {}                      {}
# cluster_Al8H42O28                        {}                      {}
# cluster_Al8H50O32                        {}                      {}
#
#                                    EconNN16                EconNN17  \
# cluster_Al10H54O38                       {}                      {}
# cluster_Al11H54O38                       {}                      {}
# cluster_Al12H54O38                       {}                      {}
# cluster_Al13H48O40                       {}                      {}
# cluster_Al13H51O41                       {}                      {}
# cluster_Al13H66O48                       {}                      {}
# cluster_Al13H72O48                       {}                      {}
# cluster_Al14H66O48                       {}                      {}
# cluster_Al15H66O48                       {}                      {}
# cluster_Al16H78O58                       {}                      {}
# cluster_Al1H10O5                         {}                      {}
# cluster_Al1H12O6                         {}                      {}
# cluster_Al20H96O72   {u'H': 6.0, u'O': 6.0}  {u'H': 8.0, u'O': 6.0}
# cluster_Al26H132O92  {u'H': 6.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al26H90O78   {u'H': 6.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al2H18O10                        {}                      {}
# cluster_Al3H24O14                        {}                      {}
# cluster_Al3H27O15                        {}                      {}
# cluster_Al4H26O16                        {}                      {}
# cluster_Al4H30O18                        {}                      {}
# cluster_Al4H30O19                        {}                      {}
# cluster_Al5H36O22                        {}                      {}
# cluster_Al6H24O18                        {}                      {}
# cluster_Al6H32O22                        {}                      {}
# cluster_Al6H36O24                        {}                      {}
# cluster_Al7H36O24                        {}                      {}
# cluster_Al8H42O28                        {}                      {}
# cluster_Al8H50O32                        {}                      {}
#
#                                    EconNN18                EconNN19  \
# cluster_Al10H54O38                       {}                      {}
# cluster_Al11H54O38                       {}                      {}
# cluster_Al12H54O38                       {}                      {}
# cluster_Al13H48O40                       {}                      {}
# cluster_Al13H51O41                       {}                      {}
# cluster_Al13H66O48                       {}                      {}
# cluster_Al13H72O48                       {}                      {}
# cluster_Al14H66O48                       {}                      {}
# cluster_Al15H66O48                       {}                      {}
# cluster_Al16H78O58                       {}                      {}
# cluster_Al1H10O5                         {}                      {}
# cluster_Al1H12O6                         {}                      {}
# cluster_Al20H96O72   {u'H': 8.0, u'O': 6.0}  {u'H': 8.0, u'O': 6.0}
# cluster_Al26H132O92  {u'H': 6.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al26H90O78   {u'H': 6.0, u'O': 6.0}  {u'H': 5.0, u'O': 6.0}
# cluster_Al2H18O10                        {}                      {}
# cluster_Al3H24O14                        {}                      {}
# cluster_Al3H27O15                        {}                      {}
# cluster_Al4H26O16                        {}                      {}
# cluster_Al4H30O18                        {}                      {}
# cluster_Al4H30O19                        {}                      {}
# cluster_Al5H36O22                        {}                      {}
# cluster_Al6H24O18                        {}                      {}
# cluster_Al6H32O22                        {}                      {}
# cluster_Al6H36O24                        {}                      {}
# cluster_Al7H36O24                        {}                      {}
# cluster_Al8H42O28                        {}                      {}
# cluster_Al8H50O32                        {}                      {}
#
#                                      EconNN2                 EconNN20  \
# cluster_Al10H54O38    {u'H': 8.0, u'O': 6.0}                       {}
# cluster_Al11H54O38    {u'H': 8.0, u'O': 6.0}                       {}
# cluster_Al12H54O38    {u'H': 8.0, u'O': 6.0}                       {}
# cluster_Al13H48O40    {u'H': 6.0, u'O': 6.0}                       {}
# cluster_Al13H51O41    {u'H': 6.0, u'O': 6.0}                       {}
# cluster_Al13H66O48    {u'H': 8.0, u'O': 6.0}                       {}
# cluster_Al13H72O48    {u'H': 6.0, u'O': 6.0}                       {}
# cluster_Al14H66O48    {u'H': 8.0, u'O': 6.0}                       {}
# cluster_Al15H66O48    {u'H': 8.0, u'O': 6.0}                       {}
# cluster_Al16H78O58    {u'H': 6.0, u'O': 6.0}                       {}
# cluster_Al1H10O5                          {}                       {}
# cluster_Al1H12O6                          {}                       {}
# cluster_Al20H96O72    {u'H': 6.0, u'O': 6.0}                       {}
# cluster_Al26H132O92   {u'H': 6.0, u'O': 6.0}  {u'H': 10.0, u'O': 6.0}
# cluster_Al26H90O78    {u'H': 6.0, u'O': 6.0}   {u'H': 6.0, u'O': 6.0}
# cluster_Al2H18O10                         {}                       {}
# cluster_Al3H24O14    {u'H': 10.0, u'O': 6.0}                       {}
# cluster_Al3H27O15    {u'H': 10.0, u'O': 6.0}                       {}
# cluster_Al4H26O16                         {}                       {}
# cluster_Al4H30O18     {u'H': 9.0, u'O': 6.0}                       {}
# cluster_Al4H30O19     {u'H': 9.0, u'O': 7.0}                       {}
# cluster_Al5H36O22     {u'H': 8.0, u'O': 6.0}                       {}
# cluster_Al6H24O18     {u'H': 6.0, u'O': 5.0}                       {}
# cluster_Al6H32O22     {u'H': 6.0, u'O': 5.0}                       {}
# cluster_Al6H36O24     {u'H': 8.0, u'O': 6.0}                       {}
# cluster_Al7H36O24     {u'H': 8.0, u'O': 6.0}                       {}
# cluster_Al8H42O28     {u'H': 7.0, u'O': 6.0}                       {}
# cluster_Al8H50O32    {u'H': 10.0, u'O': 6.0}                       {}
#
#                                    EconNN21                EconNN22  \
# cluster_Al10H54O38                       {}                      {}
# cluster_Al11H54O38                       {}                      {}
# cluster_Al12H54O38                       {}                      {}
# cluster_Al13H48O40                       {}                      {}
# cluster_Al13H51O41                       {}                      {}
# cluster_Al13H66O48                       {}                      {}
# cluster_Al13H72O48                       {}                      {}
# cluster_Al14H66O48                       {}                      {}
# cluster_Al15H66O48                       {}                      {}
# cluster_Al16H78O58                       {}                      {}
# cluster_Al1H10O5                         {}                      {}
# cluster_Al1H12O6                         {}                      {}
# cluster_Al20H96O72                       {}                      {}
# cluster_Al26H132O92  {u'H': 8.0, u'O': 6.0}  {u'H': 8.0, u'O': 6.0}
# cluster_Al26H90O78   {u'H': 6.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al2H18O10                        {}                      {}
# cluster_Al3H24O14                        {}                      {}
# cluster_Al3H27O15                        {}                      {}
# cluster_Al4H26O16                        {}                      {}
# cluster_Al4H30O18                        {}                      {}
# cluster_Al4H30O19                        {}                      {}
# cluster_Al5H36O22                        {}                      {}
# cluster_Al6H24O18                        {}                      {}
# cluster_Al6H32O22                        {}                      {}
# cluster_Al6H36O24                        {}                      {}
# cluster_Al7H36O24                        {}                      {}
# cluster_Al8H42O28                        {}                      {}
# cluster_Al8H50O32                        {}                      {}
#
#                                     EconNN23                 EconNN24  \
# cluster_Al10H54O38                        {}                       {}
# cluster_Al11H54O38                        {}                       {}
# cluster_Al12H54O38                        {}                       {}
# cluster_Al13H48O40                        {}                       {}
# cluster_Al13H51O41                        {}                       {}
# cluster_Al13H66O48                        {}                       {}
# cluster_Al13H72O48                        {}                       {}
# cluster_Al14H66O48                        {}                       {}
# cluster_Al15H66O48                        {}                       {}
# cluster_Al16H78O58                        {}                       {}
# cluster_Al1H10O5                          {}                       {}
# cluster_Al1H12O6                          {}                       {}
# cluster_Al20H96O72                        {}                       {}
# cluster_Al26H132O92  {u'H': 10.0, u'O': 6.0}  {u'H': 10.0, u'O': 6.0}
# cluster_Al26H90O78    {u'H': 6.0, u'O': 6.0}   {u'H': 6.0, u'O': 6.0}
# cluster_Al2H18O10                         {}                       {}
# cluster_Al3H24O14                         {}                       {}
# cluster_Al3H27O15                         {}                       {}
# cluster_Al4H26O16                         {}                       {}
# cluster_Al4H30O18                         {}                       {}
# cluster_Al4H30O19                         {}                       {}
# cluster_Al5H36O22                         {}                       {}
# cluster_Al6H24O18                         {}                       {}
# cluster_Al6H32O22                         {}                       {}
# cluster_Al6H36O24                         {}                       {}
# cluster_Al7H36O24                         {}                       {}
# cluster_Al8H42O28                         {}                       {}
# cluster_Al8H50O32                         {}                       {}
#
#                                     EconNN25                  EconNN3  \
# cluster_Al10H54O38                        {}   {u'H': 6.0, u'O': 6.0}
# cluster_Al11H54O38                        {}   {u'H': 8.0, u'O': 6.0}
# cluster_Al12H54O38                        {}   {u'H': 8.0, u'O': 6.0}
# cluster_Al13H48O40                        {}   {u'H': 6.0, u'O': 6.0}
# cluster_Al13H51O41                        {}   {u'H': 6.0, u'O': 6.0}
# cluster_Al13H66O48                        {}   {u'H': 6.0, u'O': 6.0}
# cluster_Al13H72O48                        {}   {u'H': 6.0, u'O': 6.0}
# cluster_Al14H66O48                        {}   {u'H': 8.0, u'O': 6.0}
# cluster_Al15H66O48                        {}   {u'H': 8.0, u'O': 6.0}
# cluster_Al16H78O58                        {}   {u'H': 8.0, u'O': 6.0}
# cluster_Al1H10O5                          {}                       {}
# cluster_Al1H12O6                          {}                       {}
# cluster_Al20H96O72                        {}   {u'H': 8.0, u'O': 6.0}
# cluster_Al26H132O92  {u'H': 10.0, u'O': 6.0}   {u'H': 6.0, u'O': 6.0}
# cluster_Al26H90O78               {u'O': 4.0}   {u'H': 6.0, u'O': 6.0}
# cluster_Al2H18O10                         {}                       {}
# cluster_Al3H24O14                         {}                       {}
# cluster_Al3H27O15                         {}                       {}
# cluster_Al4H26O16                         {}                       {}
# cluster_Al4H30O18                         {}   {u'H': 9.0, u'O': 6.0}
# cluster_Al4H30O19                         {}   {u'H': 9.0, u'O': 7.0}
# cluster_Al5H36O22                         {}   {u'H': 8.0, u'O': 6.0}
# cluster_Al6H24O18                         {}                       {}
# cluster_Al6H32O22                         {}   {u'H': 8.0, u'O': 6.0}
# cluster_Al6H36O24                         {}                       {}
# cluster_Al7H36O24                         {}   {u'H': 8.0, u'O': 6.0}
# cluster_Al8H42O28                         {}   {u'H': 7.0, u'O': 6.0}
# cluster_Al8H50O32                         {}  {u'H': 10.0, u'O': 6.0}
#
#                                      EconNN4                 EconNN5  \
# cluster_Al10H54O38    {u'H': 8.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al11H54O38    {u'H': 6.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al12H54O38    {u'H': 6.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al13H48O40    {u'H': 6.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al13H51O41    {u'H': 7.0, u'O': 6.0}  {u'H': 7.0, u'O': 6.0}
# cluster_Al13H66O48    {u'H': 6.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al13H72O48    {u'H': 6.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al14H66O48    {u'H': 8.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al15H66O48    {u'H': 8.0, u'O': 6.0}  {u'H': 6.0, u'O': 6.0}
# cluster_Al16H78O58    {u'H': 6.0, u'O': 6.0}  {u'H': 8.0, u'O': 6.0}
# cluster_Al1H10O5                          {}                      {}
# cluster_Al1H12O6                          {}                      {}
# cluster_Al20H96O72    {u'H': 8.0, u'O': 6.0}  {u'H': 8.0, u'O': 6.0}
# ...
# cluster_Al2H18O10                   {}                 {}                 {}
# cluster_Al3H24O14                   {}                 {}                 {}
# cluster_Al3H27O15                   {}                 {}                 {}
# cluster_Al4H26O16                   {}                 {}                 {}
# cluster_Al4H30O18                   {}                 {}                 {}
# cluster_Al4H30O19                   {}                 {}                 {}
# cluster_Al5H36O22                   {}                 {}                 {}
# cluster_Al6H24O18                   {}                 {}                 {}
# cluster_Al6H32O22                   {}                 {}                 {}
# cluster_Al6H36O24                   {}                 {}                 {}
# cluster_Al7H36O24                   {}                 {}                 {}
# cluster_Al8H42O28                   {}                 {}                 {}
# cluster_Al8H50O32                   {}                 {}                 {}
#
#                     MinimumOKeeffeNN15 MinimumOKeeffeNN16 MinimumOKeeffeNN17  \
# cluster_Al10H54O38                  {}                 {}                 {}
# cluster_Al11H54O38                  {}                 {}                 {}
# cluster_Al12H54O38                  {}                 {}                 {}
# cluster_Al13H48O40                  {}                 {}                 {}
# cluster_Al13H51O41                  {}                 {}                 {}
# cluster_Al13H66O48                  {}                 {}                 {}
# cluster_Al13H72O48                  {}                 {}                 {}
# cluster_Al14H66O48                  {}                 {}                 {}
# cluster_Al15H66O48                  {}                 {}                 {}
# cluster_Al16H78O58         {u'O': 6.0}                 {}                 {}
# cluster_Al1H10O5                    {}                 {}                 {}
# cluster_Al1H12O6                    {}                 {}                 {}
# cluster_Al20H96O72         {u'O': 6.0}        {u'O': 6.0}        {u'O': 6.0}
# cluster_Al26H132O92        {u'O': 6.0}        {u'O': 6.0}        {u'O': 4.0}
# cluster_Al26H90O78         {u'O': 6.0}        {u'O': 6.0}        {u'O': 6.0}
# cluster_Al2H18O10                   {}                 {}                 {}
# cluster_Al3H24O14                   {}                 {}                 {}
# cluster_Al3H27O15                   {}                 {}                 {}
# cluster_Al4H26O16                   {}                 {}                 {}
# cluster_Al4H30O18                   {}                 {}                 {}
# cluster_Al4H30O19                   {}                 {}                 {}
# cluster_Al5H36O22                   {}                 {}                 {}
# cluster_Al6H24O18                   {}                 {}                 {}
# cluster_Al6H32O22                   {}                 {}                 {}
# cluster_Al6H36O24                   {}                 {}                 {}
# cluster_Al7H36O24                   {}                 {}                 {}
# cluster_Al8H42O28                   {}                 {}                 {}
# cluster_Al8H50O32                   {}                 {}                 {}
#
#                     MinimumOKeeffeNN18 MinimumOKeeffeNN19 MinimumOKeeffeNN2  \
# cluster_Al10H54O38                  {}                 {}       {u'O': 6.0}
# cluster_Al11H54O38                  {}                 {}       {u'O': 5.0}
# cluster_Al12H54O38                  {}                 {}       {u'O': 4.0}
# cluster_Al13H48O40                  {}                 {}       {u'O': 6.0}
# cluster_Al13H51O41                  {}                 {}       {u'O': 6.0}
# cluster_Al13H66O48                  {}                 {}       {u'O': 6.0}
# cluster_Al13H72O48                  {}                 {}       {u'O': 6.0}
# cluster_Al14H66O48                  {}                 {}       {u'O': 5.0}
# cluster_Al15H66O48                  {}                 {}       {u'O': 4.0}
# cluster_Al16H78O58                  {}                 {}       {u'O': 6.0}
# cluster_Al1H10O5                    {}                 {}                {}
# cluster_Al1H12O6                    {}                 {}                {}
# cluster_Al20H96O72         {u'O': 6.0}        {u'O': 6.0}       {u'O': 6.0}
# cluster_Al26H132O92        {u'O': 5.0}        {u'O': 4.0}       {u'O': 4.0}
# cluster_Al26H90O78         {u'O': 6.0}        {u'O': 6.0}       {u'O': 6.0}
# cluster_Al2H18O10                   {}                 {}                {}
# cluster_Al3H24O14                   {}                 {}       {u'O': 6.0}
# cluster_Al3H27O15                   {}                 {}       {u'O': 6.0}
# cluster_Al4H26O16                   {}                 {}                {}
# cluster_Al4H30O18                   {}                 {}       {u'O': 6.0}
# cluster_Al4H30O19                   {}                 {}       {u'O': 4.0}
# cluster_Al5H36O22                   {}                 {}       {u'O': 5.0}
# cluster_Al6H24O18                   {}                 {}       {u'O': 5.0}
# cluster_Al6H32O22                   {}                 {}       {u'O': 5.0}
# cluster_Al6H36O24                   {}                 {}       {u'O': 6.0}
# cluster_Al7H36O24                   {}                 {}       {u'O': 4.0}
# cluster_Al8H42O28                   {}                 {}       {u'O': 4.0}
# cluster_Al8H50O32                   {}                 {}       {u'O': 6.0}
#
#                     MinimumOKeeffeNN20 MinimumOKeeffeNN21 MinimumOKeeffeNN22  \
# cluster_Al10H54O38                  {}                 {}                 {}
# cluster_Al11H54O38                  {}                 {}                 {}
# cluster_Al12H54O38                  {}                 {}                 {}
# cluster_Al13H48O40                  {}                 {}                 {}
# cluster_Al13H51O41                  {}                 {}                 {}
# cluster_Al13H66O48                  {}                 {}                 {}
# cluster_Al13H72O48                  {}                 {}                 {}
# cluster_Al14H66O48                  {}                 {}                 {}
# cluster_Al15H66O48                  {}                 {}                 {}
# cluster_Al16H78O58                  {}                 {}                 {}
# cluster_Al1H10O5                    {}                 {}                 {}
# cluster_Al1H12O6                    {}                 {}                 {}
# cluster_Al20H96O72                  {}                 {}                 {}
# cluster_Al26H132O92        {u'O': 6.0}        {u'O': 5.0}        {u'O': 5.0}
# cluster_Al26H90O78         {u'O': 6.0}        {u'O': 6.0}        {u'O': 6.0}
# cluster_Al2H18O10                   {}                 {}                 {}
# cluster_Al3H24O14                   {}                 {}                 {}
# cluster_Al3H27O15                   {}                 {}                 {}
# cluster_Al4H26O16                   {}                 {}                 {}
# cluster_Al4H30O18                   {}                 {}                 {}
# cluster_Al4H30O19                   {}                 {}                 {}
# cluster_Al5H36O22                   {}                 {}                 {}
# cluster_Al6H24O18                   {}                 {}                 {}
# cluster_Al6H32O22                   {}                 {}                 {}
# cluster_Al6H36O24                   {}                 {}                 {}
# cluster_Al7H36O24                   {}                 {}                 {}
# cluster_Al8H42O28                   {}                 {}                 {}
# cluster_Al8H50O32                   {}                 {}                 {}
#
#                     MinimumOKeeffeNN23 MinimumOKeeffeNN24 MinimumOKeeffeNN25  \
# cluster_Al10H54O38                  {}                 {}                 {}
# cluster_Al11H54O38                  {}                 {}                 {}
# cluster_Al12H54O38                  {}                 {}                 {}
# cluster_Al13H48O40                  {}                 {}                 {}
# cluster_Al13H51O41                  {}                 {}                 {}
# cluster_Al13H66O48                  {}                 {}                 {}
# cluster_Al13H72O48                  {}                 {}                 {}
# cluster_Al14H66O48                  {}                 {}                 {}
# cluster_Al15H66O48                  {}                 {}                 {}
# cluster_Al16H78O58                  {}                 {}                 {}
# cluster_Al1H10O5                    {}                 {}                 {}
# cluster_Al1H12O6                    {}                 {}                 {}
# cluster_Al20H96O72                  {}                 {}                 {}
# cluster_Al26H132O92        {u'O': 6.0}        {u'O': 6.0}        {u'O': 6.0}
# cluster_Al26H90O78         {u'O': 6.0}        {u'O': 6.0}        {u'O': 4.0}
# cluster_Al2H18O10                   {}                 {}                 {}
# cluster_Al3H24O14                   {}                 {}                 {}
# cluster_Al3H27O15                   {}                 {}                 {}
# cluster_Al4H26O16                   {}                 {}                 {}
# cluster_Al4H30O18                   {}                 {}                 {}
# cluster_Al4H30O19                   {}                 {}                 {}
# cluster_Al5H36O22                   {}                 {}                 {}
# cluster_Al6H24O18                   {}                 {}                 {}
# cluster_Al6H32O22                   {}                 {}                 {}
# cluster_Al6H36O24                   {}                 {}                 {}
# cluster_Al7H36O24                   {}                 {}                 {}
# cluster_Al8H42O28                   {}                 {}                 {}
# cluster_Al8H50O32                   {}                 {}                 {}
#
#                     MinimumOKeeffeNN3 MinimumOKeeffeNN4 MinimumOKeeffeNN5  \
# cluster_Al10H54O38        {u'O': 6.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al11H54O38        {u'O': 5.0}       {u'O': 4.0}       {u'O': 4.0}
# cluster_Al12H54O38        {u'O': 4.0}       {u'O': 4.0}       {u'O': 6.0}
# cluster_Al13H48O40        {u'O': 6.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al13H51O41        {u'O': 6.0}       {u'O': 4.0}       {u'O': 5.0}
# cluster_Al13H66O48        {u'O': 6.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al13H72O48        {u'O': 6.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al14H66O48        {u'O': 6.0}       {u'O': 5.0}       {u'O': 4.0}
# cluster_Al15H66O48        {u'O': 4.0}       {u'O': 5.0}       {u'O': 6.0}
# cluster_Al16H78O58        {u'O': 6.0}       {u'O': 6.0}       {u'O': 5.0}
# cluster_Al1H10O5                   {}                {}                {}
# cluster_Al1H12O6                   {}                {}                {}
# cluster_Al20H96O72        {u'O': 6.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al26H132O92       {u'O': 5.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al26H90O78        {u'O': 6.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al2H18O10                  {}                {}                {}
# cluster_Al3H24O14                  {}                {}                {}
# cluster_Al3H27O15                  {}                {}                {}
# cluster_Al4H26O16                  {}                {}                {}
# cluster_Al4H30O18         {u'O': 6.0}                {}                {}
# cluster_Al4H30O19         {u'O': 4.0}                {}                {}
# cluster_Al5H36O22         {u'O': 6.0}       {u'O': 6.0}                {}
# cluster_Al6H24O18                  {}                {}                {}
# cluster_Al6H32O22         {u'O': 6.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al6H36O24                  {}                {}                {}
# cluster_Al7H36O24         {u'O': 4.0}       {u'O': 4.0}       {u'O': 4.0}
# cluster_Al8H42O28         {u'O': 4.0}       {u'O': 5.0}       {u'O': 4.0}
# cluster_Al8H50O32         {u'O': 6.0}                {}                {}
#
#                     MinimumOKeeffeNN6 MinimumOKeeffeNN7 MinimumOKeeffeNN8  \
# cluster_Al10H54O38        {u'O': 6.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al11H54O38        {u'O': 6.0}       {u'O': 6.0}       {u'O': 5.0}
# cluster_Al12H54O38        {u'O': 5.0}       {u'O': 4.0}       {u'O': 4.0}
# cluster_Al13H48O40        {u'O': 6.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al13H51O41        {u'O': 6.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al13H66O48        {u'O': 6.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al13H72O48        {u'O': 6.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al14H66O48        {u'O': 6.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al15H66O48        {u'O': 5.0}       {u'O': 4.0}       {u'O': 4.0}
# cluster_Al16H78O58        {u'O': 6.0}       {u'O': 6.0}       {u'O': 5.0}
# cluster_Al1H10O5                   {}                {}                {}
# cluster_Al1H12O6                   {}                {}                {}
# cluster_Al20H96O72        {u'O': 6.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al26H132O92       {u'O': 5.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al26H90O78        {u'O': 6.0}       {u'O': 6.0}       {u'O': 6.0}
# cluster_Al2H18O10                  {}                {}                {}
# cluster_Al3H24O14                  {}                {}                {}
# cluster_Al3H27O15                  {}                {}                {}
# cluster_Al4H26O16                  {}                {}                {}
# cluster_Al4H30O18                  {}                {}                {}
# cluster_Al4H30O19                  {}                {}                {}
# cluster_Al5H36O22                  {}                {}                {}
# cluster_Al6H24O18                  {}                {}                {}
# cluster_Al6H32O22                  {}                {}                {}
# cluster_Al6H36O24                  {}                {}                {}
# cluster_Al7H36O24         {u'O': 4.0}                {}                {}
# cluster_Al8H42O28         {u'O': 4.0}       {u'O': 6.0}                {}
# cluster_Al8H50O32                  {}                {}                {}
#
#                     MinimumOKeeffeNN9
# cluster_Al10H54O38        {u'O': 6.0}
# cluster_Al11H54O38        {u'O': 6.0}
# cluster_Al12H54O38        {u'O': 5.0}
# cluster_Al13H48O40        {u'O': 6.0}
# cluster_Al13H51O41        {u'O': 6.0}
# cluster_Al13H66O48        {u'O': 6.0}
# cluster_Al13H72O48        {u'O': 6.0}
# cluster_Al14H66O48        {u'O': 6.0}
# cluster_Al15H66O48        {u'O': 4.0}
# cluster_Al16H78O58        {u'O': 6.0}
# cluster_Al1H10O5                   {}
# cluster_Al1H12O6                   {}
# cluster_Al20H96O72        {u'O': 6.0}
# cluster_Al26H132O92       {u'O': 6.0}
# cluster_Al26H90O78        {u'O': 6.0}
# cluster_Al2H18O10                  {}
# cluster_Al3H24O14                  {}
# cluster_Al3H27O15                  {}
# cluster_Al4H26O16                  {}
# cluster_Al4H30O18                  {}
# cluster_Al4H30O19                  {}
# cluster_Al5H36O22                  {}
# cluster_Al6H24O18                  {}
# cluster_Al6H32O22                  {}
# cluster_Al6H36O24                  {}
# cluster_Al7H36O24                  {}
# cluster_Al8H42O28                  {}
# cluster_Al8H50O32                  {}

# %%
nbf = NbFuncs(bm)
df = nbf.final()
df
# Out:
#                      BrunnerNN_reciprocal   EconNN  JMolNN  MinimumDistanceNN  \
# cluster_Al10H54O38                  0.600    2.200   0.600              0.600
# cluster_Al11H54O38                  1.091    3.091   1.091              1.364
# cluster_Al12H54O38                  2.000    4.333   2.000              2.250
# cluster_Al13H48O40                  1.385    3.692   1.385              1.385
# cluster_Al13H51O41                  1.385    3.692   1.385              1.385
# cluster_Al13H66O48                  3.000    6.231   3.000              2.923
# cluster_Al13H72O48                  1.385    5.077   1.385              1.462
# cluster_Al14H66O48                  2.143    5.714   2.143              2.429
# cluster_Al15H66O48                  2.867    6.533   2.867              3.133
# cluster_Al16H78O58                  2.438    6.562   2.438              2.438
# cluster_Al1H10O5                    0.000   10.000   0.000              0.000
# cluster_Al1H12O6                    0.000   12.000   0.000              0.000
# cluster_Al20H96O72                  4.000    8.600   4.000              4.000
# cluster_Al26H132O92                 5.115   11.192   5.115              4.923
# cluster_Al26H90O78                  1.154    6.538   1.154              1.154
# cluster_Al2H18O10                   0.000   10.000   0.000              0.000
# cluster_Al3H24O14                   2.333    7.667   2.333              2.333
# cluster_Al3H27O15                   8.333    8.333   2.333              2.333
# cluster_Al4H26O16                   0.000    8.500   0.000              0.000
# cluster_Al4H30O18                   5.750    5.750   1.750              1.750
# cluster_Al4H30O19                   1.750    6.250   1.750              1.750
# cluster_Al5H36O22                   1.600    4.800   1.600              1.600
# cluster_Al6H24O18                   2.000    5.333   2.000              2.000
# cluster_Al6H32O22                   2.167    4.167   2.167              2.167
# cluster_Al6H36O24                   0.000    5.333   0.000              0.000
# cluster_Al7H36O24                   0.857    2.857   0.857              1.143
# cluster_Al8H42O28                   0.750    2.500   0.750              0.875
# cluster_Al8H50O32                   0.000    3.250   0.000              0.000
# Total                              54.101  170.198  44.101             45.395
#
#                      MinimumOKeeffeNN
# cluster_Al10H54O38              0.600
# cluster_Al11H54O38              1.364
# cluster_Al12H54O38              2.250
# cluster_Al13H48O40              1.385
# cluster_Al13H51O41              1.385
# cluster_Al13H66O48              2.923
# cluster_Al13H72O48              1.462
# cluster_Al14H66O48              2.429
# cluster_Al15H66O48              3.133
# cluster_Al16H78O58              2.438
# cluster_Al1H10O5                0.000
# cluster_Al1H12O6                0.000
# cluster_Al20H96O72              4.000
# cluster_Al26H132O92             4.923
# cluster_Al26H90O78              1.154
# cluster_Al2H18O10               0.000
# cluster_Al3H24O14               2.333
# cluster_Al3H27O15               2.333
# cluster_Al4H26O16               0.000
# cluster_Al4H30O18               1.750
# cluster_Al4H30O19               1.750
# cluster_Al5H36O22               1.600
# cluster_Al6H24O18               2.000
# cluster_Al6H32O22               2.167
# cluster_Al6H36O24               0.000
# cluster_Al7H36O24               1.143
# cluster_Al8H42O28               0.875
# cluster_Al8H50O32               0.000
# Total                          45.395

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 12))

sns.set(font='Times New Roman')
sns.set(font_scale=2)

hm = sns.heatmap(df, annot=True, cmap="BuPu", vmax=10)

ax.set_xticklabels(df.columns.tolist(), rotation=45)
ax.set_yticklabels(df.index.tolist())

plt.savefig('common_binaries.png')
plt.show()
