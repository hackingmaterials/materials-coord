# %%
import pandas as pd
pd.set_option("display.max_columns",999) # display all columns
pd.set_option("display.max_rows", 999)

from pymatgen.analysis.local_env import BrunnerNN_reciprocal, EconNN, JMolNN, \
                                        MinimumDistanceNN, MinimumOKeeffeNN, MinimumVIRENN, \
                                        VoronoiNN, VoronoiNN_modified, CrystalNN
from materialscoord.core import Benchmark, HumanInterpreter

# methods = [BrunnerNN_reciprocal(), EconNN(), JMolNN(), 
#            MinimumDistanceNN(), MinimumOKeeffeNN(), MinimumVIRENN(),
#            HumanInterpreter()]
methods = [BrunnerNN_reciprocal(), HumanInterpreter()]
structure_groups = ["clusters"]

preset = Benchmark.from_preset(preset_name=structure_groups)
preset.benchmark(methods=methods)
# Out:
# /Users/hillarypan/AJResearch/cn_routines/codes/pymatgen/pymatgen/__init__.py:89: UserWarning:
# Pymatgen will drop Py2k support from v2019.1.1. Pls consult the documentation
# at https://www.pymatgen.org for more details.
#   at https://www.pymatgen.org for more details.""")
#                              BrunnerNN_reciprocal0  \
# cluster_Al10H54O38               (Al, {u'O': 6.0})
# cluster_Al11H54O38               (Al, {u'O': 6.0})
# cluster_Al12H54O38               (Al, {u'O': 6.0})
# cluster_Al13H48O40               (Al, {u'O': 4.0})
# cluster_Al13H51O41               (Al, {u'O': 4.0})
# cluster_Al13H66O48               (Al, {u'O': 6.0})
# cluster_Al13H72O48               (Al, {u'O': 6.0})
# cluster_Al14H66O48               (Al, {u'O': 6.0})
# cluster_Al15H66O48               (Al, {u'O': 6.0})
# cluster_Al16H78O58               (Al, {u'O': 6.0})
# cluster_Al1H10O5                 (Al, {u'O': 5.0})
# cluster_Al1H12O6                 (Al, {u'O': 6.0})
# cluster_Al20H96O72               (Al, {u'O': 6.0})
# cluster_Al26H132O92              (Al, {u'O': 6.0})
# cluster_Al26H90O78               (Al, {u'O': 6.0})
# cluster_Al2H18O10                (Al, {u'O': 6.0})
# cluster_Al3H24O14                (Al, {u'O': 6.0})
# cluster_Al3H27O15    (Al, {u'H': 10.0, u'O': 6.0})
# cluster_Al4H26O16                (Al, {u'O': 6.0})
# cluster_Al4H30O18     (Al, {u'H': 9.0, u'O': 6.0})
# cluster_Al4H30O19                (Al, {u'O': 7.0})
# cluster_Al5H36O22                (Al, {u'O': 6.0})
# cluster_Al6H24O18                (Al, {u'O': 5.0})
# cluster_Al6H32O22                (Al, {u'O': 5.0})
# cluster_Al6H36O24                (Al, {u'O': 6.0})
# cluster_Al7H36O24                (Al, {u'O': 6.0})
# cluster_Al8H42O28                (Al, {u'O': 6.0})
# cluster_Al8H50O32                (Al, {u'O': 6.0})
#
#                              BrunnerNN_reciprocal1 BrunnerNN_reciprocal10  \
# cluster_Al10H54O38               (Al, {u'O': 6.0})       (H, {u'O': 1.0})
# cluster_Al11H54O38               (Al, {u'O': 6.0})      (Al, {u'O': 6.0})
# cluster_Al12H54O38               (Al, {u'O': 6.0})      (Al, {u'O': 6.0})
# cluster_Al13H48O40               (Al, {u'O': 6.0})      (Al, {u'O': 6.0})
# cluster_Al13H51O41               (Al, {u'O': 6.0})      (Al, {u'O': 6.0})
# cluster_Al13H66O48               (Al, {u'O': 6.0})      (Al, {u'O': 6.0})
# cluster_Al13H72O48               (Al, {u'O': 6.0})      (Al, {u'O': 6.0})
# cluster_Al14H66O48               (Al, {u'O': 6.0})      (Al, {u'O': 6.0})
# cluster_Al15H66O48               (Al, {u'O': 4.0})      (Al, {u'O': 6.0})
# cluster_Al16H78O58               (Al, {u'O': 6.0})      (Al, {u'O': 6.0})
# cluster_Al1H10O5                  (H, {u'O': 1.0})       (H, {u'O': 1.0})
# cluster_Al1H12O6                  (H, {u'O': 1.0})             (null, {})
# cluster_Al20H96O72               (Al, {u'O': 6.0})      (Al, {u'O': 6.0})
# cluster_Al26H132O92              (Al, {u'O': 6.0})      (Al, {u'O': 6.0})
# cluster_Al26H90O78               (Al, {u'O': 6.0})      (Al, {u'O': 6.0})
# cluster_Al2H18O10                 (H, {u'O': 1.0})       (O, {u'H': 2.0})
# cluster_Al3H24O14                (Al, {u'O': 6.0})       (H, {u'O': 1.0})
# cluster_Al3H27O15    (Al, {u'H': 10.0, u'O': 6.0})       (H, {u'O': 1.0})
# cluster_Al4H26O16                (Al, {u'O': 6.0})       (H, {u'O': 1.0})
# cluster_Al4H30O18     (Al, {u'H': 9.0, u'O': 6.0})       (H, {u'O': 1.0})
# cluster_Al4H30O19                (Al, {u'O': 7.0})       (H, {u'O': 1.0})
# cluster_Al5H36O22                (Al, {u'O': 6.0})       (H, {u'O': 1.0})
# cluster_Al6H24O18                (Al, {u'O': 5.0})       (H, {u'O': 1.0})
# cluster_Al6H32O22                (Al, {u'O': 6.0})       (H, {u'O': 1.0})
# cluster_Al6H36O24                (Al, {u'O': 6.0})       (H, {u'O': 1.0})
# cluster_Al7H36O24                (Al, {u'O': 6.0})       (H, {u'O': 1.0})
# cluster_Al8H42O28                (Al, {u'O': 6.0})       (H, {u'O': 1.0})
# cluster_Al8H50O32                (Al, {u'O': 6.0})       (H, {u'O': 1.0})
#
#                     BrunnerNN_reciprocal100 BrunnerNN_reciprocal101  \
# cluster_Al10H54O38         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al11H54O38         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al12H54O38         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al13H48O40         (O, {u'H': 2.0})              (null, {})
# cluster_Al13H51O41         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al13H66O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al13H72O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al14H66O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al15H66O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al16H78O58         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78         (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal102 BrunnerNN_reciprocal103  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38         (O, {u'H': 2.0})              (null, {})
# cluster_Al12H54O38         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al13H66O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al13H72O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al14H66O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al15H66O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al16H78O58         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78         (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal104 BrunnerNN_reciprocal105  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38               (null, {})              (null, {})
# cluster_Al12H54O38               (null, {})              (null, {})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41         (O, {u'H': 1.0})              (null, {})
# cluster_Al13H66O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al13H72O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al14H66O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al15H66O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al16H78O58         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78         (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal106 BrunnerNN_reciprocal107  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38               (null, {})              (null, {})
# cluster_Al12H54O38               (null, {})              (null, {})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41               (null, {})              (null, {})
# cluster_Al13H66O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al13H72O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al14H66O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al15H66O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al16H78O58         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78         (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal108 BrunnerNN_reciprocal109  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38               (null, {})              (null, {})
# cluster_Al12H54O38               (null, {})              (null, {})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41               (null, {})              (null, {})
# cluster_Al13H66O48         (O, {u'H': 1.0})        (O, {u'H': 2.0})
# cluster_Al13H72O48         (O, {u'H': 1.0})        (O, {u'H': 2.0})
# cluster_Al14H66O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al15H66O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al16H78O58         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78         (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal11 BrunnerNN_reciprocal110  \
# cluster_Al10H54O38        (H, {u'O': 1.0})              (null, {})
# cluster_Al11H54O38        (H, {u'O': 1.0})              (null, {})
# cluster_Al12H54O38       (Al, {u'O': 6.0})              (null, {})
# cluster_Al13H48O40       (Al, {u'O': 6.0})              (null, {})
# cluster_Al13H51O41       (Al, {u'O': 6.0})              (null, {})
# cluster_Al13H66O48       (Al, {u'O': 6.0})        (O, {u'H': 2.0})
# cluster_Al13H72O48       (Al, {u'O': 6.0})        (O, {u'H': 2.0})
# cluster_Al14H66O48       (Al, {u'O': 6.0})        (O, {u'H': 2.0})
# cluster_Al15H66O48       (Al, {u'O': 6.0})        (O, {u'H': 1.0})
# cluster_Al16H78O58       (Al, {u'O': 6.0})        (O, {u'H': 1.0})
# cluster_Al1H10O5          (O, {u'H': 2.0})              (null, {})
# cluster_Al1H12O6                (null, {})              (null, {})
# cluster_Al20H96O72       (Al, {u'O': 6.0})        (H, {u'O': 1.0})
# cluster_Al26H132O92      (Al, {u'O': 6.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78       (Al, {u'O': 6.0})        (H, {u'O': 1.0})
# cluster_Al2H18O10               (null, {})              (null, {})
# cluster_Al3H24O14         (H, {u'O': 1.0})              (null, {})
# cluster_Al3H27O15         (H, {u'O': 1.0})              (null, {})
# cluster_Al4H26O16         (H, {u'O': 1.0})              (null, {})
# cluster_Al4H30O18         (H, {u'O': 1.0})              (null, {})
# cluster_Al4H30O19         (H, {u'O': 1.0})              (null, {})
# cluster_Al5H36O22         (H, {u'O': 1.0})              (null, {})
# cluster_Al6H24O18         (H, {u'O': 1.0})              (null, {})
# cluster_Al6H32O22         (H, {u'O': 1.0})              (null, {})
# cluster_Al6H36O24         (H, {u'O': 1.0})              (null, {})
# cluster_Al7H36O24         (H, {u'O': 1.0})              (null, {})
# cluster_Al8H42O28         (H, {u'O': 1.0})              (null, {})
# cluster_Al8H50O32         (H, {u'O': 1.0})              (null, {})
#
#                     BrunnerNN_reciprocal111 BrunnerNN_reciprocal112  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38               (null, {})              (null, {})
# cluster_Al12H54O38               (null, {})              (null, {})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41               (null, {})              (null, {})
# cluster_Al13H66O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al13H72O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al14H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al15H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al16H78O58         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78         (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal113 BrunnerNN_reciprocal114  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38               (null, {})              (null, {})
# cluster_Al12H54O38               (null, {})              (null, {})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41               (null, {})              (null, {})
# cluster_Al13H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al13H72O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al14H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al15H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al16H78O58         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78         (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal115 BrunnerNN_reciprocal116  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38               (null, {})              (null, {})
# cluster_Al12H54O38               (null, {})              (null, {})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41               (null, {})              (null, {})
# cluster_Al13H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al13H72O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al14H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al15H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al16H78O58         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (H, {u'O': 1.0})        (O, {u'H': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78         (H, {u'O': 1.0})       (O, {u'Al': 4.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal117 BrunnerNN_reciprocal118  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38               (null, {})              (null, {})
# cluster_Al12H54O38               (null, {})              (null, {})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41               (null, {})              (null, {})
# cluster_Al13H66O48         (O, {u'H': 2.0})        (O, {u'H': 1.0})
# cluster_Al13H72O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al14H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al15H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al16H78O58         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78        (O, {u'Al': 4.0})       (O, {u'Al': 4.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal119 BrunnerNN_reciprocal12  \
# cluster_Al10H54O38               (null, {})       (H, {u'O': 1.0})
# cluster_Al11H54O38               (null, {})       (H, {u'O': 1.0})
# cluster_Al12H54O38               (null, {})       (H, {u'O': 1.0})
# cluster_Al13H48O40               (null, {})      (Al, {u'O': 6.0})
# cluster_Al13H51O41               (null, {})      (Al, {u'O': 6.0})
# cluster_Al13H66O48         (O, {u'H': 2.0})      (Al, {u'O': 6.0})
# cluster_Al13H72O48         (O, {u'H': 2.0})      (Al, {u'O': 6.0})
# cluster_Al14H66O48         (O, {u'H': 2.0})      (Al, {u'O': 6.0})
# cluster_Al15H66O48         (O, {u'H': 2.0})      (Al, {u'O': 6.0})
# cluster_Al16H78O58         (O, {u'H': 1.0})      (Al, {u'O': 6.0})
# cluster_Al1H10O5                 (null, {})       (O, {u'H': 2.0})
# cluster_Al1H12O6                 (null, {})             (null, {})
# cluster_Al20H96O72         (O, {u'H': 1.0})      (Al, {u'O': 6.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})      (Al, {u'O': 6.0})
# cluster_Al26H90O78        (O, {u'Al': 4.0})      (Al, {u'O': 4.0})
# cluster_Al2H18O10                (null, {})             (null, {})
# cluster_Al3H24O14                (null, {})       (H, {u'O': 1.0})
# cluster_Al3H27O15                (null, {})       (H, {u'O': 1.0})
# cluster_Al4H26O16                (null, {})       (H, {u'O': 1.0})
# cluster_Al4H30O18                (null, {})       (H, {u'O': 1.0})
# cluster_Al4H30O19                (null, {})       (H, {u'O': 1.0})
# cluster_Al5H36O22                (null, {})       (H, {u'O': 1.0})
# cluster_Al6H24O18                (null, {})       (H, {u'O': 1.0})
# cluster_Al6H32O22                (null, {})       (H, {u'O': 1.0})
# cluster_Al6H36O24                (null, {})       (H, {u'O': 1.0})
# cluster_Al7H36O24                (null, {})       (H, {u'O': 1.0})
# cluster_Al8H42O28                (null, {})       (H, {u'O': 1.0})
# cluster_Al8H50O32                (null, {})       (H, {u'O': 1.0})
#
#                     BrunnerNN_reciprocal120 BrunnerNN_reciprocal121  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38               (null, {})              (null, {})
# cluster_Al12H54O38               (null, {})              (null, {})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41               (null, {})              (null, {})
# cluster_Al13H66O48         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al13H72O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al14H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al15H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al16H78O58         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78        (O, {u'Al': 4.0})       (O, {u'Al': 4.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal122 BrunnerNN_reciprocal123  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38               (null, {})              (null, {})
# cluster_Al12H54O38               (null, {})              (null, {})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41               (null, {})              (null, {})
# cluster_Al13H66O48         (O, {u'H': 1.0})        (O, {u'H': 2.0})
# cluster_Al13H72O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al14H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al15H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al16H78O58         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78        (O, {u'Al': 4.0})       (O, {u'Al': 4.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal124 BrunnerNN_reciprocal125  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38               (null, {})              (null, {})
# cluster_Al12H54O38               (null, {})              (null, {})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41               (null, {})              (null, {})
# cluster_Al13H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al13H72O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al14H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al15H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al16H78O58         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal126 BrunnerNN_reciprocal127  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38               (null, {})              (null, {})
# cluster_Al12H54O38               (null, {})              (null, {})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41               (null, {})              (null, {})
# cluster_Al13H66O48         (O, {u'H': 2.0})              (null, {})
# cluster_Al13H72O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al14H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al15H66O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al16H78O58         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78         (O, {u'H': 1.0})        (O, {u'H': 2.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal128 BrunnerNN_reciprocal129  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38               (null, {})              (null, {})
# cluster_Al12H54O38               (null, {})              (null, {})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41               (null, {})              (null, {})
# cluster_Al13H66O48               (null, {})              (null, {})
# cluster_Al13H72O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al14H66O48               (null, {})              (null, {})
# cluster_Al15H66O48         (O, {u'H': 2.0})              (null, {})
# cluster_Al16H78O58         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78         (O, {u'H': 2.0})        (O, {u'H': 1.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal13 BrunnerNN_reciprocal130  \
# cluster_Al10H54O38        (H, {u'O': 1.0})              (null, {})
# cluster_Al11H54O38        (H, {u'O': 1.0})              (null, {})
# cluster_Al12H54O38        (H, {u'O': 1.0})              (null, {})
# cluster_Al13H48O40        (H, {u'O': 1.0})              (null, {})
# cluster_Al13H51O41        (H, {u'O': 1.0})              (null, {})
# cluster_Al13H66O48        (H, {u'O': 1.0})              (null, {})
# cluster_Al13H72O48        (H, {u'O': 1.0})        (O, {u'H': 2.0})
# cluster_Al14H66O48       (Al, {u'O': 6.0})              (null, {})
# cluster_Al15H66O48       (Al, {u'O': 6.0})              (null, {})
# cluster_Al16H78O58       (Al, {u'O': 6.0})        (O, {u'H': 1.0})
# cluster_Al1H10O5          (O, {u'H': 2.0})              (null, {})
# cluster_Al1H12O6                (null, {})              (null, {})
# cluster_Al20H96O72       (Al, {u'O': 6.0})        (O, {u'H': 1.0})
# cluster_Al26H132O92      (Al, {u'O': 6.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78       (Al, {u'O': 6.0})        (O, {u'H': 2.0})
# cluster_Al2H18O10               (null, {})              (null, {})
# cluster_Al3H24O14         (H, {u'O': 1.0})              (null, {})
# cluster_Al3H27O15         (H, {u'O': 1.0})              (null, {})
# cluster_Al4H26O16         (H, {u'O': 1.0})              (null, {})
# cluster_Al4H30O18         (H, {u'O': 1.0})              (null, {})
# cluster_Al4H30O19         (H, {u'O': 1.0})              (null, {})
# cluster_Al5H36O22         (H, {u'O': 1.0})              (null, {})
# cluster_Al6H24O18         (H, {u'O': 1.0})              (null, {})
# cluster_Al6H32O22         (H, {u'O': 1.0})              (null, {})
# cluster_Al6H36O24         (H, {u'O': 1.0})              (null, {})
# cluster_Al7H36O24         (H, {u'O': 1.0})              (null, {})
# cluster_Al8H42O28         (H, {u'O': 1.0})              (null, {})
# cluster_Al8H50O32         (H, {u'O': 1.0})              (null, {})
#
#                     BrunnerNN_reciprocal131 BrunnerNN_reciprocal132  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38               (null, {})              (null, {})
# cluster_Al12H54O38               (null, {})              (null, {})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41               (null, {})              (null, {})
# cluster_Al13H66O48               (null, {})              (null, {})
# cluster_Al13H72O48         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al14H66O48               (null, {})              (null, {})
# cluster_Al15H66O48               (null, {})              (null, {})
# cluster_Al16H78O58         (O, {u'H': 1.0})        (O, {u'H': 2.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78         (O, {u'H': 2.0})        (O, {u'H': 1.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal133 BrunnerNN_reciprocal134  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38               (null, {})              (null, {})
# cluster_Al12H54O38               (null, {})              (null, {})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41               (null, {})              (null, {})
# cluster_Al13H66O48               (null, {})              (null, {})
# cluster_Al13H72O48               (null, {})              (null, {})
# cluster_Al14H66O48               (null, {})              (null, {})
# cluster_Al15H66O48               (null, {})              (null, {})
# cluster_Al16H78O58         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78         (O, {u'H': 2.0})        (O, {u'H': 1.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal135 BrunnerNN_reciprocal136  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38               (null, {})              (null, {})
# cluster_Al12H54O38               (null, {})              (null, {})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41               (null, {})              (null, {})
# cluster_Al13H66O48               (null, {})              (null, {})
# cluster_Al13H72O48               (null, {})              (null, {})
# cluster_Al14H66O48               (null, {})              (null, {})
# cluster_Al15H66O48               (null, {})              (null, {})
# cluster_Al16H78O58         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal137 BrunnerNN_reciprocal138  \
# cluster_Al10H54O38               (null, {})              (null, {})
# cluster_Al11H54O38               (null, {})              (null, {})
# cluster_Al12H54O38               (null, {})              (null, {})
# cluster_Al13H48O40               (null, {})              (null, {})
# cluster_Al13H51O41               (null, {})              (null, {})
# cluster_Al13H66O48               (null, {})              (null, {})
# cluster_Al13H72O48               (null, {})              (null, {})
# cluster_Al14H66O48               (null, {})              (null, {})
# cluster_Al15H66O48               (null, {})              (null, {})
# cluster_Al16H78O58         (O, {u'H': 2.0})        (O, {u'H': 2.0})
# cluster_Al1H10O5                 (null, {})              (null, {})
# cluster_Al1H12O6                 (null, {})              (null, {})
# cluster_Al20H96O72         (O, {u'H': 1.0})        (O, {u'H': 1.0})
# cluster_Al26H132O92        (H, {u'O': 1.0})        (H, {u'O': 1.0})
# cluster_Al26H90O78         (O, {u'H': 1.0})        (O, {u'H': 2.0})
# cluster_Al2H18O10                (null, {})              (null, {})
# cluster_Al3H24O14                (null, {})              (null, {})
# cluster_Al3H27O15                (null, {})              (null, {})
# cluster_Al4H26O16                (null, {})              (null, {})
# cluster_Al4H30O18                (null, {})              (null, {})
# cluster_Al4H30O19                (null, {})              (null, {})
# cluster_Al5H36O22                (null, {})              (null, {})
# cluster_Al6H24O18                (null, {})              (null, {})
# cluster_Al6H32O22                (null, {})              (null, {})
# cluster_Al6H36O24                (null, {})              (null, {})
# cluster_Al7H36O24                (null, {})              (null, {})
# cluster_Al8H42O28                (null, {})              (null, {})
# cluster_Al8H50O32                (null, {})              (null, {})
#
#                     BrunnerNN_reciprocal139 BrunnerNN_reciprocal14  \
# cluster_Al10H54O38               (null, {})       (H, {u'O': 1.0})
# cluster_Al11H54O38               (null, {})       (H, {u'O': 1.0})
# cluster_Al12H54O38               (null, {})       (H, {u'O': 1.0})
# cluster_Al13H48O40               (null, {})       (H, {u'O': 1.0})
# cluster_Al13H51O41               (null, {})       (H, {u'O': 1.0})
# cluster_Al13H66O48               (null, {})       (H, {u'O': 1.0})
# cluster_Al13H72O48               (null, {})       (H, {u'O': 1.0})
# cluster_Al14H66O48               (null, {})       (H, {u'O': 1.0})
# cluster_Al15H66O48               (null, {})      (Al, {u'O': 6.0})
# ...
# cluster_Al3H24O14     (H, {u'H': 2.0, u'Al': 1.0})
# cluster_Al3H27O15     (H, {u'H': 2.0, u'Al': 1.0})
# cluster_Al4H26O16     (H, {u'H': 1.0, u'Al': 2.0})
# cluster_Al4H30O18                 (H, {u'O': 1.0})
# cluster_Al4H30O19     (H, {u'H': 2.0, u'Al': 1.0})
# cluster_Al5H36O22                 (H, {u'O': 1.0})
# cluster_Al6H24O18     (H, {u'H': 2.0, u'Al': 1.0})
# cluster_Al6H32O22                 (H, {u'O': 5.0})
# cluster_Al6H36O24     (H, {u'H': 1.0, u'Al': 2.0})
# cluster_Al7H36O24     (H, {u'H': 1.0, u'Al': 3.0})
# cluster_Al8H42O28     (H, {u'H': 1.0, u'Al': 3.0})
# cluster_Al8H50O32     (H, {u'H': 1.0, u'Al': 3.0})
#
#                                HumanInterpreter90  \
# cluster_Al10H54O38   (O, {u'H': 2.0, u'Al': 1.0})
# cluster_Al11H54O38               (O, {u'O': 1.0})
# cluster_Al12H54O38               (O, {u'O': 1.0})
# cluster_Al13H48O40               (O, {u'O': 1.0})
# cluster_Al13H51O41               (O, {u'O': 1.0})
# cluster_Al13H66O48               (O, {u'O': 1.0})
# cluster_Al13H72O48               (O, {u'O': 1.0})
# cluster_Al14H66O48               (O, {u'O': 1.0})
# cluster_Al15H66O48               (O, {u'O': 1.0})
# cluster_Al16H78O58               (H, {u'O': 1.0})
# cluster_Al1H10O5                       (null, {})
# cluster_Al1H12O6                       (null, {})
# cluster_Al20H96O72   (H, {u'H': 1.0, u'Al': 2.0})
# cluster_Al26H132O92  (H, {u'H': 1.0, u'Al': 2.0})
# cluster_Al26H90O78               (H, {u'O': 1.0})
# cluster_Al2H18O10                      (null, {})
# cluster_Al3H24O14                      (null, {})
# cluster_Al3H27O15                      (null, {})
# cluster_Al4H26O16                      (null, {})
# cluster_Al4H30O18                      (null, {})
# cluster_Al4H30O19                      (null, {})
# cluster_Al5H36O22                      (null, {})
# cluster_Al6H24O18                      (null, {})
# cluster_Al6H32O22                      (null, {})
# cluster_Al6H36O24                      (null, {})
# cluster_Al7H36O24                      (null, {})
# cluster_Al8H42O28                      (null, {})
# cluster_Al8H50O32                      (null, {})
#
#                                HumanInterpreter91  \
# cluster_Al10H54O38               (O, {u'O': 1.0})
# cluster_Al11H54O38               (O, {u'O': 1.0})
# cluster_Al12H54O38               (O, {u'O': 1.0})
# cluster_Al13H48O40               (O, {u'O': 1.0})
# cluster_Al13H51O41   (O, {u'H': 2.0, u'Al': 1.0})
# cluster_Al13H66O48               (O, {u'O': 1.0})
# cluster_Al13H72O48               (O, {u'O': 1.0})
# cluster_Al14H66O48               (O, {u'O': 1.0})
# cluster_Al15H66O48               (O, {u'O': 1.0})
# cluster_Al16H78O58               (H, {u'O': 1.0})
# cluster_Al1H10O5                       (null, {})
# cluster_Al1H12O6                       (null, {})
# cluster_Al20H96O72   (H, {u'H': 1.0, u'Al': 2.0})
# cluster_Al26H132O92  (H, {u'H': 1.0, u'Al': 2.0})
# cluster_Al26H90O78   (H, {u'H': 2.0, u'Al': 1.0})
# cluster_Al2H18O10                      (null, {})
# cluster_Al3H24O14                      (null, {})
# cluster_Al3H27O15                      (null, {})
# cluster_Al4H26O16                      (null, {})
# cluster_Al4H30O18                      (null, {})
# cluster_Al4H30O19                      (null, {})
# cluster_Al5H36O22                      (null, {})
# cluster_Al6H24O18                      (null, {})
# cluster_Al6H32O22                      (null, {})
# cluster_Al6H36O24                      (null, {})
# cluster_Al7H36O24                      (null, {})
# cluster_Al8H42O28                      (null, {})
# cluster_Al8H50O32                      (null, {})
#
#                                HumanInterpreter92  \
# cluster_Al10H54O38               (O, {u'O': 1.0})
# cluster_Al11H54O38               (O, {u'O': 1.0})
# cluster_Al12H54O38               (O, {u'O': 1.0})
# cluster_Al13H48O40               (O, {u'O': 1.0})
# cluster_Al13H51O41               (O, {u'O': 1.0})
# cluster_Al13H66O48               (O, {u'O': 1.0})
# cluster_Al13H72O48               (O, {u'O': 1.0})
# cluster_Al14H66O48               (O, {u'O': 1.0})
# cluster_Al15H66O48               (O, {u'O': 1.0})
# cluster_Al16H78O58   (H, {u'H': 2.0, u'Al': 1.0})
# cluster_Al1H10O5                       (null, {})
# cluster_Al1H12O6                       (null, {})
# cluster_Al20H96O72               (H, {u'O': 1.0})
# cluster_Al26H132O92              (H, {u'O': 6.0})
# cluster_Al26H90O78               (H, {u'O': 1.0})
# cluster_Al2H18O10                      (null, {})
# cluster_Al3H24O14                      (null, {})
# cluster_Al3H27O15                      (null, {})
# cluster_Al4H26O16                      (null, {})
# cluster_Al4H30O18                      (null, {})
# cluster_Al4H30O19                      (null, {})
# cluster_Al5H36O22                      (null, {})
# cluster_Al6H24O18                      (null, {})
# cluster_Al6H32O22                      (null, {})
# cluster_Al6H36O24                      (null, {})
# cluster_Al7H36O24                      (null, {})
# cluster_Al8H42O28                      (null, {})
# cluster_Al8H50O32                      (null, {})
#
#                                HumanInterpreter93  \
# cluster_Al10H54O38   (O, {u'H': 2.0, u'Al': 1.0})
# cluster_Al11H54O38               (O, {u'O': 1.0})
# cluster_Al12H54O38               (O, {u'O': 1.0})
# cluster_Al13H48O40               (O, {u'O': 1.0})
# cluster_Al13H51O41               (O, {u'O': 1.0})
# cluster_Al13H66O48               (O, {u'O': 1.0})
# cluster_Al13H72O48               (O, {u'O': 1.0})
# cluster_Al14H66O48               (O, {u'O': 1.0})
# cluster_Al15H66O48               (O, {u'O': 1.0})
# cluster_Al16H78O58               (H, {u'O': 1.0})
# cluster_Al1H10O5                       (null, {})
# cluster_Al1H12O6                       (null, {})
# cluster_Al20H96O72               (H, {u'O': 6.0})
# cluster_Al26H132O92  (H, {u'H': 2.0, u'Al': 1.0})
# cluster_Al26H90O78               (H, {u'O': 1.0})
# cluster_Al2H18O10                      (null, {})
# cluster_Al3H24O14                      (null, {})
# cluster_Al3H27O15                      (null, {})
# cluster_Al4H26O16                      (null, {})
# cluster_Al4H30O18                      (null, {})
# cluster_Al4H30O19                      (null, {})
# cluster_Al5H36O22                      (null, {})
# cluster_Al6H24O18                      (null, {})
# cluster_Al6H32O22                      (null, {})
# cluster_Al6H36O24                      (null, {})
# cluster_Al7H36O24                      (null, {})
# cluster_Al8H42O28                      (null, {})
# cluster_Al8H50O32                      (null, {})
#
#                                HumanInterpreter94  \
# cluster_Al10H54O38               (O, {u'O': 1.0})
# cluster_Al11H54O38               (O, {u'O': 1.0})
# cluster_Al12H54O38               (O, {u'O': 1.0})
# cluster_Al13H48O40               (O, {u'O': 1.0})
# cluster_Al13H51O41   (O, {u'H': 2.0, u'Al': 1.0})
# cluster_Al13H66O48               (O, {u'O': 1.0})
# cluster_Al13H72O48               (O, {u'O': 1.0})
# cluster_Al14H66O48               (O, {u'O': 1.0})
# cluster_Al15H66O48               (O, {u'O': 1.0})
# cluster_Al16H78O58               (O, {u'O': 1.0})
# cluster_Al1H10O5                       (null, {})
# cluster_Al1H12O6                       (null, {})
# cluster_Al20H96O72   (H, {u'H': 1.0, u'Al': 2.0})
# cluster_Al26H132O92  (H, {u'H': 2.0, u'Al': 1.0})
# cluster_Al26H90O78   (H, {u'H': 1.0, u'Al': 2.0})
# cluster_Al2H18O10                      (null, {})
# cluster_Al3H24O14                      (null, {})
# cluster_Al3H27O15                      (null, {})
# cluster_Al4H26O16                      (null, {})
# cluster_Al4H30O18                      (null, {})
# cluster_Al4H30O19                      (null, {})
# cluster_Al5H36O22                      (null, {})
# cluster_Al6H24O18                      (null, {})
# cluster_Al6H32O22                      (null, {})
# cluster_Al6H36O24                      (null, {})
# cluster_Al7H36O24                      (null, {})
# cluster_Al8H42O28                      (null, {})
# cluster_Al8H50O32                      (null, {})
#
#                                HumanInterpreter95  \
# cluster_Al10H54O38               (O, {u'O': 1.0})
# cluster_Al11H54O38               (O, {u'O': 1.0})
# cluster_Al12H54O38               (O, {u'O': 1.0})
# cluster_Al13H48O40               (O, {u'O': 1.0})
# cluster_Al13H51O41               (O, {u'O': 1.0})
# cluster_Al13H66O48               (O, {u'O': 1.0})
# cluster_Al13H72O48               (O, {u'O': 1.0})
# cluster_Al14H66O48               (O, {u'O': 1.0})
# cluster_Al15H66O48               (O, {u'O': 1.0})
# cluster_Al16H78O58   (O, {u'H': 2.0, u'Al': 1.0})
# cluster_Al1H10O5                       (null, {})
# cluster_Al1H12O6                       (null, {})
# cluster_Al20H96O72               (H, {u'O': 1.0})
# cluster_Al26H132O92  (H, {u'H': 2.0, u'Al': 1.0})
# cluster_Al26H90O78               (H, {u'O': 1.0})
# cluster_Al2H18O10                      (null, {})
# cluster_Al3H24O14                      (null, {})
# cluster_Al3H27O15                      (null, {})
# cluster_Al4H26O16                      (null, {})
# cluster_Al4H30O18                      (null, {})
# cluster_Al4H30O19                      (null, {})
# cluster_Al5H36O22                      (null, {})
# cluster_Al6H24O18                      (null, {})
# cluster_Al6H32O22                      (null, {})
# cluster_Al6H36O24                      (null, {})
# cluster_Al7H36O24                      (null, {})
# cluster_Al8H42O28                      (null, {})
# cluster_Al8H50O32                      (null, {})
#
#                                HumanInterpreter96  \
# cluster_Al10H54O38   (O, {u'H': 2.0, u'Al': 1.0})
# cluster_Al11H54O38               (O, {u'O': 1.0})
# cluster_Al12H54O38               (O, {u'O': 1.0})
# cluster_Al13H48O40               (O, {u'O': 1.0})
# cluster_Al13H51O41               (O, {u'O': 1.0})
# cluster_Al13H66O48               (O, {u'O': 1.0})
# cluster_Al13H72O48               (O, {u'O': 1.0})
# cluster_Al14H66O48               (O, {u'O': 1.0})
# cluster_Al15H66O48               (O, {u'O': 1.0})
# cluster_Al16H78O58               (O, {u'O': 1.0})
# cluster_Al1H10O5                       (null, {})
# cluster_Al1H12O6                       (null, {})
# cluster_Al20H96O72   (H, {u'H': 1.0, u'Al': 2.0})
# cluster_Al26H132O92  (H, {u'H': 2.0, u'Al': 1.0})
# cluster_Al26H90O78   (H, {u'H': 2.0, u'Al': 1.0})
# cluster_Al2H18O10                      (null, {})
# cluster_Al3H24O14                      (null, {})
# cluster_Al3H27O15                      (null, {})
# cluster_Al4H26O16                      (null, {})
# cluster_Al4H30O18                      (null, {})
# cluster_Al4H30O19                      (null, {})
# cluster_Al5H36O22                      (null, {})
# cluster_Al6H24O18                      (null, {})
# cluster_Al6H32O22                      (null, {})
# cluster_Al6H36O24                      (null, {})
# cluster_Al7H36O24                      (null, {})
# cluster_Al8H42O28                      (null, {})
# cluster_Al8H50O32                      (null, {})
#
#                                HumanInterpreter97  \
# cluster_Al10H54O38               (O, {u'O': 1.0})
# cluster_Al11H54O38               (O, {u'O': 1.0})
# cluster_Al12H54O38               (O, {u'O': 1.0})
# cluster_Al13H48O40               (O, {u'O': 1.0})
# cluster_Al13H51O41   (O, {u'H': 2.0, u'Al': 1.0})
# cluster_Al13H66O48               (O, {u'O': 1.0})
# cluster_Al13H72O48               (O, {u'O': 1.0})
# cluster_Al14H66O48               (O, {u'O': 1.0})
# cluster_Al15H66O48               (O, {u'O': 1.0})
# cluster_Al16H78O58               (O, {u'O': 1.0})
# cluster_Al1H10O5                       (null, {})
# cluster_Al1H12O6                       (null, {})
# cluster_Al20H96O72   (H, {u'H': 1.0, u'Al': 2.0})
# cluster_Al26H132O92              (H, {u'O': 6.0})
# cluster_Al26H90O78               (H, {u'O': 1.0})
# cluster_Al2H18O10                      (null, {})
# cluster_Al3H24O14                      (null, {})
# cluster_Al3H27O15                      (null, {})
# cluster_Al4H26O16                      (null, {})
# cluster_Al4H30O18                      (null, {})
# cluster_Al4H30O19                      (null, {})
# cluster_Al5H36O22                      (null, {})
# cluster_Al6H24O18                      (null, {})
# cluster_Al6H32O22                      (null, {})
# cluster_Al6H36O24                      (null, {})
# cluster_Al7H36O24                      (null, {})
# cluster_Al8H42O28                      (null, {})
# cluster_Al8H50O32                      (null, {})
#
#                                HumanInterpreter98  \
# cluster_Al10H54O38               (O, {u'O': 1.0})
# cluster_Al11H54O38               (O, {u'O': 1.0})
# cluster_Al12H54O38               (O, {u'O': 1.0})
# cluster_Al13H48O40               (O, {u'O': 1.0})
# cluster_Al13H51O41               (O, {u'O': 1.0})
# cluster_Al13H66O48               (O, {u'O': 6.0})
# cluster_Al13H72O48               (O, {u'O': 1.0})
# cluster_Al14H66O48               (O, {u'O': 1.0})
# cluster_Al15H66O48               (O, {u'O': 1.0})
# cluster_Al16H78O58   (O, {u'H': 2.0, u'Al': 1.0})
# cluster_Al1H10O5                       (null, {})
# cluster_Al1H12O6                       (null, {})
# cluster_Al20H96O72               (H, {u'O': 6.0})
# cluster_Al26H132O92  (H, {u'H': 2.0, u'Al': 1.0})
# cluster_Al26H90O78               (H, {u'O': 1.0})
# cluster_Al2H18O10                      (null, {})
# cluster_Al3H24O14                      (null, {})
# cluster_Al3H27O15                      (null, {})
# cluster_Al4H26O16                      (null, {})
# cluster_Al4H30O18                      (null, {})
# cluster_Al4H30O19                      (null, {})
# cluster_Al5H36O22                      (null, {})
# cluster_Al6H24O18                      (null, {})
# cluster_Al6H32O22                      (null, {})
# cluster_Al6H36O24                      (null, {})
# cluster_Al7H36O24                      (null, {})
# cluster_Al8H42O28                      (null, {})
# cluster_Al8H50O32                      (null, {})
#
#                                HumanInterpreter99
# cluster_Al10H54O38   (O, {u'H': 2.0, u'Al': 1.0})
# cluster_Al11H54O38               (O, {u'O': 1.0})
# cluster_Al12H54O38               (O, {u'O': 1.0})
# cluster_Al13H48O40               (O, {u'O': 1.0})
# cluster_Al13H51O41               (O, {u'O': 1.0})
# cluster_Al13H66O48               (O, {u'O': 6.0})
# cluster_Al13H72O48               (O, {u'O': 1.0})
# cluster_Al14H66O48               (O, {u'O': 1.0})
# cluster_Al15H66O48               (O, {u'O': 1.0})
# cluster_Al16H78O58               (O, {u'O': 1.0})
# cluster_Al1H10O5                       (null, {})
# cluster_Al1H12O6                       (null, {})
# cluster_Al20H96O72   (H, {u'H': 1.0, u'Al': 2.0})
# cluster_Al26H132O92  (H, {u'H': 2.0, u'Al': 1.0})
# cluster_Al26H90O78   (H, {u'H': 1.0, u'Al': 2.0})
# cluster_Al2H18O10                      (null, {})
# cluster_Al3H24O14                      (null, {})
# cluster_Al3H27O15                      (null, {})
# cluster_Al4H26O16                      (null, {})
# cluster_Al4H30O18                      (null, {})
# cluster_Al4H30O19                      (null, {})
# cluster_Al5H36O22                      (null, {})
# cluster_Al6H24O18                      (null, {})
# cluster_Al6H32O22                      (null, {})
# cluster_Al6H36O24                      (null, {})
# cluster_Al7H36O24                      (null, {})
# cluster_Al8H42O28                      (null, {})
# cluster_Al8H50O32                      (null, {})

# %%
df = preset.score(methods)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-b0a0c8be8908> in <module>()
# ----> 1 df = preset.score(methods)
#       2 df
#
# /Users/hillarypan/AJResearch/cn_routines/codes/materialscoord/materialscoord/core.py in score(self, methods)
#     249                     hisite = bm[hi[j]]
#     250                     for k in range(len(site)):
# --> 251                         coord = [z for z in hisite[k].values()]
#     252                         if all(isinstance(z, float) for z in coord) or not coord:
#     253                             temp = Counter(site[k])
#
# AttributeError: 'tuple' object has no attribute 'values'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 10))

sns.set(font='Times New Roman')
sns.set(font_scale=1.5)

hm = sns.heatmap(df, annot=True, cmap="BuPu", vmax=10)

ax.set_xticklabels(df.columns.tolist(), rotation=60)
ax.set_yticklabels(df.index.tolist())

plt.savefig('cation_anion.png')
plt.show()
