# %%
import pandas as pd
pd.set_option("display.max_columns",999) # display all columns
pd.set_option("display.max_rows", 999)

from pymatgen.analysis.local_env import BrunnerNN_reciprocal, EconNN, JMolNN, \
                                        MinimumDistanceNN, MinimumOKeeffeNN, MinimumVIRENN, \
                                        VoronoiNN, VoronoiNN_modified, CrystalNN
from materialscoord.core import Benchmark, HumanInterpreter

methods = [BrunnerNN_reciprocal(), EconNN(), JMolNN(), CrystalNN(distance_cutoffs=None, x_diff_weight=None), VoronoiNN(tol=0.5),
           MinimumDistanceNN(), MinimumOKeeffeNN(), MinimumVIRENN(),
           HumanInterpreter()]
structure_groups = ["A2BX4", "ABX3", "ABX4"]

preset = Benchmark.from_preset(preset_name=structure_groups)
preset.benchmark(methods=methods)
# Out:
# /Users/hillarypan/AJResearch/cn_routines/codes/pymatgen/pymatgen/__init__.py:89: UserWarning:
# Pymatgen will drop Py2k support from v2019.1.1. Pls consult the documentation
# at https://www.pymatgen.org for more details.
#   at https://www.pymatgen.org for more details.""")
#                              BrunnerNN_reciprocal0 BrunnerNN_reciprocal1  \
# AlAsO4_33254                           {u'O': 4.0}           {u'O': 4.0}
# BAsO4_highcristobalite_26891           {u'O': 4.0}           {u'O': 4.0}
# BaAl2O4_21080                          {u'O': 9.0}           {u'O': 4.0}
# BaTiO3_67520                          {u'O': 12.0}           {u'O': 6.0}
# BaZnF4_182604                          {u'F': 8.0}           {u'F': 6.0}
# Be2SiO4_phenakite_64942                {u'O': 4.0}           {u'O': 4.0}
# CaB2O4_34641                           {u'O': 8.0}           {u'O': 3.0}
# CaCO3_aragonite_15194                  {u'O': 9.0}           {u'O': 3.0}
# CaCO3_calcite_18164                    {u'O': 6.0}           {u'O': 3.0}
# CaFe2O4_166080                         {u'O': 8.0}           {u'O': 6.0}
# CaWO4_scheelite_15586                  {u'O': 8.0}           {u'O': 4.0}
# CePO4_monazite_79746                   {u'O': 9.0}           {u'O': 4.0}
# CrVO4_27508                            {u'O': 4.0}           {u'O': 6.0}
# Fe2SiO4_olivine_4353                   {u'O': 6.0}           {u'O': 6.0}
# FeTiO3_ilmenite_9805                   {u'O': 6.0}           {u'O': 6.0}
# FeWO4_wolframite_26811                 {u'O': 6.0}           {u'O': 6.0}
# GaPO4_lowcristobalite_97550            {u'O': 4.0}           {u'O': 4.0}
# K2NiF4_73450                           {u'F': 9.0}           {u'F': 6.0}
# K2SO4_beta_2827                       {u'O': 11.0}           {u'O': 9.0}
# MgAl2O4_spinel_31373                   {u'O': 4.0}           {u'O': 6.0}
# MgUO4_24725                            {u'O': 6.0}           {u'O': 6.0}
# MnMoO4_alpha_15615                     {u'O': 6.0}           {u'O': 6.0}
# Na2SO4_thenardite_2895                 {u'O': 6.0}           {u'O': 4.0}
# SbNbO4_20344                           {u'O': 6.0}           {u'O': 5.0}
# Sr2PbO4_16806                          {u'O': 7.0}           {u'O': 6.0}
# SrTiO3_perovskite_80871               {u'O': 12.0}           {u'O': 6.0}
# TlAlF4_202453                          {u'F': 6.0}           {u'F': 8.0}
# ZnSO4_71018                            {u'O': 6.0}           {u'O': 4.0}
# ZrSiO4_zircon_15759                    {u'O': 8.0}           {u'O': 4.0}
#
#                              BrunnerNN_reciprocal2 BrunnerNN_reciprocal3  \
# AlAsO4_33254                                    {}                    {}
# BAsO4_highcristobalite_26891                    {}                    {}
# BaAl2O4_21080                                   {}                    {}
# BaTiO3_67520                                    {}                    {}
# BaZnF4_182604                                   {}                    {}
# Be2SiO4_phenakite_64942                {u'O': 4.0}                    {}
# CaB2O4_34641                                    {}                    {}
# CaCO3_aragonite_15194                           {}                    {}
# CaCO3_calcite_18164                             {}                    {}
# CaFe2O4_166080                         {u'O': 6.0}                    {}
# CaWO4_scheelite_15586                           {}                    {}
# CePO4_monazite_79746                            {}                    {}
# CrVO4_27508                                     {}                    {}
# Fe2SiO4_olivine_4353                   {u'O': 4.0}                    {}
# FeTiO3_ilmenite_9805                            {}                    {}
# FeWO4_wolframite_26811                          {}                    {}
# GaPO4_lowcristobalite_97550                     {}                    {}
# K2NiF4_73450                                    {}                    {}
# K2SO4_beta_2827                        {u'O': 4.0}                    {}
# MgAl2O4_spinel_31373                            {}                    {}
# MgUO4_24725                                     {}                    {}
# MnMoO4_alpha_15615                     {u'O': 4.0}           {u'O': 4.0}
# Na2SO4_thenardite_2895                          {}                    {}
# SbNbO4_20344                                    {}                    {}
# Sr2PbO4_16806                                   {}                    {}
# SrTiO3_perovskite_80871                         {}                    {}
# TlAlF4_202453                                   {}                    {}
# ZnSO4_71018                                     {}                    {}
# ZrSiO4_zircon_15759                             {}                    {}
#
#                                 CrystalNN0   CrystalNN1   CrystalNN2  \
# AlAsO4_33254                   {u'O': 4.0}  {u'O': 4.0}           {}
# BAsO4_highcristobalite_26891   {u'O': 4.0}  {u'O': 4.0}           {}
# BaAl2O4_21080                  {u'O': 9.0}  {u'O': 4.0}           {}
# BaTiO3_67520                  {u'O': 12.0}  {u'O': 6.0}           {}
# BaZnF4_182604                 {u'F': 11.0}  {u'F': 6.0}           {}
# Be2SiO4_phenakite_64942        {u'O': 4.0}  {u'O': 4.0}  {u'O': 4.0}
# CaB2O4_34641                   {u'O': 8.0}  {u'O': 3.0}           {}
# CaCO3_aragonite_15194          {u'O': 9.0}  {u'O': 3.0}           {}
# CaCO3_calcite_18164            {u'O': 6.0}  {u'O': 3.0}           {}
# CaFe2O4_166080                 {u'O': 8.0}  {u'O': 6.0}  {u'O': 6.0}
# CaWO4_scheelite_15586          {u'O': 8.0}  {u'O': 4.0}           {}
# CePO4_monazite_79746           {u'O': 9.0}  {u'O': 4.0}           {}
# CrVO4_27508                    {u'O': 4.0}  {u'O': 6.0}           {}
# Fe2SiO4_olivine_4353           {u'O': 6.0}  {u'O': 6.0}  {u'O': 4.0}
# FeTiO3_ilmenite_9805           {u'O': 6.0}  {u'O': 6.0}           {}
# FeWO4_wolframite_26811         {u'O': 6.0}  {u'O': 6.0}           {}
# GaPO4_lowcristobalite_97550    {u'O': 4.0}  {u'O': 4.0}           {}
# K2NiF4_73450                   {u'F': 9.0}  {u'F': 6.0}           {}
# K2SO4_beta_2827               {u'O': 10.0}  {u'O': 9.0}  {u'O': 4.0}
# MgAl2O4_spinel_31373           {u'O': 4.0}  {u'O': 6.0}           {}
# MgUO4_24725                    {u'O': 6.0}  {u'O': 6.0}           {}
# MnMoO4_alpha_15615             {u'O': 6.0}  {u'O': 6.0}  {u'O': 4.0}
# Na2SO4_thenardite_2895         {u'O': 6.0}  {u'O': 4.0}           {}
# SbNbO4_20344                   {u'O': 6.0}  {u'O': 5.0}           {}
# Sr2PbO4_16806                  {u'O': 7.0}  {u'O': 6.0}           {}
# SrTiO3_perovskite_80871       {u'O': 12.0}  {u'O': 6.0}           {}
# TlAlF4_202453                  {u'F': 6.0}  {u'F': 8.0}           {}
# ZnSO4_71018                    {u'O': 6.0}  {u'O': 4.0}           {}
# ZrSiO4_zircon_15759            {u'O': 8.0}  {u'O': 4.0}           {}
#
#                                CrystalNN3       EconNN0       EconNN1  \
# AlAsO4_33254                           {}   {u'O': 4.0}   {u'O': 4.0}
# BAsO4_highcristobalite_26891           {}   {u'O': 4.0}   {u'O': 4.0}
# BaAl2O4_21080                          {}  {u'O': 15.0}   {u'O': 4.0}
# BaTiO3_67520                           {}  {u'O': 12.0}   {u'O': 6.0}
# BaZnF4_182604                          {}  {u'F': 13.0}   {u'F': 6.0}
# Be2SiO4_phenakite_64942                {}   {u'O': 4.0}   {u'O': 4.0}
# CaB2O4_34641                           {}   {u'O': 8.0}   {u'O': 3.0}
# CaCO3_aragonite_15194                  {}   {u'O': 9.0}   {u'O': 3.0}
# CaCO3_calcite_18164                    {}  {u'O': 12.0}   {u'O': 3.0}
# CaFe2O4_166080                         {}   {u'O': 9.0}   {u'O': 6.0}
# CaWO4_scheelite_15586                  {}   {u'O': 8.0}   {u'O': 4.0}
# CePO4_monazite_79746                   {}  {u'O': 10.0}   {u'O': 4.0}
# CrVO4_27508                            {}   {u'O': 4.0}   {u'O': 6.0}
# Fe2SiO4_olivine_4353                   {}   {u'O': 6.0}   {u'O': 6.0}
# FeTiO3_ilmenite_9805                   {}   {u'O': 6.0}   {u'O': 6.0}
# FeWO4_wolframite_26811                 {}   {u'O': 6.0}   {u'O': 6.0}
# GaPO4_lowcristobalite_97550            {}   {u'O': 4.0}   {u'O': 4.0}
# K2NiF4_73450                           {}   {u'F': 9.0}   {u'F': 6.0}
# K2SO4_beta_2827                        {}  {u'O': 13.0}   {u'O': 9.0}
# MgAl2O4_spinel_31373                   {}   {u'O': 4.0}   {u'O': 6.0}
# MgUO4_24725                            {}   {u'O': 6.0}   {u'O': 6.0}
# MnMoO4_alpha_15615            {u'O': 4.0}   {u'O': 6.0}   {u'O': 6.0}
# Na2SO4_thenardite_2895                 {}   {u'O': 8.0}   {u'O': 4.0}
# SbNbO4_20344                           {}   {u'O': 6.0}   {u'O': 5.0}
# Sr2PbO4_16806                          {}   {u'O': 7.0}   {u'O': 6.0}
# SrTiO3_perovskite_80871                {}  {u'O': 12.0}   {u'O': 6.0}
# TlAlF4_202453                          {}   {u'F': 6.0}  {u'F': 16.0}
# ZnSO4_71018                            {}   {u'O': 6.0}   {u'O': 4.0}
# ZrSiO4_zircon_15759                    {}   {u'O': 8.0}   {u'O': 4.0}
#
#                                   EconNN2      EconNN3 HumanInterpreter0  \
# AlAsO4_33254                           {}           {}       {u'O': 4.0}
# BAsO4_highcristobalite_26891           {}           {}       {u'O': 4.0}
# BaAl2O4_21080                          {}           {}       {u'O': 9.0}
# BaTiO3_67520                           {}           {}      {u'O': 12.0}
# BaZnF4_182604                          {}           {}      {u'F': 11.0}
# Be2SiO4_phenakite_64942       {u'O': 4.0}           {}       {u'O': 4.0}
# CaB2O4_34641                           {}           {}       {u'O': 8.0}
# CaCO3_aragonite_15194                  {}           {}       {u'O': 9.0}
# CaCO3_calcite_18164                    {}           {}       {u'O': 6.0}
# CaFe2O4_166080                {u'O': 6.0}           {}       {u'O': 8.0}
# CaWO4_scheelite_15586                  {}           {}       {u'O': 8.0}
# CePO4_monazite_79746                   {}           {}       {u'O': 9.0}
# CrVO4_27508                            {}           {}       {u'O': 4.0}
# Fe2SiO4_olivine_4353          {u'O': 4.0}           {}       {u'O': 6.0}
# FeTiO3_ilmenite_9805                   {}           {}       {u'O': 6.0}
# FeWO4_wolframite_26811                 {}           {}       {u'O': 6.0}
# GaPO4_lowcristobalite_97550            {}           {}       {u'O': 4.0}
# K2NiF4_73450                           {}           {}       {u'F': 9.0}
# K2SO4_beta_2827               {u'O': 4.0}           {}      {u'O': 11.0}
# MgAl2O4_spinel_31373                   {}           {}       {u'O': 4.0}
# MgUO4_24725                            {}           {}       {u'O': 6.0}
# MnMoO4_alpha_15615            {u'O': 4.0}  {u'O': 4.0}       {u'O': 6.0}
# Na2SO4_thenardite_2895                 {}           {}       {u'O': 6.0}
# SbNbO4_20344                           {}           {}       {u'O': 6.0}
# Sr2PbO4_16806                          {}           {}       {u'O': 7.0}
# SrTiO3_perovskite_80871                {}           {}      {u'O': 12.0}
# TlAlF4_202453                          {}           {}       {u'F': 6.0}
# ZnSO4_71018                            {}           {}       {u'O': 6.0}
# ZrSiO4_zircon_15759                    {}           {}       {u'O': 8.0}
#
#                              HumanInterpreter1 HumanInterpreter2  \
# AlAsO4_33254                       {u'O': 4.0}                {}
# BAsO4_highcristobalite_26891       {u'O': 4.0}                {}
# BaAl2O4_21080                      {u'O': 4.0}                {}
# BaTiO3_67520                       {u'O': 6.0}                {}
# BaZnF4_182604                      {u'F': 6.0}                {}
# Be2SiO4_phenakite_64942            {u'O': 4.0}       {u'O': 4.0}
# CaB2O4_34641                       {u'O': 3.0}                {}
# CaCO3_aragonite_15194              {u'O': 3.0}                {}
# CaCO3_calcite_18164                {u'O': 3.0}                {}
# CaFe2O4_166080                     {u'O': 6.0}       {u'O': 6.0}
# CaWO4_scheelite_15586              {u'O': 4.0}                {}
# CePO4_monazite_79746               {u'O': 4.0}                {}
# CrVO4_27508                        {u'O': 6.0}                {}
# Fe2SiO4_olivine_4353               {u'O': 6.0}       {u'O': 4.0}
# FeTiO3_ilmenite_9805               {u'O': 6.0}                {}
# FeWO4_wolframite_26811             {u'O': 6.0}                {}
# GaPO4_lowcristobalite_97550        {u'O': 4.0}                {}
# K2NiF4_73450                       {u'F': 6.0}                {}
# K2SO4_beta_2827                    {u'O': 9.0}       {u'O': 4.0}
# MgAl2O4_spinel_31373               {u'O': 6.0}                {}
# MgUO4_24725                        {u'O': 6.0}                {}
# MnMoO4_alpha_15615                 {u'O': 6.0}       {u'O': 4.0}
# Na2SO4_thenardite_2895             {u'O': 4.0}                {}
# SbNbO4_20344                       {u'O': 6.0}                {}
# Sr2PbO4_16806                      {u'O': 6.0}                {}
# SrTiO3_perovskite_80871            {u'O': 6.0}                {}
# TlAlF4_202453                      {u'F': 8.0}                {}
# ZnSO4_71018                        {u'O': 4.0}                {}
# ZrSiO4_zircon_15759                {u'O': 4.0}                {}
#
#                              HumanInterpreter3      JMolNN0      JMolNN1  \
# AlAsO4_33254                                {}  {u'O': 4.0}  {u'O': 4.0}
# BAsO4_highcristobalite_26891                {}  {u'O': 4.0}  {u'O': 4.0}
# BaAl2O4_21080                               {}           {}  {u'O': 4.0}
# BaTiO3_67520                                {}           {}  {u'O': 6.0}
# BaZnF4_182604                               {}           {}  {u'F': 6.0}
# Be2SiO4_phenakite_64942                     {}           {}           {}
# CaB2O4_34641                                {}           {}  {u'O': 3.0}
# CaCO3_aragonite_15194                       {}           {}  {u'O': 3.0}
# CaCO3_calcite_18164                         {}           {}  {u'O': 3.0}
# CaFe2O4_166080                              {}  {u'O': 5.0}  {u'O': 6.0}
# CaWO4_scheelite_15586                       {}           {}  {u'O': 4.0}
# CePO4_monazite_79746                        {}  {u'O': 9.0}  {u'O': 4.0}
# CrVO4_27508                                 {}  {u'O': 4.0}  {u'O': 6.0}
# Fe2SiO4_olivine_4353                        {}  {u'O': 6.0}  {u'O': 6.0}
# FeTiO3_ilmenite_9805                        {}  {u'O': 6.0}  {u'O': 6.0}
# FeWO4_wolframite_26811                      {}  {u'O': 6.0}  {u'O': 6.0}
# GaPO4_lowcristobalite_97550                 {}  {u'O': 4.0}  {u'O': 4.0}
# K2NiF4_73450                                {}           {}  {u'F': 6.0}
# K2SO4_beta_2827                             {}           {}           {}
# MgAl2O4_spinel_31373                        {}  {u'O': 4.0}  {u'O': 6.0}
# MgUO4_24725                                 {}  {u'O': 6.0}  {u'O': 6.0}
# MnMoO4_alpha_15615                 {u'O': 4.0}  {u'O': 6.0}  {u'O': 6.0}
# Na2SO4_thenardite_2895                      {}           {}  {u'O': 4.0}
# SbNbO4_20344                                {}  {u'O': 6.0}  {u'O': 5.0}
# Sr2PbO4_16806                               {}           {}  {u'O': 6.0}
# SrTiO3_perovskite_80871                     {}           {}  {u'O': 6.0}
# TlAlF4_202453                               {}  {u'F': 6.0}           {}
# ZnSO4_71018                                 {}  {u'O': 6.0}  {u'O': 4.0}
# ZrSiO4_zircon_15759                         {}  {u'O': 8.0}  {u'O': 4.0}
#
#                                   JMolNN2      JMolNN3 MinimumDistanceNN0  \
# AlAsO4_33254                           {}           {}        {u'O': 4.0}
# BAsO4_highcristobalite_26891           {}           {}        {u'O': 4.0}
# BaAl2O4_21080                          {}           {}        {u'O': 9.0}
# BaTiO3_67520                           {}           {}       {u'O': 12.0}
# BaZnF4_182604                          {}           {}        {u'F': 8.0}
# Be2SiO4_phenakite_64942       {u'O': 4.0}           {}        {u'O': 4.0}
# CaB2O4_34641                           {}           {}        {u'O': 6.0}
# CaCO3_aragonite_15194                  {}           {}        {u'O': 9.0}
# CaCO3_calcite_18164                    {}           {}        {u'O': 6.0}
# CaFe2O4_166080                {u'O': 6.0}           {}        {u'O': 8.0}
# CaWO4_scheelite_15586                  {}           {}        {u'O': 8.0}
# CePO4_monazite_79746                   {}           {}        {u'O': 8.0}
# CrVO4_27508                            {}           {}        {u'O': 4.0}
# Fe2SiO4_olivine_4353          {u'O': 4.0}           {}        {u'O': 6.0}
# FeTiO3_ilmenite_9805                   {}           {}        {u'O': 3.0}
# FeWO4_wolframite_26811                 {}           {}        {u'O': 6.0}
# GaPO4_lowcristobalite_97550            {}           {}        {u'O': 4.0}
# K2NiF4_73450                           {}           {}        {u'F': 9.0}
# K2SO4_beta_2827               {u'O': 4.0}           {}        {u'O': 5.0}
# MgAl2O4_spinel_31373                   {}           {}        {u'O': 4.0}
# MgUO4_24725                            {}           {}        {u'O': 2.0}
# MnMoO4_alpha_15615            {u'O': 4.0}  {u'O': 4.0}        {u'O': 6.0}
# Na2SO4_thenardite_2895                 {}           {}        {u'O': 6.0}
# SbNbO4_20344                           {}           {}        {u'O': 3.0}
# Sr2PbO4_16806                          {}           {}        {u'O': 6.0}
# SrTiO3_perovskite_80871                {}           {}       {u'O': 12.0}
# TlAlF4_202453                          {}           {}        {u'F': 6.0}
# ZnSO4_71018                            {}           {}        {u'O': 4.0}
# ZrSiO4_zircon_15759                    {}           {}        {u'O': 8.0}
#
#                              MinimumDistanceNN1 MinimumDistanceNN2  \
# AlAsO4_33254                        {u'O': 4.0}                 {}
# BAsO4_highcristobalite_26891        {u'O': 4.0}                 {}
# BaAl2O4_21080                       {u'O': 4.0}                 {}
# BaTiO3_67520                        {u'O': 5.0}                 {}
# BaZnF4_182604                       {u'F': 4.0}                 {}
# Be2SiO4_phenakite_64942             {u'O': 4.0}        {u'O': 4.0}
# CaB2O4_34641                        {u'O': 3.0}                 {}
# CaCO3_aragonite_15194               {u'O': 3.0}                 {}
# CaCO3_calcite_18164                 {u'O': 3.0}                 {}
# CaFe2O4_166080                      {u'O': 6.0}        {u'O': 6.0}
# CaWO4_scheelite_15586               {u'O': 4.0}                 {}
# CePO4_monazite_79746                {u'O': 4.0}                 {}
# CrVO4_27508                         {u'O': 6.0}                 {}
# Fe2SiO4_olivine_4353                {u'O': 4.0}        {u'O': 4.0}
# FeTiO3_ilmenite_9805                {u'O': 6.0}                 {}
# FeWO4_wolframite_26811              {u'O': 4.0}                 {}
# GaPO4_lowcristobalite_97550         {u'O': 4.0}                 {}
# K2NiF4_73450                        {u'F': 6.0}                 {}
# K2SO4_beta_2827                     {u'O': 7.0}        {u'O': 4.0}
# MgAl2O4_spinel_31373                {u'O': 6.0}                 {}
# MgUO4_24725                         {u'O': 2.0}                 {}
# MnMoO4_alpha_15615                  {u'O': 6.0}        {u'O': 4.0}
# Na2SO4_thenardite_2895              {u'O': 4.0}                 {}
# SbNbO4_20344                        {u'O': 3.0}                 {}
# Sr2PbO4_16806                       {u'O': 6.0}                 {}
# SrTiO3_perovskite_80871             {u'O': 6.0}                 {}
# TlAlF4_202453                       {u'F': 8.0}                 {}
# ZnSO4_71018                         {u'O': 4.0}                 {}
# ZrSiO4_zircon_15759                 {u'O': 4.0}                 {}
#
#                              MinimumDistanceNN3 MinimumOKeeffeNN0  \
# AlAsO4_33254                                 {}       {u'O': 4.0}
# BAsO4_highcristobalite_26891                 {}       {u'O': 4.0}
# BaAl2O4_21080                                {}       {u'O': 6.0}
# BaTiO3_67520                                 {}                {}
# BaZnF4_182604                                {}       {u'F': 4.0}
# Be2SiO4_phenakite_64942                      {}       {u'O': 4.0}
# CaB2O4_34641                                 {}       {u'O': 6.0}
# CaCO3_aragonite_15194                        {}       {u'O': 9.0}
# CaCO3_calcite_18164                          {}       {u'O': 6.0}
# CaFe2O4_166080                               {}                {}
# CaWO4_scheelite_15586                        {}       {u'O': 8.0}
# CePO4_monazite_79746                         {}       {u'O': 8.0}
# CrVO4_27508                                  {}       {u'O': 4.0}
# Fe2SiO4_olivine_4353                         {}       {u'O': 6.0}
# FeTiO3_ilmenite_9805                         {}       {u'O': 3.0}
# FeWO4_wolframite_26811                       {}       {u'O': 6.0}
# GaPO4_lowcristobalite_97550                  {}       {u'O': 4.0}
# K2NiF4_73450                                 {}                {}
# K2SO4_beta_2827                              {}                {}
# MgAl2O4_spinel_31373                         {}       {u'O': 4.0}
# MgUO4_24725                                  {}       {u'O': 2.0}
# MnMoO4_alpha_15615                  {u'O': 4.0}       {u'O': 6.0}
# Na2SO4_thenardite_2895                       {}       {u'O': 2.0}
# SbNbO4_20344                                 {}       {u'O': 3.0}
# Sr2PbO4_16806                                {}                {}
# SrTiO3_perovskite_80871                      {}                {}
# TlAlF4_202453                                {}       {u'F': 6.0}
# ZnSO4_71018                                  {}       {u'O': 4.0}
# ZrSiO4_zircon_15759                          {}       {u'O': 8.0}
#
#                              MinimumOKeeffeNN1 MinimumOKeeffeNN2  \
# AlAsO4_33254                       {u'O': 4.0}                {}
# BAsO4_highcristobalite_26891       {u'O': 4.0}                {}
# BaAl2O4_21080                      {u'O': 4.0}                {}
# BaTiO3_67520                       {u'O': 5.0}                {}
# BaZnF4_182604                      {u'F': 4.0}                {}
# Be2SiO4_phenakite_64942            {u'O': 4.0}       {u'O': 4.0}
# CaB2O4_34641                       {u'O': 3.0}                {}
# CaCO3_aragonite_15194              {u'O': 3.0}                {}
# CaCO3_calcite_18164                {u'O': 3.0}                {}
# CaFe2O4_166080                     {u'O': 6.0}       {u'O': 6.0}
# CaWO4_scheelite_15586              {u'O': 4.0}                {}
# CePO4_monazite_79746               {u'O': 4.0}                {}
# CrVO4_27508                        {u'O': 6.0}                {}
# Fe2SiO4_olivine_4353               {u'O': 4.0}       {u'O': 4.0}
# FeTiO3_ilmenite_9805               {u'O': 6.0}                {}
# FeWO4_wolframite_26811             {u'O': 4.0}                {}
# GaPO4_lowcristobalite_97550        {u'O': 4.0}                {}
# K2NiF4_73450                       {u'F': 6.0}                {}
# K2SO4_beta_2827                             {}       {u'O': 4.0}
# MgAl2O4_spinel_31373               {u'O': 6.0}                {}
# MgUO4_24725                        {u'O': 2.0}                {}
# MnMoO4_alpha_15615                 {u'O': 6.0}       {u'O': 4.0}
# Na2SO4_thenardite_2895             {u'O': 4.0}                {}
# SbNbO4_20344                       {u'O': 3.0}                {}
# Sr2PbO4_16806                      {u'O': 6.0}                {}
# SrTiO3_perovskite_80871            {u'O': 6.0}                {}
# TlAlF4_202453                               {}                {}
# ZnSO4_71018                        {u'O': 4.0}                {}
# ZrSiO4_zircon_15759                {u'O': 4.0}                {}
#
#                              MinimumOKeeffeNN3 MinimumVIRENN0 MinimumVIRENN1  \
# AlAsO4_33254                                {}    {u'O': 4.0}    {u'O': 4.0}
# BAsO4_highcristobalite_26891                {}    {u'O': 4.0}    {u'O': 4.0}
# BaAl2O4_21080                               {}    {u'O': 9.0}    {u'O': 4.0}
# BaTiO3_67520                                {}   {u'O': 12.0}    {u'O': 5.0}
# BaZnF4_182604                               {}    {u'F': 8.0}    {u'F': 4.0}
# Be2SiO4_phenakite_64942                     {}    {u'O': 4.0}    {u'O': 4.0}
# CaB2O4_34641                                {}    {u'O': 6.0}    {u'O': 3.0}
# CaCO3_aragonite_15194                       {}    {u'O': 9.0}    {u'O': 3.0}
# CaCO3_calcite_18164                         {}    {u'O': 6.0}    {u'O': 3.0}
# CaFe2O4_166080                              {}    {u'O': 8.0}    {u'O': 6.0}
# CaWO4_scheelite_15586                       {}    {u'O': 8.0}    {u'O': 4.0}
# CePO4_monazite_79746                        {}    {u'O': 8.0}    {u'O': 4.0}
# CrVO4_27508                                 {}    {u'O': 4.0}    {u'O': 6.0}
# Fe2SiO4_olivine_4353                        {}    {u'O': 6.0}    {u'O': 4.0}
# FeTiO3_ilmenite_9805                        {}    {u'O': 3.0}    {u'O': 6.0}
# FeWO4_wolframite_26811                      {}    {u'O': 6.0}    {u'O': 4.0}
# GaPO4_lowcristobalite_97550                 {}    {u'O': 4.0}    {u'O': 4.0}
# K2NiF4_73450                                {}    {u'F': 9.0}    {u'F': 6.0}
# K2SO4_beta_2827                             {}    {u'O': 5.0}    {u'O': 7.0}
# MgAl2O4_spinel_31373                        {}    {u'O': 4.0}    {u'O': 6.0}
# MgUO4_24725                                 {}    {u'O': 2.0}    {u'O': 2.0}
# MnMoO4_alpha_15615                 {u'O': 4.0}    {u'O': 6.0}    {u'O': 6.0}
# Na2SO4_thenardite_2895                      {}    {u'O': 6.0}    {u'O': 4.0}
# SbNbO4_20344                                {}    {u'O': 3.0}    {u'O': 3.0}
# Sr2PbO4_16806                               {}    {u'O': 6.0}    {u'O': 6.0}
# SrTiO3_perovskite_80871                     {}   {u'O': 12.0}    {u'O': 6.0}
# TlAlF4_202453                               {}    {u'F': 6.0}    {u'F': 8.0}
# ZnSO4_71018                                 {}    {u'O': 4.0}    {u'O': 4.0}
# ZrSiO4_zircon_15759                         {}    {u'O': 8.0}    {u'O': 4.0}
#
#                              MinimumVIRENN2 MinimumVIRENN3    VoronoiNN0  \
# AlAsO4_33254                             {}             {}   {u'O': 4.0}
# BAsO4_highcristobalite_26891             {}             {}   {u'O': 4.0}
# BaAl2O4_21080                            {}             {}   {u'O': 9.0}
# BaTiO3_67520                             {}             {}  {u'O': 12.0}
# BaZnF4_182604                            {}             {}   {u'F': 9.0}
# Be2SiO4_phenakite_64942         {u'O': 4.0}             {}   {u'O': 4.0}
# CaB2O4_34641                             {}             {}   {u'O': 8.0}
# CaCO3_aragonite_15194                    {}             {}   {u'O': 9.0}
# CaCO3_calcite_18164                      {}             {}   {u'O': 6.0}
# CaFe2O4_166080                  {u'O': 6.0}             {}   {u'O': 8.0}
# CaWO4_scheelite_15586                    {}             {}   {u'O': 8.0}
# CePO4_monazite_79746                     {}             {}   {u'O': 9.0}
# CrVO4_27508                              {}             {}   {u'O': 4.0}
# Fe2SiO4_olivine_4353            {u'O': 4.0}             {}   {u'O': 6.0}
# FeTiO3_ilmenite_9805                     {}             {}   {u'O': 6.0}
# FeWO4_wolframite_26811                   {}             {}   {u'O': 6.0}
# GaPO4_lowcristobalite_97550              {}             {}   {u'O': 4.0}
# K2NiF4_73450                             {}             {}   {u'F': 9.0}
# K2SO4_beta_2827                 {u'O': 4.0}             {}   {u'O': 9.0}
# MgAl2O4_spinel_31373                     {}             {}   {u'O': 4.0}
# MgUO4_24725                              {}             {}   {u'O': 6.0}
# MnMoO4_alpha_15615              {u'O': 4.0}    {u'O': 4.0}   {u'O': 6.0}
# Na2SO4_thenardite_2895                   {}             {}   {u'O': 6.0}
# SbNbO4_20344                             {}             {}   {u'O': 6.0}
# Sr2PbO4_16806                            {}             {}   {u'O': 7.0}
# SrTiO3_perovskite_80871                  {}             {}  {u'O': 12.0}
# TlAlF4_202453                            {}             {}   {u'F': 6.0}
# ZnSO4_71018                              {}             {}   {u'O': 6.0}
# ZrSiO4_zircon_15759                      {}             {}   {u'O': 8.0}
#
#                                VoronoiNN1   VoronoiNN2   VoronoiNN3
# AlAsO4_33254                  {u'O': 4.0}           {}           {}
# BAsO4_highcristobalite_26891  {u'O': 4.0}           {}           {}
# BaAl2O4_21080                 {u'O': 4.0}           {}           {}
# BaTiO3_67520                  {u'O': 6.0}           {}           {}
# BaZnF4_182604                 {u'F': 6.0}           {}           {}
# Be2SiO4_phenakite_64942       {u'O': 4.0}  {u'O': 4.0}           {}
# CaB2O4_34641                  {u'O': 3.0}           {}           {}
# CaCO3_aragonite_15194         {u'O': 3.0}           {}           {}
# CaCO3_calcite_18164           {u'O': 3.0}           {}           {}
# CaFe2O4_166080                {u'O': 6.0}  {u'O': 6.0}           {}
# CaWO4_scheelite_15586         {u'O': 4.0}           {}           {}
# CePO4_monazite_79746          {u'O': 4.0}           {}           {}
# CrVO4_27508                   {u'O': 6.0}           {}           {}
# Fe2SiO4_olivine_4353          {u'O': 6.0}  {u'O': 4.0}           {}
# FeTiO3_ilmenite_9805          {u'O': 6.0}           {}           {}
# FeWO4_wolframite_26811        {u'O': 6.0}           {}           {}
# GaPO4_lowcristobalite_97550   {u'O': 4.0}           {}           {}
# K2NiF4_73450                  {u'F': 6.0}           {}           {}
# K2SO4_beta_2827               {u'O': 9.0}  {u'O': 4.0}           {}
# MgAl2O4_spinel_31373          {u'O': 6.0}           {}           {}
# MgUO4_24725                   {u'O': 6.0}           {}           {}
# MnMoO4_alpha_15615            {u'O': 6.0}  {u'O': 4.0}  {u'O': 4.0}
# Na2SO4_thenardite_2895        {u'O': 4.0}           {}           {}
# SbNbO4_20344                  {u'O': 5.0}           {}           {}
# Sr2PbO4_16806                 {u'O': 6.0}           {}           {}
# SrTiO3_perovskite_80871       {u'O': 6.0}           {}           {}
# TlAlF4_202453                 {u'F': 8.0}           {}           {}
# ZnSO4_71018                   {u'O': 4.0}           {}           {}
# ZrSiO4_zircon_15759           {u'O': 4.0}           {}           {}

# %%
df = preset.score(methods)
df
# Out:
#                               BrunnerNN_reciprocal  CrystalNN  EconNN  JMolNN  \
# AlAsO4_33254                                   0.0      0.000   0.000   0.000
# BAsO4_highcristobalite_26891                   0.0      0.000   0.000   0.000
# BaAl2O4_21080                                  0.0      0.000   2.000   3.000
# BaTiO3_67520                                   0.0      0.000   0.000   6.000
# BaZnF4_182604                                  1.5      0.000   1.000   5.500
# Be2SiO4_phenakite_64942                        0.0      0.000   0.000   2.667
# CaB2O4_34641                                   0.0      0.000   0.000   2.667
# CaCO3_aragonite_15194                          0.0      0.000   0.000   4.500
# CaCO3_calcite_18164                            0.0      0.000   3.000   3.000
# CaFe2O4_166080                                 0.0      0.000   0.333   1.000
# CaWO4_scheelite_15586                          0.0      0.000   0.000   4.000
# CePO4_monazite_79746                           0.0      0.000   0.500   0.000
# CrVO4_27508                                    0.0      0.000   0.000   0.000
# Fe2SiO4_olivine_4353                           0.0      0.000   0.000   0.000
# FeTiO3_ilmenite_9805                           0.0      0.000   0.000   0.000
# FeWO4_wolframite_26811                         0.0      0.000   0.000   0.000
# GaPO4_lowcristobalite_97550                    0.0      0.000   0.000   0.000
# K2NiF4_73450                                   0.0      0.000   0.000   6.000
# K2SO4_beta_2827                                0.0      0.333   0.667   6.667
# MgAl2O4_spinel_31373                           0.0      0.000   0.000   0.000
# MgUO4_24725                                    0.0      0.000   0.000   0.000
# MnMoO4_alpha_15615                             0.0      0.000   0.000   0.000
# Na2SO4_thenardite_2895                         0.0      0.000   1.333   4.000
# SbNbO4_20344                                   0.5      0.500   0.500   0.500
# Sr2PbO4_16806                                  0.0      0.000   0.000   4.667
# SrTiO3_perovskite_80871                        0.0      0.000   0.000   6.000
# TlAlF4_202453                                  0.0      0.000   4.000   4.000
# ZnSO4_71018                                    0.0      0.000   0.000   0.000
# ZrSiO4_zircon_15759                            0.0      0.000   0.000   0.000
# Total                                          2.0      0.833  13.333  64.167
#
#                               MinimumDistanceNN  MinimumOKeeffeNN  \
# AlAsO4_33254                              0.000             0.000
# BAsO4_highcristobalite_26891              0.000             0.000
# BaAl2O4_21080                             0.000             1.000
# BaTiO3_67520                              0.500             6.500
# BaZnF4_182604                             2.500             4.500
# Be2SiO4_phenakite_64942                   0.000             0.000
# CaB2O4_34641                              0.667             0.667
# CaCO3_aragonite_15194                     0.000             0.000
# CaCO3_calcite_18164                       0.000             0.000
# CaFe2O4_166080                            0.000             2.667
# CaWO4_scheelite_15586                     0.000             0.000
# CePO4_monazite_79746                      0.500             0.500
# CrVO4_27508                               0.000             0.000
# Fe2SiO4_olivine_4353                      0.667             0.667
# FeTiO3_ilmenite_9805                      1.500             1.500
# FeWO4_wolframite_26811                    1.000             1.000
# GaPO4_lowcristobalite_97550               0.000             0.000
# K2NiF4_73450                              0.000             6.000
# K2SO4_beta_2827                           2.667             6.667
# MgAl2O4_spinel_31373                      0.000             0.000
# MgUO4_24725                               4.000             4.000
# MnMoO4_alpha_15615                        0.000             0.000
# Na2SO4_thenardite_2895                    0.000             2.667
# SbNbO4_20344                              3.000             3.000
# Sr2PbO4_16806                             0.667             4.667
# SrTiO3_perovskite_80871                   0.000             6.000
# TlAlF4_202453                             0.000             4.000
# ZnSO4_71018                               1.000             1.000
# ZrSiO4_zircon_15759                       0.000             0.000
# Total                                    18.667            57.000
#
#                               MinimumVIRENN  VoronoiNN
# AlAsO4_33254                          0.000      0.000
# BAsO4_highcristobalite_26891          0.000      0.000
# BaAl2O4_21080                         0.000      0.000
# BaTiO3_67520                          0.500      0.000
# BaZnF4_182604                         2.500      1.000
# Be2SiO4_phenakite_64942               0.000      0.000
# CaB2O4_34641                          0.667      0.000
# CaCO3_aragonite_15194                 0.000      0.000
# CaCO3_calcite_18164                   0.000      0.000
# CaFe2O4_166080                        0.000      0.000
# CaWO4_scheelite_15586                 0.000      0.000
# CePO4_monazite_79746                  0.500      0.000
# CrVO4_27508                           0.000      0.000
# Fe2SiO4_olivine_4353                  0.667      0.000
# FeTiO3_ilmenite_9805                  1.500      0.000
# FeWO4_wolframite_26811                1.000      0.000
# GaPO4_lowcristobalite_97550           0.000      0.000
# K2NiF4_73450                          0.000      0.000
# K2SO4_beta_2827                       2.667      0.667
# MgAl2O4_spinel_31373                  0.000      0.000
# MgUO4_24725                           4.000      0.000
# MnMoO4_alpha_15615                    0.000      0.000
# Na2SO4_thenardite_2895                0.000      0.000
# SbNbO4_20344                          3.000      0.500
# Sr2PbO4_16806                         0.667      0.000
# SrTiO3_perovskite_80871               0.000      0.000
# TlAlF4_202453                         0.000      0.000
# ZnSO4_71018                           1.000      0.000
# ZrSiO4_zircon_15759                   0.000      0.000
# Total                                18.667      2.167

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 10))

sns.set(font='Times New Roman')
sns.set(font_scale=1.5)

hm = sns.heatmap(df, annot=True, cmap="BuPu", vmax=10)

ax.set_xticklabels(df.columns.tolist(), rotation=60)
ax.set_yticklabels(df.index.tolist())

plt.savefig('cation_anion.png')
plt.show()
