# %%
import pandas as pd
pd.set_option("display.max_columns",999) # display all columns
pd.set_option("display.max_rows", 999)

from pymatgen.analysis.local_env import BrunnerNN_reciprocal, BrunnerNN_relative, BrunnerNN_real, EconNN, JMolNN, \
                                        MinimumDistanceNN, MinimumOKeeffeNN, MinimumVIRENN, \
                                        VoronoiNN, VoronoiNN_modified, CrystalNN
from materialscoord.core import Benchmark, HumanInterpreter, NbFuncs

methods = [BrunnerNN_reciprocal(), BrunnerNN_relative(), BrunnerNN_real(), 
           EconNN(), JMolNN(), MinimumDistanceNN(), MinimumOKeeffeNN(), 
           VoronoiNN(), VoronoiNN_modified(), CrystalNN(), HumanInterpreter()]
structure_groups = ["laves"]
bm = Benchmark(methods=methods, structure_groups=structure_groups, unique_sites=True,
               use_weights=False, cation_anion=True, anion_cation=False)
bm.benchmark()
# Out:
# /Users/hillarypan/AJResearch/cn_routines/codes/pymatgen/pymatgen/__init__.py:87: UserWarning:
# Pymatgen will drop Py2k support from v2019.1.1. Pls consult the documentation
# at https://www.pymatgen.org for more details.
#   at https://www.pymatgen.org for more details.""")
# Initialization successful.

# %%
report = bm.report()
report
# Out:
#                    BrunnerNN_real0 BrunnerNN_real1      BrunnerNN_reciprocal0  \
# MgCu2_laves_46007    {u'Cu': 12.0}    {u'Cu': 6.0}  {u'Mg': 4.0, u'Cu': 12.0}
# MgNi2_laves_104838    {u'Ni': 3.0}    {u'Ni': 5.0}  {u'Ni': 12.0, u'Mg': 4.0}
# MgZn2_laves_46006    {u'Zn': 12.0}    {u'Zn': 6.0}  {u'Mg': 4.0, u'Zn': 12.0}
#
#                         BrunnerNN_reciprocal1 BrunnerNN_relative0  \
# MgCu2_laves_46007    {u'Mg': 6.0, u'Cu': 6.0}       {u'Cu': 12.0}
# MgNi2_laves_104838  {u'Ni': 12.0, u'Mg': 4.0}        {u'Ni': 3.0}
# MgZn2_laves_46006    {u'Mg': 6.0, u'Zn': 6.0}       {u'Zn': 12.0}
#
#                    BrunnerNN_relative1                 CrystalNN0  \
# MgCu2_laves_46007         {u'Cu': 6.0}              {u'Cu': 12.0}
# MgNi2_laves_104838        {u'Ni': 5.0}              {u'Ni': 12.0}
# MgZn2_laves_46006         {u'Zn': 6.0}  {u'Zn': 12.0, u'Mg': 4.0}
#
#                                   CrystalNN1                    EconNN0  \
# MgCu2_laves_46007   {u'Mg': 6.0, u'Cu': 6.0}  {u'Mg': 4.0, u'Cu': 12.0}
# MgNi2_laves_104838             {u'Ni': 12.0}  {u'Ni': 12.0, u'Mg': 4.0}
# MgZn2_laves_46006   {u'Mg': 6.0, u'Zn': 6.0}  {u'Mg': 4.0, u'Zn': 12.0}
#
#                                       EconNN1          HumanInterpreter0  \
# MgCu2_laves_46007    {u'Mg': 6.0, u'Cu': 6.0}  {u'Mg': 4.0, u'Cu': 12.0}
# MgNi2_laves_104838  {u'Ni': 12.0, u'Mg': 4.0}  {u'Ni': 12.0, u'Mg': 4.0}
# MgZn2_laves_46006    {u'Mg': 6.0, u'Zn': 6.0}  {u'Mg': 4.0, u'Zn': 12.0}
#
#                             HumanInterpreter1        JMolNN0  \
# MgCu2_laves_46007    {u'Mg': 6.0, u'Cu': 6.0}  {u'Cu': 12.0}
# MgNi2_laves_104838  {u'Ni': 12.0, u'Mg': 4.0}  {u'Ni': 12.0}
# MgZn2_laves_46006    {u'Mg': 6.0, u'Zn': 6.0}  {u'Zn': 12.0}
#
#                                      JMolNN1         MinimumDistanceNN0  \
# MgCu2_laves_46007   {u'Mg': 6.0, u'Cu': 6.0}  {u'Mg': 4.0, u'Cu': 12.0}
# MgNi2_laves_104838             {u'Ni': 12.0}  {u'Ni': 12.0, u'Mg': 4.0}
# MgZn2_laves_46006   {u'Mg': 6.0, u'Zn': 6.0}  {u'Mg': 4.0, u'Zn': 12.0}
#
#                            MinimumDistanceNN1          MinimumOKeeffeNN0  \
# MgCu2_laves_46007                {u'Cu': 6.0}               {u'Mg': 4.0}
# MgNi2_laves_104838  {u'Ni': 12.0, u'Mg': 4.0}  {u'Ni': 12.0, u'Mg': 4.0}
# MgZn2_laves_46006                {u'Zn': 6.0}  {u'Mg': 4.0, u'Zn': 12.0}
#
#                             MinimumOKeeffeNN1                 VoronoiNN0  \
# MgCu2_laves_46007    {u'Mg': 6.0, u'Cu': 6.0}  {u'Mg': 4.0, u'Cu': 12.0}
# MgNi2_laves_104838  {u'Ni': 12.0, u'Mg': 4.0}  {u'Ni': 12.0, u'Mg': 4.0}
# MgZn2_laves_46006    {u'Mg': 6.0, u'Zn': 6.0}  {u'Zn': 12.0, u'Mg': 4.0}
#
#                                    VoronoiNN1        VoronoiNN_modified0  \
# MgCu2_laves_46007    {u'Mg': 6.0, u'Cu': 6.0}  {u'Mg': 4.0, u'Cu': 12.0}
# MgNi2_laves_104838  {u'Ni': 12.0, u'Mg': 4.0}  {u'Ni': 12.0, u'Mg': 4.0}
# MgZn2_laves_46006    {u'Zn': 6.0, u'Mg': 6.0}  {u'Zn': 12.0, u'Mg': 4.0}
#
#                           VoronoiNN_modified1
# MgCu2_laves_46007    {u'Mg': 6.0, u'Cu': 6.0}
# MgNi2_laves_104838  {u'Ni': 12.0, u'Mg': 4.0}
# MgZn2_laves_46006    {u'Zn': 6.0, u'Mg': 6.0}

# %%
nbf = NbFuncs(bm)
df = nbf.final()
df
# Out:
#                     BrunnerNN_real  BrunnerNN_reciprocal  BrunnerNN_relative  \
# MgCu2_laves_46007            0.000                   0.0               0.000
# MgNi2_laves_104838           1.333                   0.0               1.333
# MgZn2_laves_46006            2.333                   0.0               2.333
# Total                        3.667                   0.0               3.667
#
#                     CrystalNN  EconNN  JMolNN  MinimumDistanceNN  \
# MgCu2_laves_46007       0.000     0.0   0.000                0.0
# MgNi2_laves_104838      1.333     0.0   1.333                0.0
# MgZn2_laves_46006       0.000     0.0   1.333                0.0
# Total                   1.333     0.0   2.667                0.0
#
#                     MinimumOKeeffeNN  VoronoiNN  VoronoiNN_modified
# MgCu2_laves_46007                4.0        0.0                 0.0
# MgNi2_laves_104838               0.0        0.0                 0.0
# MgZn2_laves_46006                0.0        0.0                 0.0
# Total                            4.0        0.0                 0.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 5))

sns.set(font='Times New Roman')
sns.set(font_scale=1)

hm = sns.heatmap(df, annot=True, cmap="BuPu", vmax=10)

ax.set_xticklabels(df.columns.tolist(), rotation=45)
ax.set_yticklabels(df.index.tolist())

plt.savefig('laves.png')
plt.show()
