# %%
import pandas as pd
pd.set_option("display.max_columns",999) # display all columns
pd.set_option("display.max_rows", 999)

from pymatgen.analysis.local_env import BrunnerNN_reciprocal, BrunnerNN_relative, BrunnerNN_real, EconNN, JMolNN, \
                                        MinimumDistanceNN, MinimumOKeeffeNN, MinimumVIRENN, \
                                        VoronoiNN, VoronoiNN_modified, CrystalNN
from materialscoord.core import Benchmark, HumanInterpreter, NbFuncs

methods = [BrunnerNN_reciprocal(), EconNN(), JMolNN(), MinimumDistanceNN(), MinimumOKeeffeNN(), 
           VoronoiNN(tol=0.5), CrystalNN(), HumanInterpreter()]
#structure_groups = ["A2BX4", "ABX3", "ABX4"]
structure_groups = ["A2BX4"]
bm = Benchmark(methods=methods, structure_groups=structure_groups, unique_sites=True,
               use_weights=False, cation_anion=True, anion_cation=False)
bm.benchmark()
# Out:
# /Users/hillarypan/AJResearch/cn_routines/codes/pymatgen/pymatgen/__init__.py:89: UserWarning:
# Pymatgen will drop Py2k support from v2019.1.1. Pls consult the documentation
# at https://www.pymatgen.org for more details.
#   at https://www.pymatgen.org for more details.""")
# Initialization successful.

# %%
report = bm.report()
report
# Out:
#                         BrunnerNN_reciprocal0 BrunnerNN_reciprocal1  \
# BaAl2O4_21080                     {u'O': 9.0}           {u'O': 4.0}
# Be2SiO4_phenakite_64942           {u'O': 4.0}           {u'O': 4.0}
# CaB2O4_34641                      {u'O': 8.0}           {u'O': 3.0}
# CaFe2O4_166080                    {u'O': 8.0}           {u'O': 6.0}
# Fe2SiO4_olivine_4353              {u'O': 6.0}           {u'O': 6.0}
# K2NiF4_73450                      {u'F': 9.0}           {u'F': 6.0}
# K2SO4_beta_2827                  {u'O': 11.0}           {u'O': 9.0}
# MgAl2O4_spinel_31373              {u'O': 4.0}           {u'O': 6.0}
# Na2SO4_thenardite_2895            {u'O': 6.0}           {u'O': 4.0}
# Sr2PbO4_16806                     {u'O': 7.0}           {u'O': 6.0}
#
#                         BrunnerNN_reciprocal2    CrystalNN0   CrystalNN1  \
# BaAl2O4_21080                              {}   {u'O': 9.0}  {u'O': 4.0}
# Be2SiO4_phenakite_64942           {u'O': 4.0}   {u'O': 4.0}  {u'O': 4.0}
# CaB2O4_34641                               {}   {u'O': 8.0}  {u'O': 3.0}
# CaFe2O4_166080                    {u'O': 6.0}   {u'O': 8.0}  {u'O': 6.0}
# Fe2SiO4_olivine_4353              {u'O': 4.0}   {u'O': 6.0}  {u'O': 6.0}
# K2NiF4_73450                               {}   {u'F': 9.0}  {u'F': 6.0}
# K2SO4_beta_2827                   {u'O': 4.0}  {u'O': 10.0}  {u'O': 9.0}
# MgAl2O4_spinel_31373                       {}   {u'O': 4.0}  {u'O': 6.0}
# Na2SO4_thenardite_2895                     {}   {u'O': 6.0}  {u'O': 4.0}
# Sr2PbO4_16806                              {}   {u'O': 7.0}  {u'O': 6.0}
#
#                           CrystalNN2       EconNN0      EconNN1      EconNN2  \
# BaAl2O4_21080                     {}  {u'O': 15.0}  {u'O': 4.0}           {}
# Be2SiO4_phenakite_64942  {u'O': 4.0}   {u'O': 4.0}  {u'O': 4.0}  {u'O': 4.0}
# CaB2O4_34641                      {}   {u'O': 8.0}  {u'O': 3.0}           {}
# CaFe2O4_166080           {u'O': 6.0}   {u'O': 9.0}  {u'O': 6.0}  {u'O': 6.0}
# Fe2SiO4_olivine_4353     {u'O': 4.0}   {u'O': 6.0}  {u'O': 6.0}  {u'O': 4.0}
# K2NiF4_73450                      {}   {u'F': 9.0}  {u'F': 6.0}           {}
# K2SO4_beta_2827          {u'O': 4.0}  {u'O': 13.0}  {u'O': 9.0}  {u'O': 4.0}
# MgAl2O4_spinel_31373              {}   {u'O': 4.0}  {u'O': 6.0}           {}
# Na2SO4_thenardite_2895            {}   {u'O': 8.0}  {u'O': 4.0}           {}
# Sr2PbO4_16806                     {}   {u'O': 7.0}  {u'O': 6.0}           {}
#
#                         HumanInterpreter0 HumanInterpreter1 HumanInterpreter2  \
# BaAl2O4_21080                 {u'O': 9.0}       {u'O': 4.0}                {}
# Be2SiO4_phenakite_64942       {u'O': 4.0}       {u'O': 4.0}       {u'O': 4.0}
# CaB2O4_34641                  {u'O': 8.0}       {u'O': 3.0}                {}
# CaFe2O4_166080                {u'O': 8.0}       {u'O': 6.0}       {u'O': 6.0}
# Fe2SiO4_olivine_4353          {u'O': 6.0}       {u'O': 6.0}       {u'O': 4.0}
# K2NiF4_73450                  {u'F': 9.0}       {u'F': 6.0}                {}
# K2SO4_beta_2827              {u'O': 11.0}       {u'O': 9.0}       {u'O': 4.0}
# MgAl2O4_spinel_31373          {u'O': 4.0}       {u'O': 6.0}                {}
# Na2SO4_thenardite_2895        {u'O': 6.0}       {u'O': 4.0}                {}
# Sr2PbO4_16806                 {u'O': 7.0}       {u'O': 6.0}                {}
#
#                              JMolNN0      JMolNN1      JMolNN2  \
# BaAl2O4_21080                     {}  {u'O': 4.0}           {}
# Be2SiO4_phenakite_64942           {}           {}  {u'O': 4.0}
# CaB2O4_34641                      {}  {u'O': 3.0}           {}
# CaFe2O4_166080           {u'O': 5.0}  {u'O': 6.0}  {u'O': 6.0}
# Fe2SiO4_olivine_4353     {u'O': 6.0}  {u'O': 6.0}  {u'O': 4.0}
# K2NiF4_73450                      {}  {u'F': 6.0}           {}
# K2SO4_beta_2827                   {}           {}  {u'O': 4.0}
# MgAl2O4_spinel_31373     {u'O': 4.0}  {u'O': 6.0}           {}
# Na2SO4_thenardite_2895            {}  {u'O': 4.0}           {}
# Sr2PbO4_16806                     {}  {u'O': 6.0}           {}
#
#                         MinimumDistanceNN0 MinimumDistanceNN1  \
# BaAl2O4_21080                  {u'O': 9.0}        {u'O': 4.0}
# Be2SiO4_phenakite_64942        {u'O': 4.0}        {u'O': 4.0}
# CaB2O4_34641                   {u'O': 6.0}        {u'O': 3.0}
# CaFe2O4_166080                 {u'O': 8.0}        {u'O': 6.0}
# Fe2SiO4_olivine_4353           {u'O': 6.0}        {u'O': 4.0}
# K2NiF4_73450                   {u'F': 9.0}        {u'F': 6.0}
# K2SO4_beta_2827                {u'O': 5.0}        {u'O': 7.0}
# MgAl2O4_spinel_31373           {u'O': 4.0}        {u'O': 6.0}
# Na2SO4_thenardite_2895         {u'O': 6.0}        {u'O': 4.0}
# Sr2PbO4_16806                  {u'O': 6.0}        {u'O': 6.0}
#
#                         MinimumDistanceNN2 MinimumOKeeffeNN0  \
# BaAl2O4_21080                           {}       {u'O': 6.0}
# Be2SiO4_phenakite_64942        {u'O': 4.0}       {u'O': 4.0}
# CaB2O4_34641                            {}       {u'O': 6.0}
# CaFe2O4_166080                 {u'O': 6.0}                {}
# Fe2SiO4_olivine_4353           {u'O': 4.0}       {u'O': 6.0}
# K2NiF4_73450                            {}                {}
# K2SO4_beta_2827                {u'O': 4.0}                {}
# MgAl2O4_spinel_31373                    {}       {u'O': 4.0}
# Na2SO4_thenardite_2895                  {}       {u'O': 2.0}
# Sr2PbO4_16806                           {}                {}
#
#                         MinimumOKeeffeNN1 MinimumOKeeffeNN2   VoronoiNN0  \
# BaAl2O4_21080                 {u'O': 4.0}                {}  {u'O': 9.0}
# Be2SiO4_phenakite_64942       {u'O': 4.0}       {u'O': 4.0}  {u'O': 4.0}
# CaB2O4_34641                  {u'O': 3.0}                {}  {u'O': 8.0}
# CaFe2O4_166080                {u'O': 6.0}       {u'O': 6.0}  {u'O': 8.0}
# Fe2SiO4_olivine_4353          {u'O': 4.0}       {u'O': 4.0}  {u'O': 6.0}
# K2NiF4_73450                  {u'F': 6.0}                {}  {u'F': 9.0}
# K2SO4_beta_2827                        {}       {u'O': 4.0}  {u'O': 9.0}
# MgAl2O4_spinel_31373          {u'O': 6.0}                {}  {u'O': 4.0}
# Na2SO4_thenardite_2895        {u'O': 4.0}                {}  {u'O': 6.0}
# Sr2PbO4_16806                 {u'O': 6.0}                {}  {u'O': 7.0}
#
#                           VoronoiNN1   VoronoiNN2
# BaAl2O4_21080            {u'O': 4.0}           {}
# Be2SiO4_phenakite_64942  {u'O': 4.0}  {u'O': 4.0}
# CaB2O4_34641             {u'O': 3.0}           {}
# CaFe2O4_166080           {u'O': 6.0}  {u'O': 6.0}
# Fe2SiO4_olivine_4353     {u'O': 6.0}  {u'O': 4.0}
# K2NiF4_73450             {u'F': 6.0}           {}
# K2SO4_beta_2827          {u'O': 9.0}  {u'O': 4.0}
# MgAl2O4_spinel_31373     {u'O': 6.0}           {}
# Na2SO4_thenardite_2895   {u'O': 4.0}           {}
# Sr2PbO4_16806            {u'O': 6.0}           {}

# %%
nbf = NbFuncs(bm)
df = nbf.final()
df
# Out:
#                          BrunnerNN_reciprocal  CrystalNN  EconNN  JMolNN  \
# BaAl2O4_21080                             0.0      0.000   2.000   3.000
# Be2SiO4_phenakite_64942                   0.0      0.000   0.000   2.667
# CaB2O4_34641                              0.0      0.000   0.000   2.667
# CaFe2O4_166080                            0.0      0.000   0.333   1.000
# Fe2SiO4_olivine_4353                      0.0      0.000   0.000   0.000
# K2NiF4_73450                              0.0      0.000   0.000   6.000
# K2SO4_beta_2827                           0.0      0.333   0.667   6.667
# MgAl2O4_spinel_31373                      0.0      0.000   0.000   0.000
# Na2SO4_thenardite_2895                    0.0      0.000   1.333   4.000
# Sr2PbO4_16806                             0.0      0.000   0.000   4.667
# Total                                     0.0      0.333   4.333  30.667
#
#                          MinimumDistanceNN  MinimumOKeeffeNN  VoronoiNN
# BaAl2O4_21080                        0.000             1.000      0.000
# Be2SiO4_phenakite_64942              0.000             0.000      0.000
# CaB2O4_34641                         0.667             0.667      0.000
# CaFe2O4_166080                       0.000             2.667      0.000
# Fe2SiO4_olivine_4353                 0.667             0.667      0.000
# K2NiF4_73450                         0.000             6.000      0.000
# K2SO4_beta_2827                      2.667             6.667      0.667
# MgAl2O4_spinel_31373                 0.000             0.000      0.000
# Na2SO4_thenardite_2895               0.000             2.667      0.000
# Sr2PbO4_16806                        0.667             4.667      0.000
# Total                                4.667            25.000      0.667

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 10))

sns.set(font='Times New Roman')
sns.set(font_scale=2)

hm = sns.heatmap(df, annot=True, cmap="BuPu", vmax=10)

ax.set_xticklabels(df.columns.tolist(), rotation=45)
ax.set_yticklabels(df.index.tolist())

plt.savefig('ternary.png')
plt.show()
