# %%
import pandas as pd
pd.set_option("display.max_columns",999) # display all columns
pd.set_option("display.max_rows", 999)

from pymatgen.analysis.local_env import BrunnerNN_reciprocal, EconNN, JmolNN, \
                                        MinimumDistanceNN, MinimumOKeeffeNN, MinimumVIRENN, \
                                        VoronoiNN, VoronoiNN_modified, CrystalNN
from materialscoord.core import Benchmark, HumanInterpreter

methods = [MinimumDistanceNN(),  MinimumOKeeffeNN(), MinimumVIRENN(), JmolNN(), EconNN(), 
           BrunnerNN_reciprocal(), VoronoiNN(tol=0.5), CrystalNN(), HumanInterpreter()]
structure_groups = ["common_binaries"]

preset = Benchmark.from_preset(preset_name=structure_groups)
preset.benchmark(methods=methods)
# Out:
# /Users/hillarypan/pymatgen/pymatgen/io/cif.py:37: UserWarning: Please install optional dependency pybtex if youwant to extract references from CIF files.
#   warnings.warn("Please install optional dependency pybtex if you"
# /Users/hillarypan/pymatgen/pymatgen/io/cif.py:1106: UserWarning: Issues encountered while parsing CIF:
#   warnings.warn("Issues encountered while parsing CIF:")
# /Users/hillarypan/pymatgen/pymatgen/io/cif.py:1108: UserWarning: Some fractional co-ordinates rounded to ideal values to avoid finite precision errors.
#   warnings.warn(error)
# /Users/hillarypan/pymatgen/pymatgen/analysis/local_env.py:3419: UserWarning: CrystalNN: distance cutoffs set but no oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#   warnings.warn("CrystalNN: distance cutoffs set but no oxidation "
# /Users/hillarypan/pymatgen/pymatgen/analysis/local_env.py:3232: UserWarning: CrystalNN: cannot locate an appropriate radius, covalent or atomic radii will be used, this can lead to non-optimal results.
#   "CrystalNN: cannot locate an appropriate radius, "
#                         MinimumDistanceNN0 MinimumDistanceNN1  \
# Al2O3_corundum_9770              {'Al': 4}                 {}
# CsCl_53847                       {'Cs': 8}                 {}
# Cu5Zn8_gamma_brass_2092                 {}                 {}
# Fe3O4_inv_spinel_26410           {'Fe': 4}                 {}
# NaCl_rocksalt_100633             {'Na': 6}                 {}
# NiAs_5245                        {'Ni': 6}                 {}
# Pb3O4_22325                      {'Pb': 3}          {'Pb': 3}
# Th3P4_25724                      {'Th': 6}                 {}
# TiO2_rutile_9852                 {'Ti': 3}                 {}
# ZnS_sphalerite_651455            {'Zn': 4}                 {}
# ZnS_wurtzite_67453               {'Zn': 4}                 {}
#
#                         MinimumDistanceNN2 MinimumDistanceNN3  \
# Al2O3_corundum_9770                     {}                 {}
# CsCl_53847                              {}                 {}
# Cu5Zn8_gamma_brass_2092                 {}                 {}
# Fe3O4_inv_spinel_26410                  {}                 {}
# NaCl_rocksalt_100633                    {}                 {}
# NiAs_5245                               {}                 {}
# Pb3O4_22325                             {}                 {}
# Th3P4_25724                             {}                 {}
# TiO2_rutile_9852                        {}                 {}
# ZnS_sphalerite_651455                   {}                 {}
# ZnS_wurtzite_67453                      {}                 {}
#
#                         MinimumOKeeffeNN0 MinimumOKeeffeNN1 MinimumOKeeffeNN2  \
# Al2O3_corundum_9770             {'Al': 4}                {}                {}
# CsCl_53847                      {'Cs': 8}                {}                {}
# Cu5Zn8_gamma_brass_2092                {}                {}                {}
# Fe3O4_inv_spinel_26410          {'Fe': 4}                {}                {}
# NaCl_rocksalt_100633            {'Na': 6}                {}                {}
# NiAs_5245                       {'Ni': 6}                {}                {}
# Pb3O4_22325                     {'Pb': 3}         {'Pb': 3}                {}
# Th3P4_25724                     {'Th': 6}                {}                {}
# TiO2_rutile_9852                {'Ti': 3}                {}                {}
# ZnS_sphalerite_651455           {'Zn': 4}                {}                {}
# ZnS_wurtzite_67453              {'Zn': 4}                {}                {}
#
#                         MinimumOKeeffeNN3 MinimumVIRENN0 MinimumVIRENN1  \
# Al2O3_corundum_9770                    {}      {'Al': 4}             {}
# CsCl_53847                             {}      {'Cs': 8}             {}
# Cu5Zn8_gamma_brass_2092                {}             {}             {}
# Fe3O4_inv_spinel_26410                 {}      {'Fe': 1}             {}
# NaCl_rocksalt_100633                   {}      {'Na': 6}             {}
# NiAs_5245                              {}      {'Ni': 6}             {}
# Pb3O4_22325                            {}      {'Pb': 3}      {'Pb': 3}
# Th3P4_25724                            {}      {'Th': 6}             {}
# TiO2_rutile_9852                       {}      {'Ti': 3}             {}
# ZnS_sphalerite_651455                  {}      {'Zn': 4}             {}
# ZnS_wurtzite_67453                     {}      {'Zn': 4}             {}
#
#                         MinimumVIRENN2 MinimumVIRENN3    JmolNN0    JmolNN1  \
# Al2O3_corundum_9770                 {}             {}  {'Al': 4}         {}
# CsCl_53847                          {}             {}         {}         {}
# Cu5Zn8_gamma_brass_2092             {}             {}         {}         {}
# Fe3O4_inv_spinel_26410              {}             {}  {'Fe': 4}         {}
# NaCl_rocksalt_100633                {}             {}         {}         {}
# NiAs_5245                           {}             {}  {'Ni': 6}         {}
# Pb3O4_22325                         {}             {}  {'Pb': 3}  {'Pb': 3}
# Th3P4_25724                         {}             {}  {'Th': 6}         {}
# TiO2_rutile_9852                    {}             {}  {'Ti': 3}         {}
# ZnS_sphalerite_651455               {}             {}  {'Zn': 4}         {}
# ZnS_wurtzite_67453                  {}             {}  {'Zn': 4}         {}
#
#                         JmolNN2 JmolNN3    EconNN0    EconNN1 EconNN2 EconNN3  \
# Al2O3_corundum_9770          {}      {}  {'Al': 4}         {}      {}      {}
# CsCl_53847                   {}      {}  {'Cs': 8}         {}      {}      {}
# Cu5Zn8_gamma_brass_2092      {}      {}         {}         {}      {}      {}
# Fe3O4_inv_spinel_26410       {}      {}  {'Fe': 4}         {}      {}      {}
# NaCl_rocksalt_100633         {}      {}  {'Na': 6}         {}      {}      {}
# NiAs_5245                    {}      {}  {'Ni': 6}         {}      {}      {}
# Pb3O4_22325                  {}      {}  {'Pb': 3}  {'Pb': 4}      {}      {}
# Th3P4_25724                  {}      {}  {'Th': 6}         {}      {}      {}
# TiO2_rutile_9852             {}      {}  {'Ti': 3}         {}      {}      {}
# ZnS_sphalerite_651455        {}      {}  {'Zn': 4}         {}      {}      {}
# ZnS_wurtzite_67453           {}      {}  {'Zn': 4}         {}      {}      {}
#
#                         BrunnerNN_reciprocal0 BrunnerNN_reciprocal1  \
# Al2O3_corundum_9770                 {'Al': 4}                    {}
# CsCl_53847                          {'Cs': 8}                    {}
# Cu5Zn8_gamma_brass_2092                    {}                    {}
# Fe3O4_inv_spinel_26410              {'Fe': 4}                    {}
# NaCl_rocksalt_100633                {'Na': 6}                    {}
# NiAs_5245                           {'Ni': 6}                    {}
# Pb3O4_22325                         {'Pb': 3}             {'Pb': 3}
# Th3P4_25724                         {'Th': 6}                    {}
# TiO2_rutile_9852                    {'Ti': 3}                    {}
# ZnS_sphalerite_651455               {'Zn': 4}                    {}
# ZnS_wurtzite_67453                  {'Zn': 4}                    {}
#
#                         BrunnerNN_reciprocal2 BrunnerNN_reciprocal3  \
# Al2O3_corundum_9770                        {}                    {}
# CsCl_53847                                 {}                    {}
# Cu5Zn8_gamma_brass_2092                    {}                    {}
# Fe3O4_inv_spinel_26410                     {}                    {}
# NaCl_rocksalt_100633                       {}                    {}
# NiAs_5245                                  {}                    {}
# Pb3O4_22325                                {}                    {}
# Th3P4_25724                                {}                    {}
# TiO2_rutile_9852                           {}                    {}
# ZnS_sphalerite_651455                      {}                    {}
# ZnS_wurtzite_67453                         {}                    {}
#
#                         VoronoiNN0 VoronoiNN1 VoronoiNN2 VoronoiNN3  \
# Al2O3_corundum_9770      {'Al': 4}         {}         {}         {}
# CsCl_53847               {'Cs': 8}         {}         {}         {}
# Cu5Zn8_gamma_brass_2092         {}         {}         {}         {}
# Fe3O4_inv_spinel_26410   {'Fe': 4}         {}         {}         {}
# NaCl_rocksalt_100633     {'Na': 6}         {}         {}         {}
# NiAs_5245                {'Ni': 6}         {}         {}         {}
# Pb3O4_22325              {'Pb': 3}  {'Pb': 3}         {}         {}
# Th3P4_25724              {'Th': 6}         {}         {}         {}
# TiO2_rutile_9852         {'Ti': 3}         {}         {}         {}
# ZnS_sphalerite_651455    {'Zn': 4}         {}         {}         {}
# ZnS_wurtzite_67453       {'Zn': 4}         {}         {}         {}
#
#                         CrystalNN0 CrystalNN1 CrystalNN2 CrystalNN3  \
# Al2O3_corundum_9770      {'Al': 4}         {}         {}         {}
# CsCl_53847               {'Cs': 8}         {}         {}         {}
# Cu5Zn8_gamma_brass_2092         {}         {}         {}         {}
# Fe3O4_inv_spinel_26410   {'Fe': 4}         {}         {}         {}
# NaCl_rocksalt_100633     {'Na': 6}         {}         {}         {}
# NiAs_5245                {'Ni': 6}         {}         {}         {}
# Pb3O4_22325              {'Pb': 3}  {'Pb': 3}         {}         {}
# Th3P4_25724              {'Th': 6}         {}         {}         {}
# TiO2_rutile_9852         {'Ti': 3}         {}         {}         {}
# ZnS_sphalerite_651455    {'Zn': 4}         {}         {}         {}
# ZnS_wurtzite_67453       {'Zn': 4}         {}         {}         {}
#
#                         HumanInterpreter0 HumanInterpreter1 HumanInterpreter2  \
# Al2O3_corundum_9770           {'Al': 4.0}                {}                {}
# CsCl_53847                    {'Cs': 8.0}                {}                {}
# Cu5Zn8_gamma_brass_2092                {}                {}                {}
# Fe3O4_inv_spinel_26410        {'Fe': 4.0}                {}                {}
# NaCl_rocksalt_100633          {'Na': 6.0}                {}                {}
# NiAs_5245                     {'Ni': 6.0}                {}                {}
# Pb3O4_22325                   {'Pb': 3.0}       {'Pb': 3.0}                {}
# Th3P4_25724                   {'Th': 6.0}                {}                {}
# TiO2_rutile_9852              {'Ti': 3.0}                {}                {}
# ZnS_sphalerite_651455         {'Zn': 4.0}                {}                {}
# ZnS_wurtzite_67453            {'Zn': 4.0}                {}                {}
#
#                         HumanInterpreter3
# Al2O3_corundum_9770                    {}
# CsCl_53847                             {}
# Cu5Zn8_gamma_brass_2092                {}
# Fe3O4_inv_spinel_26410                 {}
# NaCl_rocksalt_100633                   {}
# NiAs_5245                              {}
# Pb3O4_22325                            {}
# Th3P4_25724                            {}
# TiO2_rutile_9852                       {}
# ZnS_sphalerite_651455                  {}
# ZnS_wurtzite_67453                     {}

# %%
df = preset.score(methods)
df
# Out:
# /Users/hillarypan/MaterialsCoord/materialscoord/core.py:411: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   df = pd.concat([df, df_cs[df_cs.columns[-1:]]], axis=1)
#                          MinimumDistanceNN  MinimumOKeeffeNN  MinimumVIRENN  \
# Al2O3_corundum_9770                    0.0               0.0            0.0
# CsCl_53847                             0.0               0.0            0.0
# Cu5Zn8_gamma_brass_2092                NaN               NaN            NaN
# Fe3O4_inv_spinel_26410                 0.0               0.0            3.0
# NaCl_rocksalt_100633                   0.0               0.0            0.0
# NiAs_5245                              0.0               0.0            0.0
# Pb3O4_22325                            0.0               0.0            0.0
# Th3P4_25724                            0.0               0.0            0.0
# TiO2_rutile_9852                       0.0               0.0            0.0
# ZnS_sphalerite_651455                  0.0               0.0            0.0
# ZnS_wurtzite_67453                     0.0               0.0            0.0
# Total                                  0.0               0.0            3.0
#
#                          JmolNN  EconNN  BrunnerNN_reciprocal  VoronoiNN  \
# Al2O3_corundum_9770         0.0     0.0                   0.0        0.0
# CsCl_53847                  8.0     0.0                   0.0        0.0
# Cu5Zn8_gamma_brass_2092     NaN     NaN                   NaN        NaN
# Fe3O4_inv_spinel_26410      0.0     0.0                   0.0        0.0
# NaCl_rocksalt_100633        6.0     0.0                   0.0        0.0
# NiAs_5245                   0.0     0.0                   0.0        0.0
# Pb3O4_22325                 0.0     0.5                   0.0        0.0
# Th3P4_25724                 0.0     0.0                   0.0        0.0
# TiO2_rutile_9852            0.0     0.0                   0.0        0.0
# ZnS_sphalerite_651455       0.0     0.0                   0.0        0.0
# ZnS_wurtzite_67453          0.0     0.0                   0.0        0.0
# Total                      14.0     0.5                   0.0        0.0
#
#                          CrystalNN
# Al2O3_corundum_9770            0.0
# CsCl_53847                     0.0
# Cu5Zn8_gamma_brass_2092        NaN
# Fe3O4_inv_spinel_26410         0.0
# NaCl_rocksalt_100633           0.0
# NiAs_5245                      0.0
# Pb3O4_22325                    0.0
# Th3P4_25724                    0.0
# TiO2_rutile_9852               0.0
# ZnS_sphalerite_651455          0.0
# ZnS_wurtzite_67453             0.0
# Total                          0.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(17, 10))

sns.set(font='Times New Roman')
sns.set(font_scale=1.5)

hm = sns.heatmap(df, annot=True, cmap="Blues", vmax=10)

strucs = [r'Al$_2$O$_3$ (corundum)', "CsCl", r"Cu$_5$Zn$_8$ ($\gamma$-brass)", r"Fe$_3$O$_4$", "NaCl (rock-salt)", 
          "NiAs", r"Pb$_3$O$_4$", r"Th$_3$P$_4$", r"TiO$_2$ (rutile)", "ZnS (sphalerite)", "ZnS (wurtzite)", "Total"]
ax.set_yticklabels(strucs)

nn = ["MinimumDistanceNN", "MinimumOKeeffeNN", "MinimumVIRENN", "JmolNN", 
      "EconNN", "BrunnerNN", "VoronoiNN", "CrystalNN"]
ax.set_xticklabels(nn, rotation=60)

cbar = ax.collections[0].colorbar
cbar.set_label('Benchmark Score', labelpad=40, rotation=270)

ax.axhline(y=0, color='k',linewidth=1)
ax.axhline(y=len(strucs), color='k',linewidth=2)
ax.axhline(y=len(strucs)-1, color='k',linewidth=1)
ax.axvline(x=0, color='k',linewidth=1)
ax.axvline(x=len(nn), color='k',linewidth=2)

plt.savefig('binary_anion.pdf', bbox_inches='tight')
plt.show()
