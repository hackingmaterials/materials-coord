# %%
import pandas as pd
pd.set_option("display.max_columns",999) # display all columns
pd.set_option("display.max_rows", 999)

from pymatgen.analysis.local_env import BrunnerNN_reciprocal, EconNN, JmolNN, \
                                        MinimumDistanceNN, MinimumOKeeffeNN, MinimumVIRENN, \
                                        VoronoiNN, VoronoiNN_modified, CrystalNN
from materialscoord.core import Benchmark, HumanInterpreter

# CrystalNN(distance_cutoffs=None, x_diff_weight=None)
methods = [MinimumDistanceNN(),  MinimumOKeeffeNN(), MinimumVIRENN(), JmolNN(), EconNN(), 
           BrunnerNN_reciprocal(), VoronoiNN(tol=0.5), CrystalNN(), HumanInterpreter()]
structure_groups = ["elemental"]

preset = Benchmark.from_preset(preset_name=structure_groups)
preset.benchmark(methods=methods)
# Out:
# /Users/hillarypan/pymatgen/pymatgen/io/cif.py:37: UserWarning: Please install optional dependency pybtex if youwant to extract references from CIF files.
#   warnings.warn("Please install optional dependency pybtex if you"
# /Users/hillarypan/pymatgen/pymatgen/io/cif.py:1106: UserWarning: Issues encountered while parsing CIF:
#   warnings.warn("Issues encountered while parsing CIF:")
# /Users/hillarypan/pymatgen/pymatgen/io/cif.py:1108: UserWarning: Some fractional co-ordinates rounded to ideal values to avoid finite precision errors.
#   warnings.warn(error)
# /Users/hillarypan/pymatgen/pymatgen/analysis/local_env.py:3419: UserWarning: CrystalNN: distance cutoffs set but no oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#   warnings.warn("CrystalNN: distance cutoffs set but no oxidation "
# ...

# %%
df = preset.score(methods)
df
# Out:
#                    MinimumDistanceNN  MinimumOKeeffeNN  MinimumVIRENN  JmolNN  \
# As_alpha_16518                 0.000             0.000          0.000     0.0
# C_diamond_52054                0.000             0.000          0.000     0.0
# C_graphite_76767               0.000             0.000          0.000     0.0
# Cu_52256                       0.000             0.000          0.000     0.0
# Ga_12174                       0.000             0.000          0.000     0.0
# Hg_alpha_104296                0.000             0.000          0.000     0.0
# La_43573                       0.000             0.000          0.000     0.0
# Mg_52260                       0.000             0.000          0.000    12.0
# Mn_alpha_42743                 7.862             7.862          7.862     0.0
# Mn_beta_41775                  2.400             2.400          2.400     0.0
# P_black_23836                  0.000             0.000          0.000     3.0
# ...

# %%
df.index.values.tolist()
# Out:
# ['As_alpha_16518',
#  'C_diamond_52054',
#  'C_graphite_76767',
#  'Cu_52256',
#  'Ga_12174',
#  'Hg_alpha_104296',
#  'La_43573',
#  'Mg_52260',
#  'Mn_alpha_42743',
#  'Mn_beta_41775',
#  'P_black_23836',
#  'Se_trigonal_23068',
#  'Sm_76031',
#  'Sn_beta_106072',
#  'U_alpha_16056',
#  'W_alpha_43667',
#  'Total']

# %%
new_index= ['W_alpha_43667', 'La_43573', 'Mg_52260', 'Cu_52256', 
            'C_diamond_52054', 'Se_trigonal_23068', 'Sn_beta_106072',
            'As_alpha_16518', 'P_black_23836', 'C_graphite_76767', 'Sm_76031',
            'Hg_alpha_104296', 'U_alpha_16056', 'Ga_12174', 
            'Mn_alpha_42743', 'Mn_beta_41775','Total']
new_df = df.reindex(new_index)
new_df
# Out:
#                    MinimumDistanceNN  MinimumOKeeffeNN  MinimumVIRENN  JmolNN  \
# W_alpha_43667                  0.000             0.000          0.000     6.0
# La_43573                       0.000             0.000          0.000     0.0
# Mg_52260                       0.000             0.000          0.000    12.0
# Cu_52256                       0.000             0.000          0.000     0.0
# C_diamond_52054                0.000             0.000          0.000     0.0
# Se_trigonal_23068              0.000             0.000          0.000     0.0
# Sn_beta_106072                 0.000             0.000          0.000     0.0
# As_alpha_16518                 0.000             0.000          0.000     0.0
# P_black_23836                  0.000             0.000          0.000     3.0
# C_graphite_76767               0.000             0.000          0.000     0.0
# Sm_76031                       0.000             0.000          0.000     0.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
# %matplotlib inline

fig, ax = plt.subplots(figsize=(17, 10))

sns.set(font='Times New Roman')
sns.set(font_scale=1.5)

hm = sns.heatmap(new_df, annot=True, cmap="Blues", vmax=10)

# strucs = [r'$\alpha$'"-As", "C (diamond)", "C (graphite)", "Cu"
#           "Ga (III)", r'$\alpha$'"-Hg", "La", "Mg", r'$\alpha$'"-Mn", 
#           r'$\beta$'"-Mn", "P (black)", "Se (trigonal)", "Sm", 
#           r'$\beta$'"-Sn", r'$\alpha$'"-U", r'$\alpha$'"-W", "Total"]
# ax.set_yticklabels(strucs)

strucs = [r'$\alpha$'"-W", "La", "Mg", "Cu", "C (diamond)", "Se (trigonal)", r'$\beta$''-Sn',
          r'$\alpha$''-As', "P (black)", "C (graphite)", "Sm", 
          r'$\alpha$'"-Hg", r'$\alpha$''-U', "Ga (III)", 
          r'$\alpha$'"-Mn", r'$\beta$'"-Mn", "Total"]
ax.set_yticklabels(strucs)

nn = ["MinimumDistanceNN", "MinimumOKeeffeNN", "MinimumVIRENN", "JmolNN", 
      "EconNN", "BrunnerNN", "VoronoiNN", "CrystalNN"]
ax.set_xticklabels(nn, rotation=60)

cbar = ax.collections[0].colorbar
cbar.set_label('Benchmark Score', labelpad=40, rotation=270)

# # heatmap border
# ax.axhline(y=0, color='k',linewidth=1)
# ax.axhline(y=len(strucs), color='k',linewidth=2)
# ax.axhline(y=len(strucs)-1, color='k',linewidth=1)
# ax.axvline(x=0, color='k',linewidth=1)
# ax.axvline(x=len(nn), color='k',linewidth=2)

# # basic structures 
# ax.axhline(y=0, color='r', linewidth=6)
# ax.axhline(y=6.95, color='r', linewidth=3)

# l1 = mlines.Line2D([0, 0], [0, 6.95], color='r', linewidth=6)
# l2 = mlines.Line2D([len(nn), len(nn)], [0, 6.95], color='r', linewidth=6)
# ax.add_line(l1)
# ax.add_line(l2)

# # layered structures
# ax.axhline(y=7.05, color='y', linewidth=3)
# ax.axhline(y=10.95, color='y', linewidth=3)

# l3 = mlines.Line2D([0, 0], [7.1, 10.95], color='y', linewidth=6)
# l4 = mlines.Line2D([len(nn), len(nn)], [7.1, 10.95], color='y', linewidth=6)
# ax.add_line(l3)
# ax.add_line(l4)

# # multiple coordinations
# ax.axhline(y=11.05, color='g', linewidth=3)
# ax.axhline(y=13.95, color='g', linewidth=3)

# l5 = mlines.Line2D([0, 0], [11.1, 13.95], color='g', linewidth=6)
# l6 = mlines.Line2D([len(nn), len(nn)], [11.1, 13.95], color='g', linewidth=6)
# ax.add_line(l5)
# ax.add_line(l6)

# # mixed coordination
# ax.axhline(y=14.05, color='m', linewidth=3)
# ax.axhline(y=15.95, color='m', linewidth=4)

# l7 = mlines.Line2D([0, 0], [14.1, 15.95], color='k', linewidth=6)
# l8 = mlines.Line2D([len(nn), len(nn)], [14.1, 15.95], color='k', linewidth=6)
# ax.add_line(l7)
# ax.add_line(l8)

# # total

# ax.axhline(y=16.05, color='m', linewidth=3)
# ax.axhline(y=17, color='m', linewidth=4)

# l7 = mlines.Line2D([0, 0], [16.05, 17], color='k', linewidth=6)
# l8 = mlines.Line2D([len(nn), len(nn)], [16.05, 17], color='k', linewidth=6)
# ax.add_line(l7)
# ax.add_line(l8)

plt.savefig('elemental.pdf', bbox_inches='tight')
plt.show()

# %%
dist{MinimumDistanceNN:[(20, 0), (32, )]}
