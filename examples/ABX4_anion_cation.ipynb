# %%
import pandas as pd
pd.set_option("display.max_columns",999) # display all columns
pd.set_option("display.max_rows", 999)

from pymatgen.analysis.local_env import BrunnerNN_reciprocal, EconNN, JMolNN, \
                                        MinimumDistanceNN, MinimumOKeeffeNN, MinimumVIRENN, \
                                        VoronoiNN, VoronoiNN_modified, CrystalNN
from materialscoord.core import Benchmark, HumanInterpreter

methods = [BrunnerNN_reciprocal(), EconNN(), JMolNN(), CrystalNN(), VoronoiNN(tol=0.5),
           MinimumDistanceNN(), MinimumOKeeffeNN(), MinimumVIRENN(),
           HumanInterpreter()]
structure_groups = ["A2BX4"]

preset = Benchmark.from_preset("A2BX4")
preset.benchmark(methods=methods)
# Out:
# /Users/hillarypan/AJResearch/cn_routines/codes/pymatgen/pymatgen/__init__.py:89: UserWarning:
# Pymatgen will drop Py2k support from v2019.1.1. Pls consult the documentation
# at https://www.pymatgen.org for more details.
#   at https://www.pymatgen.org for more details.""")
#                             BrunnerNN_reciprocal0     BrunnerNN_reciprocal1  \
# BaAl2O4_21080                        {u'Al': 2.0}              {u'Al': 2.0}
# Be2SiO4_phenakite_64942  {u'Be': 2.0, u'Si': 1.0}  {u'Be': 2.0, u'Si': 1.0}
# CaB2O4_34641                          {u'B': 1.0}               {u'B': 2.0}
# CaFe2O4_166080                       {u'Fe': 3.0}              {u'Fe': 3.0}
# Fe2SiO4_olivine_4353                 {u'Si': 1.0}              {u'Si': 1.0}
# K2NiF4_73450                         {u'Ni': 2.0}              {u'Ni': 1.0}
# K2SO4_beta_2827                       {u'S': 1.0}               {u'S': 1.0}
# MgAl2O4_spinel_31373     {u'Mg': 1.0, u'Al': 3.0}                        {}
# Na2SO4_thenardite_2895                {u'S': 1.0}                        {}
# Sr2PbO4_16806                        {u'Pb': 2.0}              {u'Pb': 1.0}
#
#                             BrunnerNN_reciprocal2     BrunnerNN_reciprocal3  \
# BaAl2O4_21080                                  {}                        {}
# Be2SiO4_phenakite_64942  {u'Be': 2.0, u'Si': 1.0}  {u'Be': 2.0, u'Si': 1.0}
# CaB2O4_34641                                   {}                        {}
# CaFe2O4_166080                       {u'Fe': 3.0}              {u'Fe': 3.0}
# Fe2SiO4_olivine_4353                 {u'Si': 1.0}                        {}
# K2NiF4_73450                                   {}                        {}
# K2SO4_beta_2827                       {u'S': 1.0}                        {}
# MgAl2O4_spinel_31373                           {}                        {}
# Na2SO4_thenardite_2895                         {}                        {}
# Sr2PbO4_16806                                  {}                        {}
#
#                                        CrystalNN0                CrystalNN1  \
# BaAl2O4_21080                        {u'Al': 2.0}              {u'Al': 2.0}
# Be2SiO4_phenakite_64942  {u'Be': 2.0, u'Si': 1.0}  {u'Be': 2.0, u'Si': 1.0}
# CaB2O4_34641                          {u'B': 1.0}               {u'B': 2.0}
# CaFe2O4_166080           {u'Ca': 2.0, u'Fe': 3.0}  {u'Ca': 2.0, u'Fe': 3.0}
# Fe2SiO4_olivine_4353     {u'Si': 1.0, u'Fe': 3.0}  {u'Si': 1.0, u'Fe': 3.0}
# K2NiF4_73450              {u'Ni': 2.0, u'K': 4.0}   {u'Ni': 1.0, u'K': 5.0}
# K2SO4_beta_2827                       {u'S': 1.0}               {u'S': 1.0}
# MgAl2O4_spinel_31373     {u'Mg': 1.0, u'Al': 3.0}                        {}
# Na2SO4_thenardite_2895    {u'Na': 3.0, u'S': 1.0}                        {}
# Sr2PbO4_16806            {u'Pb': 2.0, u'Sr': 3.0}  {u'Pb': 1.0, u'Sr': 4.0}
#
#                                        CrystalNN2                CrystalNN3  \
# BaAl2O4_21080                                  {}                        {}
# Be2SiO4_phenakite_64942  {u'Be': 2.0, u'Si': 1.0}  {u'Be': 2.0, u'Si': 1.0}
# CaB2O4_34641                                   {}                        {}
# CaFe2O4_166080           {u'Ca': 2.0, u'Fe': 3.0}  {u'Ca': 2.0, u'Fe': 3.0}
# Fe2SiO4_olivine_4353     {u'Si': 1.0, u'Fe': 3.0}                        {}
# K2NiF4_73450                                   {}                        {}
# K2SO4_beta_2827                       {u'S': 1.0}                        {}
# MgAl2O4_spinel_31373                           {}                        {}
# Na2SO4_thenardite_2895                         {}                        {}
# Sr2PbO4_16806                                  {}                        {}
#
#                                           EconNN0                   EconNN1  \
# BaAl2O4_21080                        {u'Al': 2.0}              {u'Al': 2.0}
# Be2SiO4_phenakite_64942  {u'Be': 2.0, u'Si': 1.0}  {u'Be': 2.0, u'Si': 1.0}
# CaB2O4_34641                          {u'B': 1.0}               {u'B': 2.0}
# CaFe2O4_166080           {u'Ca': 2.0, u'Fe': 3.0}  {u'Ca': 2.0, u'Fe': 3.0}
# Fe2SiO4_olivine_4353     {u'Si': 1.0, u'Fe': 3.0}  {u'Si': 1.0, u'Fe': 3.0}
# K2NiF4_73450              {u'Ni': 2.0, u'K': 4.0}   {u'Ni': 1.0, u'K': 5.0}
# K2SO4_beta_2827                       {u'S': 1.0}               {u'S': 1.0}
# MgAl2O4_spinel_31373     {u'Mg': 1.0, u'Al': 3.0}                        {}
# Na2SO4_thenardite_2895                {u'S': 1.0}                        {}
# Sr2PbO4_16806            {u'Pb': 2.0, u'Sr': 3.0}  {u'Pb': 1.0, u'Sr': 4.0}
#
#                                           EconNN2                   EconNN3  \
# BaAl2O4_21080                                  {}                        {}
# Be2SiO4_phenakite_64942  {u'Be': 2.0, u'Si': 1.0}  {u'Be': 2.0, u'Si': 1.0}
# CaB2O4_34641                                   {}                        {}
# CaFe2O4_166080           {u'Ca': 2.0, u'Fe': 3.0}  {u'Ca': 2.0, u'Fe': 3.0}
# Fe2SiO4_olivine_4353     {u'Si': 1.0, u'Fe': 3.0}                        {}
# K2NiF4_73450                                   {}                        {}
# K2SO4_beta_2827                       {u'S': 1.0}                        {}
# MgAl2O4_spinel_31373                           {}                        {}
# Na2SO4_thenardite_2895                         {}                        {}
# Sr2PbO4_16806                                  {}                        {}
#
#                                 HumanInterpreter0         HumanInterpreter1  \
# BaAl2O4_21080            {u'Ba': 0.0, u'Al': 2.0}  {u'Ba': 0.0, u'Al': 2.0}
# Be2SiO4_phenakite_64942  {u'Be': 2.0, u'Si': 1.0}  {u'Be': 2.0, u'Si': 1.0}
# CaB2O4_34641              {u'Ca': 3.0, u'B': 2.0}   {u'Ca': 3.0, u'B': 2.0}
# CaFe2O4_166080           {u'Ca': 2.0, u'Fe': 3.0}  {u'Ca': 2.0, u'Fe': 3.0}
# Fe2SiO4_olivine_4353     {u'Si': 1.0, u'Fe': 3.0}  {u'Si': 1.0, u'Fe': 3.0}
# K2NiF4_73450              {u'Ni': 2.0, u'K': 4.0}   {u'Ni': 1.0, u'K': 5.0}
# K2SO4_beta_2827            {u'K': 5.0, u'S': 1.0}    {u'K': 5.0, u'S': 1.0}
# MgAl2O4_spinel_31373     {u'Mg': 1.0, u'Al': 3.0}                        {}
# Na2SO4_thenardite_2895    {u'Na': 3.0, u'S': 1.0}                        {}
# Sr2PbO4_16806            {u'Pb': 2.0, u'Sr': 3.0}  {u'Pb': 1.0, u'Sr': 4.0}
#
#                                 HumanInterpreter2         HumanInterpreter3  \
# BaAl2O4_21080                                  {}                        {}
# Be2SiO4_phenakite_64942  {u'Be': 2.0, u'Si': 1.0}  {u'Be': 2.0, u'Si': 1.0}
# CaB2O4_34641                                   {}                        {}
# CaFe2O4_166080           {u'Ca': 2.0, u'Fe': 3.0}  {u'Ca': 2.0, u'Fe': 3.0}
# Fe2SiO4_olivine_4353     {u'Si': 1.0, u'Fe': 3.0}                        {}
# K2NiF4_73450                                   {}                        {}
# K2SO4_beta_2827            {u'K': 5.0, u'S': 1.0}                        {}
# MgAl2O4_spinel_31373                           {}                        {}
# Na2SO4_thenardite_2895                         {}                        {}
# Sr2PbO4_16806                                  {}                        {}
#
#                                           JMolNN0                   JMolNN1  \
# BaAl2O4_21080                        {u'Al': 2.0}              {u'Al': 2.0}
# Be2SiO4_phenakite_64942              {u'Si': 1.0}              {u'Si': 1.0}
# CaB2O4_34641                          {u'B': 1.0}               {u'B': 2.0}
# CaFe2O4_166080                       {u'Fe': 3.0}  {u'Ca': 2.0, u'Fe': 3.0}
# Fe2SiO4_olivine_4353     {u'Si': 1.0, u'Fe': 3.0}  {u'Si': 1.0, u'Fe': 3.0}
# K2NiF4_73450                         {u'Ni': 2.0}              {u'Ni': 1.0}
# K2SO4_beta_2827                       {u'S': 1.0}               {u'S': 1.0}
# MgAl2O4_spinel_31373     {u'Mg': 1.0, u'Al': 3.0}                        {}
# Na2SO4_thenardite_2895                {u'S': 1.0}                        {}
# Sr2PbO4_16806                        {u'Pb': 2.0}              {u'Pb': 1.0}
#
#                                           JMolNN2                   JMolNN3  \
# BaAl2O4_21080                                  {}                        {}
# Be2SiO4_phenakite_64942              {u'Si': 1.0}              {u'Si': 1.0}
# CaB2O4_34641                                   {}                        {}
# CaFe2O4_166080           {u'Ca': 1.0, u'Fe': 3.0}  {u'Ca': 2.0, u'Fe': 3.0}
# Fe2SiO4_olivine_4353     {u'Si': 1.0, u'Fe': 3.0}                        {}
# K2NiF4_73450                                   {}                        {}
# K2SO4_beta_2827                       {u'S': 1.0}                        {}
# MgAl2O4_spinel_31373                           {}                        {}
# Na2SO4_thenardite_2895                         {}                        {}
# Sr2PbO4_16806                                  {}                        {}
#
#                                MinimumDistanceNN0        MinimumDistanceNN1  \
# BaAl2O4_21080                        {u'Al': 2.0}              {u'Al': 2.0}
# Be2SiO4_phenakite_64942  {u'Be': 2.0, u'Si': 1.0}  {u'Be': 2.0, u'Si': 1.0}
# CaB2O4_34641                          {u'B': 1.0}               {u'B': 2.0}
# CaFe2O4_166080                       {u'Fe': 3.0}              {u'Fe': 3.0}
# Fe2SiO4_olivine_4353                 {u'Si': 1.0}              {u'Si': 1.0}
# K2NiF4_73450                         {u'Ni': 2.0}              {u'Ni': 1.0}
# K2SO4_beta_2827                       {u'S': 1.0}               {u'S': 1.0}
# MgAl2O4_spinel_31373     {u'Mg': 1.0, u'Al': 3.0}                        {}
# Na2SO4_thenardite_2895                {u'S': 1.0}                        {}
# Sr2PbO4_16806                        {u'Pb': 2.0}              {u'Pb': 1.0}
#
#                                MinimumDistanceNN2        MinimumDistanceNN3  \
# BaAl2O4_21080                                  {}                        {}
# Be2SiO4_phenakite_64942  {u'Be': 2.0, u'Si': 1.0}  {u'Be': 2.0, u'Si': 1.0}
# CaB2O4_34641                                   {}                        {}
# CaFe2O4_166080                       {u'Fe': 3.0}              {u'Fe': 3.0}
# Fe2SiO4_olivine_4353                 {u'Si': 1.0}                        {}
# K2NiF4_73450                                   {}                        {}
# K2SO4_beta_2827                       {u'S': 1.0}                        {}
# MgAl2O4_spinel_31373                           {}                        {}
# Na2SO4_thenardite_2895                         {}                        {}
# Sr2PbO4_16806                                  {}                        {}
#
#                                 MinimumOKeeffeNN0         MinimumOKeeffeNN1  \
# BaAl2O4_21080                        {u'Al': 2.0}              {u'Al': 2.0}
# Be2SiO4_phenakite_64942              {u'Si': 1.0}              {u'Si': 1.0}
# CaB2O4_34641                          {u'B': 1.0}               {u'B': 2.0}
# CaFe2O4_166080           {u'Ca': 2.0, u'Fe': 3.0}  {u'Ca': 2.0, u'Fe': 3.0}
# Fe2SiO4_olivine_4353                 {u'Si': 1.0}              {u'Si': 1.0}
# K2NiF4_73450              {u'Ni': 2.0, u'K': 4.0}   {u'Ni': 1.0, u'K': 5.0}
# K2SO4_beta_2827                       {u'S': 1.0}               {u'S': 1.0}
# MgAl2O4_spinel_31373     {u'Mg': 1.0, u'Al': 3.0}                        {}
# Na2SO4_thenardite_2895                {u'S': 1.0}                        {}
# Sr2PbO4_16806                        {u'Pb': 2.0}              {u'Pb': 1.0}
#
#                         MinimumOKeeffeNN2         MinimumOKeeffeNN3  \
# BaAl2O4_21080                          {}                        {}
# Be2SiO4_phenakite_64942      {u'Si': 1.0}              {u'Si': 1.0}
# CaB2O4_34641                           {}                        {}
# CaFe2O4_166080               {u'Fe': 3.0}  {u'Ca': 2.0, u'Fe': 3.0}
# Fe2SiO4_olivine_4353         {u'Si': 1.0}                        {}
# K2NiF4_73450                           {}                        {}
# K2SO4_beta_2827               {u'S': 1.0}                        {}
# MgAl2O4_spinel_31373                   {}                        {}
# Na2SO4_thenardite_2895                 {}                        {}
# Sr2PbO4_16806                          {}                        {}
#
#                                    MinimumVIRENN0            MinimumVIRENN1  \
# BaAl2O4_21080                        {u'Al': 2.0}  {u'Ba': 2.0, u'Al': 2.0}
# Be2SiO4_phenakite_64942  {u'Be': 2.0, u'Si': 1.0}  {u'Be': 2.0, u'Si': 1.0}
# CaB2O4_34641                          {u'B': 1.0}               {u'B': 2.0}
# CaFe2O4_166080           {u'Ca': 2.0, u'Fe': 3.0}  {u'Ca': 2.0, u'Fe': 3.0}
# Fe2SiO4_olivine_4353     {u'Si': 1.0, u'Fe': 3.0}  {u'Si': 1.0, u'Fe': 3.0}
# K2NiF4_73450              {u'Ni': 2.0, u'K': 4.0}               {u'K': 5.0}
# K2SO4_beta_2827            {u'K': 1.0, u'S': 1.0}    {u'K': 2.0, u'S': 1.0}
# MgAl2O4_spinel_31373                 {u'Mg': 1.0}                        {}
# Na2SO4_thenardite_2895    {u'Na': 3.0, u'S': 1.0}                        {}
# Sr2PbO4_16806            {u'Pb': 2.0, u'Sr': 2.0}  {u'Pb': 1.0, u'Sr': 4.0}
#
#                                    MinimumVIRENN2            MinimumVIRENN3  \
# BaAl2O4_21080                                  {}                        {}
# Be2SiO4_phenakite_64942  {u'Be': 2.0, u'Si': 1.0}  {u'Be': 2.0, u'Si': 1.0}
# CaB2O4_34641                                   {}                        {}
# CaFe2O4_166080           {u'Ca': 2.0, u'Fe': 3.0}  {u'Ca': 2.0, u'Fe': 3.0}
# Fe2SiO4_olivine_4353     {u'Si': 1.0, u'Fe': 2.0}                        {}
# K2NiF4_73450                                   {}                        {}
# K2SO4_beta_2827            {u'K': 2.0, u'S': 1.0}                        {}
# MgAl2O4_spinel_31373                           {}                        {}
# Na2SO4_thenardite_2895                         {}                        {}
# Sr2PbO4_16806                                  {}                        {}
#
#                                        VoronoiNN0                VoronoiNN1  \
# BaAl2O4_21080                        {u'Al': 2.0}              {u'Al': 2.0}
# Be2SiO4_phenakite_64942  {u'Be': 2.0, u'Si': 1.0}  {u'Be': 2.0, u'Si': 1.0}
# CaB2O4_34641              {u'Ca': 1.0, u'B': 1.0}               {u'B': 2.0}
# CaFe2O4_166080           {u'Ca': 2.0, u'Fe': 3.0}  {u'Ca': 2.0, u'Fe': 3.0}
# Fe2SiO4_olivine_4353     {u'Si': 1.0, u'Fe': 3.0}  {u'Si': 1.0, u'Fe': 3.0}
# K2NiF4_73450              {u'Ni': 2.0, u'K': 4.0}   {u'Ni': 1.0, u'K': 5.0}
# K2SO4_beta_2827            {u'S': 1.0, u'K': 1.0}    {u'S': 1.0, u'K': 1.0}
# MgAl2O4_spinel_31373     {u'Mg': 1.0, u'Al': 3.0}                        {}
# Na2SO4_thenardite_2895    {u'Na': 2.0, u'S': 1.0}                        {}
# Sr2PbO4_16806            {u'Pb': 2.0, u'Sr': 3.0}  {u'Pb': 1.0, u'Sr': 4.0}
#
#                                        VoronoiNN2                VoronoiNN3
# BaAl2O4_21080                                  {}                        {}
# Be2SiO4_phenakite_64942  {u'Be': 2.0, u'Si': 1.0}  {u'Be': 2.0, u'Si': 1.0}
# CaB2O4_34641                                   {}                        {}
# CaFe2O4_166080           {u'Ca': 2.0, u'Fe': 3.0}  {u'Ca': 2.0, u'Fe': 3.0}
# Fe2SiO4_olivine_4353     {u'Si': 1.0, u'Fe': 3.0}                        {}
# K2NiF4_73450                                   {}                        {}
# K2SO4_beta_2827            {u'S': 1.0, u'K': 1.0}                        {}
# MgAl2O4_spinel_31373                           {}                        {}
# Na2SO4_thenardite_2895                         {}                        {}
# Sr2PbO4_16806                                  {}                        {}

# %%
df = preset.score(methods)
df
# Out:
#                          BrunnerNN_reciprocal  CrystalNN  EconNN  JMolNN  \
# BaAl2O4_21080                             0.0        0.0     0.0    0.00
# Be2SiO4_phenakite_64942                   0.0        0.0     0.0    2.00
# CaB2O4_34641                              3.5        3.5     3.5    3.50
# CaFe2O4_166080                            2.0        0.0     0.0    0.75
# Fe2SiO4_olivine_4353                      3.0        0.0     0.0    0.00
# K2NiF4_73450                              4.5        0.0     0.0    4.50
# K2SO4_beta_2827                           5.0        5.0     5.0    5.00
# MgAl2O4_spinel_31373                      0.0        0.0     0.0    0.00
# Na2SO4_thenardite_2895                    3.0        0.0     3.0    3.00
# Sr2PbO4_16806                             3.5        0.0     0.0    3.50
# Total                                    24.5        8.5    11.5   22.25
#
#                          MinimumDistanceNN  MinimumOKeeffeNN  MinimumVIRENN  \
# BaAl2O4_21080                          0.0               0.0           1.50
# Be2SiO4_phenakite_64942                0.0               2.0           0.00
# CaB2O4_34641                           3.5               3.5           3.50
# CaFe2O4_166080                         2.0               0.5           0.00
# Fe2SiO4_olivine_4353                   3.0               3.0           0.50
# K2NiF4_73450                           4.5               0.0           0.50
# K2SO4_beta_2827                        5.0               5.0           3.25
# MgAl2O4_spinel_31373                   0.0               0.0           3.00
# Na2SO4_thenardite_2895                 3.0               3.0           0.00
# Sr2PbO4_16806                          3.5               3.5           0.50
# Total                                 24.5              20.5          12.75
#
#                          VoronoiNN
# BaAl2O4_21080                  0.0
# Be2SiO4_phenakite_64942        0.0
# CaB2O4_34641                   3.0
# CaFe2O4_166080                 0.0
# Fe2SiO4_olivine_4353           0.0
# K2NiF4_73450                   0.0
# K2SO4_beta_2827                4.0
# MgAl2O4_spinel_31373           0.0
# Na2SO4_thenardite_2895         1.0
# Sr2PbO4_16806                  0.0
# Total                          8.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 10))

sns.set(font='Times New Roman')
sns.set(font_scale=1.5)

hm = sns.heatmap(df, annot=True, cmap="BuPu", vmax=10)

ax.set_xticklabels(df.columns.tolist(), rotation=60)
ax.set_yticklabels(df.index.tolist())

plt.savefig('cation_anion.png')
plt.show()
