# %%
import pandas as pd
pd.set_option("display.max_columns",999) # display all columns
pd.set_option("display.max_rows", 999)

from pymatgen.analysis.local_env import BrunnerNN_reciprocal, BrunnerNN_relative, BrunnerNN_real, EconNN, JMolNN, \
                                        MinimumDistanceNN, MinimumOKeeffeNN, MinimumVIRENN, \
                                        VoronoiNN, VoronoiNN_modified, CrystalNN
from materialscoord.core import Benchmark, HumanInterpreter, NbFuncs

methods = [BrunnerNN_reciprocal(), BrunnerNN_relative(), BrunnerNN_real(), 
           EconNN(), JMolNN(), MinimumDistanceNN(), MinimumOKeeffeNN(), 
           VoronoiNN(), VoronoiNN_modified(), CrystalNN(), HumanInterpreter()]
structure_groups = ["common_binaries"]
bm = Benchmark(methods=methods, structure_groups=structure_groups, unique_sites=True,
               use_weights=False, cation_anion=True, anion_cation=False)
bm.benchmark()
# Out:
# /Users/hillarypan/AJResearch/cn_routines/codes/pymatgen/pymatgen/__init__.py:87: UserWarning:
# Pymatgen will drop Py2k support from v2019.1.1. Pls consult the documentation
# at https://www.pymatgen.org for more details.
#   at https://www.pymatgen.org for more details.""")
# Initialization successful.
# [(u'Zn', {u'S': 4.0})]
# [(u'Ca', {u'F': 8.0})]
# [(u'Zn', {u'Zn': 6.0, u'Cu': 6.0}), (u'Zn', {u'Zn': 5.0, u'Cu': 6.0}), (u'Cu', {u'Zn': 9.0, u'Cu': 3.0}), (u'Cu', {u'Zn': 10.0, u'Cu': 3.0})]
# [(u'Ti', {u'O': 6.0})]
# [(u'Na', {u'Cl': 6.0})]
# [(u'Al', {u'O': 6.0})]
# [(u'Fe', {u'O': 6.0}), (u'Fe', {u'O': 4.0})]
# [(u'Zn', {u'S': 4.0})]
# [(u'Cs', {u'Cl': 8.0})]
# [(u'Zn', {u'S': 2.0})]
# [(u'Ca', {u'F': 8.0})]
# [(u'Zn', {u'Cu': 3.0}), (u'Zn', {u'Zn': 7.0, u'Cu': 6.0}), (u'Cu', {u'Zn': 3.0}), (u'Cu', {u'Zn': 2.0})]
# [(u'Ti', {u'O': 4.0})]
# [(u'Na', {u'Cl': 6.0})]
# [(u'Al', {u'O': 3.0})]
# [(u'Fe', {u'O': 6.0}), (u'Fe', {u'O': 4.0})]
# [(u'Zn', {u'S': 4.0})]
# [(u'Cs', {u'Cl': 8.0})]
# [(u'Zn', {u'S': 2.0})]
# [(u'Ca', {u'F': 8.0})]
# [(u'Zn', {u'Cu': 3.0}), (u'Zn', {u'Zn': 7.0, u'Cu': 6.0}), (u'Cu', {u'Zn': 3.0}), (u'Cu', {u'Zn': 2.0})]
# [(u'Ti', {u'O': 4.0})]
# [(u'Na', {u'Cl': 6.0})]
# [(u'Al', {u'O': 3.0})]
# [(u'Fe', {u'O': 6.0}), (u'Fe', {u'O': 4.0})]
# [(u'Zn', {u'S': 4.0})]
# [(u'Cs', {u'Cl': 8.0})]
# [(u'Zn', {u'S': 4.0})]
# [(u'Ca', {u'F': 8.0})]
# [(u'Zn', {u'Zn': 6.0, u'Cu': 7.0}), (u'Zn', {u'Zn': 9.0, u'Cu': 6.0}), (u'Cu', {u'Zn': 10.0, u'Cu': 3.0}), (u'Cu', {u'Zn': 10.0, u'Cu': 3.0})]
# [(u'Ti', {u'O': 6.0})]
# [(u'Na', {u'Cl': 6.0})]
# [(u'Al', {u'O': 6.0})]
# [(u'Fe', {u'O': 6.0}), (u'Fe', {u'O': 4.0})]
# [(u'Zn', {u'S': 4.0})]
# [(u'Cs', {u'Cl': 8.0})]
# [(u'Zn', {u'S': 4.0})]
# [(u'Ca', {})]
# [(u'Zn', {u'Zn': 6.0, u'Cu': 7.0}), (u'Zn', {u'Zn': 7.0, u'Cu': 6.0}), (u'Cu', {u'Zn': 10.0, u'Cu': 3.0}), (u'Cu', {u'Zn': 10.0, u'Cu': 3.0})]
# [(u'Ti', {u'O': 6.0})]
# [(u'Na', {})]
# [(u'Al', {u'O': 6.0})]
# [(u'Fe', {u'O': 6.0}), (u'Fe', {u'O': 4.0})]
# [(u'Zn', {u'S': 4.0})]
# [(u'Cs', {})]
# [(u'Zn', {u'S': 4.0})]
# [(u'Ca', {u'F': 8.0})]
# [(u'Zn', {u'Zn': 6.0, u'Cu': 6.0}), (u'Zn', {u'Zn': 5.0, u'Cu': 3.0}), (u'Cu', {u'Zn': 9.0, u'Cu': 3.0}), (u'Cu', {u'Zn': 4.0, u'Cu': 3.0})]
# [(u'Ti', {u'O': 6.0})]
# [(u'Na', {u'Cl': 6.0})]
# [(u'Al', {u'O': 6.0})]
# [(u'Fe', {u'O': 6.0}), (u'Fe', {u'O': 4.0})]
# [(u'Zn', {u'S': 4.0})]
# [(u'Cs', {u'Cl': 8.0})]
# [(u'Zn', {u'S': 4.0})]
# [(u'Ca', {u'F': 8.0})]
# [(u'Zn', {u'Zn': 6.0, u'Cu': 6.0}), (u'Zn', {u'Zn': 5.0, u'Cu': 3.0}), (u'Cu', {u'Zn': 9.0}), (u'Cu', {u'Zn': 4.0})]
# [(u'Ti', {u'O': 6.0})]
# [(u'Na', {u'Cl': 6.0})]
# [(u'Al', {u'O': 6.0})]
# [(u'Fe', {u'O': 6.0}), (u'Fe', {u'O': 4.0})]
# [(u'Zn', {u'S': 4.0})]
# [(u'Cs', {})]
# [(u'Zn', {u'S': 6.0})]
# [(u'Ca', {u'F': 8.0})]
# [(u'Zn', {u'Zn': 6.0, u'Cu': 7.0}), (u'Zn', {u'Zn': 9.0, u'Cu': 6.0}), (u'Cu', {u'Zn': 10.0, u'Cu': 3.0}), (u'Cu', {u'Zn': 10.0, u'Cu': 3.0})]
# [(u'Ti', {u'O': 6.0})]
# [(u'Na', {u'Cl': 6.0})]
# [(u'Al', {u'O': 12.0})]
# [(u'Fe', {u'O': 6.0}), (u'Fe', {u'O': 16.0})]
# [(u'Zn', {u'S': 4.0})]
# [(u'Cs', {u'Cl': 8.0})]
# [(u'Zn', {u'S': 4.0})]
# [(u'Ca', {u'F': 8.0})]
# [(u'Zn', {u'Zn': 6.0, u'Cu': 6.0}), (u'Zn', {u'Zn': 5.0, u'Cu': 6.0}), (u'Cu', {u'Zn': 9.0, u'Cu': 3.0}), (u'Cu', {u'Zn': 10.0, u'Cu': 3.0})]
# [(u'Ti', {u'O': 6.0})]
# [(u'Na', {u'Cl': 6.0})]
# [(u'Al', {u'O': 6.0})]
# [(u'Fe', {u'O': 6.0}), (u'Fe', {u'O': 4.0})]
# [(u'Zn', {u'S': 4.0})]
# [(u'Cs', {u'Cl': 8.0})]
# [(u'Zn', {u'S': 4.0})]
# [(u'Ca', {u'F': 8.0})]
# [(u'Zn', {u'Zn': 6.0, u'Cu': 6.0}), (u'Zn', {u'Zn': 5.0, u'Cu': 6.0}), (u'Cu', {u'Zn': 9.0}), (u'Cu', {u'Zn': 10.0, u'Cu': 3.0})]
# [(u'Ti', {u'O': 6.0})]
# [(u'Na', {u'Cl': 6.0})]
# [(u'Al', {u'O': 6.0})]
# [(u'Fe', {u'O': 6.0}), (u'Fe', {u'O': 4.0})]
# [(u'Zn', {u'S': 4.0})]
# [(u'Cs', {u'Cl': 8.0})]
# [(u'Zn', {'S': 4.0})]
# [(u'Ca', {'F': 8.0})]
# [(u'Zn', {'Zn': 6.0, 'Cu': 6.0}), (u'Zn', {'Zn': 5.0, 'Cu': 6.0}), (u'Cu', {'Zn': 9.0, 'Cu': 3.0}), (u'Cu', {'Zn': 10.0, 'Cu': 3.0})]
# [(u'Ti', {'O': 6.0})]
# [(u'Na', {'Cl': 6.0})]
# [(u'Al', {'O': 6.0})]
# [(u'Fe', {'O': 4.0}), (u'Fe', {'O': 6.0})]
# [(u'Zn', {'S': 4.0})]
# [(u'Cs', {'Cl': 8.0})]
# 4

# %%
report = bm.report()
report
# Out:
#                         BrunnerNN_real0           BrunnerNN_real1  \
# Al2O3_corundum_9770         {u'O': 3.0}                        {}
# CaF2_fluorite_60559         {u'F': 8.0}                        {}
# CsCl_53847                 {u'Cl': 8.0}                        {}
# Cu5Zn8_gamma_brass_2092    {u'Cu': 3.0}  {u'Zn': 7.0, u'Cu': 6.0}
# Fe3O4_spinel_26410          {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633       {u'Cl': 6.0}                        {}
# TiO2_anatase_9852           {u'O': 4.0}                        {}
# ZnS_wurtzite_67453          {u'S': 2.0}                        {}
# ZnS_zincblende_651455       {u'S': 4.0}                        {}
#
#                         BrunnerNN_real2 BrunnerNN_real3  \
# Al2O3_corundum_9770                  {}              {}
# CaF2_fluorite_60559                  {}              {}
# CsCl_53847                           {}              {}
# Cu5Zn8_gamma_brass_2092    {u'Zn': 3.0}    {u'Zn': 2.0}
# Fe3O4_spinel_26410                   {}              {}
# NaCl_rocksalt_100633                 {}              {}
# TiO2_anatase_9852                    {}              {}
# ZnS_wurtzite_67453                   {}              {}
# ZnS_zincblende_651455                {}              {}
#
#                             BrunnerNN_reciprocal0     BrunnerNN_reciprocal1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CaF2_fluorite_60559                   {u'F': 8.0}                        {}
# CsCl_53847                           {u'Cl': 8.0}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 6.0}  {u'Zn': 5.0, u'Cu': 6.0}
# Fe3O4_spinel_26410                    {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}                        {}
# TiO2_anatase_9852                     {u'O': 6.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
# ZnS_zincblende_651455                 {u'S': 4.0}                        {}
#
#                             BrunnerNN_reciprocal2      BrunnerNN_reciprocal3  \
# Al2O3_corundum_9770                            {}                         {}
# CaF2_fluorite_60559                            {}                         {}
# CsCl_53847                                     {}                         {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 9.0, u'Cu': 3.0}  {u'Zn': 10.0, u'Cu': 3.0}
# Fe3O4_spinel_26410                             {}                         {}
# NaCl_rocksalt_100633                           {}                         {}
# TiO2_anatase_9852                              {}                         {}
# ZnS_wurtzite_67453                             {}                         {}
# ZnS_zincblende_651455                          {}                         {}
#
#                         BrunnerNN_relative0       BrunnerNN_relative1  \
# Al2O3_corundum_9770             {u'O': 3.0}                        {}
# CaF2_fluorite_60559             {u'F': 8.0}                        {}
# CsCl_53847                     {u'Cl': 8.0}                        {}
# Cu5Zn8_gamma_brass_2092        {u'Cu': 3.0}  {u'Zn': 7.0, u'Cu': 6.0}
# Fe3O4_spinel_26410              {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633           {u'Cl': 6.0}                        {}
# TiO2_anatase_9852               {u'O': 4.0}                        {}
# ZnS_wurtzite_67453              {u'S': 2.0}                        {}
# ZnS_zincblende_651455           {u'S': 4.0}                        {}
#
#                         BrunnerNN_relative2 BrunnerNN_relative3  \
# Al2O3_corundum_9770                      {}                  {}
# CaF2_fluorite_60559                      {}                  {}
# CsCl_53847                               {}                  {}
# Cu5Zn8_gamma_brass_2092        {u'Zn': 3.0}        {u'Zn': 2.0}
# Fe3O4_spinel_26410                       {}                  {}
# NaCl_rocksalt_100633                     {}                  {}
# TiO2_anatase_9852                        {}                  {}
# ZnS_wurtzite_67453                       {}                  {}
# ZnS_zincblende_651455                    {}                  {}
#
#                                        CrystalNN0                CrystalNN1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CaF2_fluorite_60559                   {u'F': 8.0}                        {}
# CsCl_53847                           {u'Cl': 8.0}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 6.0}  {u'Zn': 5.0, u'Cu': 6.0}
# Fe3O4_spinel_26410                    {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}                        {}
# TiO2_anatase_9852                     {u'O': 6.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
# ZnS_zincblende_651455                 {u'S': 4.0}                        {}
#
#                            CrystalNN2                 CrystalNN3  \
# Al2O3_corundum_9770                {}                         {}
# CaF2_fluorite_60559                {}                         {}
# CsCl_53847                         {}                         {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 9.0}  {u'Zn': 10.0, u'Cu': 3.0}
# Fe3O4_spinel_26410                 {}                         {}
# NaCl_rocksalt_100633               {}                         {}
# TiO2_anatase_9852                  {}                         {}
# ZnS_wurtzite_67453                 {}                         {}
# ZnS_zincblende_651455              {}                         {}
#
#                                           EconNN0                   EconNN1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CaF2_fluorite_60559                   {u'F': 8.0}                        {}
# CsCl_53847                           {u'Cl': 8.0}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 7.0}  {u'Zn': 9.0, u'Cu': 6.0}
# Fe3O4_spinel_26410                    {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}                        {}
# TiO2_anatase_9852                     {u'O': 6.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
# ZnS_zincblende_651455                 {u'S': 4.0}                        {}
#
#                                            EconNN2                    EconNN3  \
# Al2O3_corundum_9770                             {}                         {}
# CaF2_fluorite_60559                             {}                         {}
# CsCl_53847                                      {}                         {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 10.0, u'Cu': 3.0}  {u'Zn': 10.0, u'Cu': 3.0}
# Fe3O4_spinel_26410                              {}                         {}
# NaCl_rocksalt_100633                            {}                         {}
# TiO2_anatase_9852                               {}                         {}
# ZnS_wurtzite_67453                              {}                         {}
# ZnS_zincblende_651455                           {}                         {}
#
#                                 HumanInterpreter0         HumanInterpreter1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CaF2_fluorite_60559                   {u'F': 8.0}                        {}
# CsCl_53847                           {u'Cl': 8.0}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 6.0}  {u'Zn': 5.0, u'Cu': 6.0}
# Fe3O4_spinel_26410                    {u'O': 4.0}               {u'O': 6.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}                        {}
# TiO2_anatase_9852                     {u'O': 6.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
# ZnS_zincblende_651455                 {u'S': 4.0}                        {}
#
#                                 HumanInterpreter2          HumanInterpreter3  \
# Al2O3_corundum_9770                            {}                         {}
# CaF2_fluorite_60559                            {}                         {}
# CsCl_53847                                     {}                         {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 9.0, u'Cu': 3.0}  {u'Zn': 10.0, u'Cu': 3.0}
# Fe3O4_spinel_26410                             {}                         {}
# NaCl_rocksalt_100633                           {}                         {}
# TiO2_anatase_9852                              {}                         {}
# ZnS_wurtzite_67453                             {}                         {}
# ZnS_zincblende_651455                          {}                         {}
#
#                                           JMolNN0                   JMolNN1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CaF2_fluorite_60559                            {}                        {}
# CsCl_53847                                     {}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 7.0}  {u'Zn': 7.0, u'Cu': 6.0}
# Fe3O4_spinel_26410                    {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633                           {}                        {}
# TiO2_anatase_9852                     {u'O': 6.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
# ZnS_zincblende_651455                 {u'S': 4.0}                        {}
#
#                                            JMolNN2                    JMolNN3  \
# Al2O3_corundum_9770                             {}                         {}
# CaF2_fluorite_60559                             {}                         {}
# CsCl_53847                                      {}                         {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 10.0, u'Cu': 3.0}  {u'Zn': 10.0, u'Cu': 3.0}
# Fe3O4_spinel_26410                              {}                         {}
# NaCl_rocksalt_100633                            {}                         {}
# TiO2_anatase_9852                               {}                         {}
# ZnS_wurtzite_67453                              {}                         {}
# ZnS_zincblende_651455                           {}                         {}
#
#                                MinimumDistanceNN0        MinimumDistanceNN1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CaF2_fluorite_60559                   {u'F': 8.0}                        {}
# CsCl_53847                           {u'Cl': 8.0}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 6.0}  {u'Zn': 5.0, u'Cu': 3.0}
# Fe3O4_spinel_26410                    {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}                        {}
# TiO2_anatase_9852                     {u'O': 6.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
# ZnS_zincblende_651455                 {u'S': 4.0}                        {}
#
#                                MinimumDistanceNN2        MinimumDistanceNN3  \
# Al2O3_corundum_9770                            {}                        {}
# CaF2_fluorite_60559                            {}                        {}
# CsCl_53847                                     {}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 9.0, u'Cu': 3.0}  {u'Zn': 4.0, u'Cu': 3.0}
# Fe3O4_spinel_26410                             {}                        {}
# NaCl_rocksalt_100633                           {}                        {}
# TiO2_anatase_9852                              {}                        {}
# ZnS_wurtzite_67453                             {}                        {}
# ZnS_zincblende_651455                          {}                        {}
#
#                                 MinimumOKeeffeNN0         MinimumOKeeffeNN1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CaF2_fluorite_60559                   {u'F': 8.0}                        {}
# CsCl_53847                                     {}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 6.0}  {u'Zn': 5.0, u'Cu': 3.0}
# Fe3O4_spinel_26410                    {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}                        {}
# TiO2_anatase_9852                     {u'O': 6.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
# ZnS_zincblende_651455                 {u'S': 4.0}                        {}
#
#                         MinimumOKeeffeNN2 MinimumOKeeffeNN3  \
# Al2O3_corundum_9770                    {}                {}
# CaF2_fluorite_60559                    {}                {}
# CsCl_53847                             {}                {}
# Cu5Zn8_gamma_brass_2092      {u'Zn': 9.0}      {u'Zn': 4.0}
# Fe3O4_spinel_26410                     {}                {}
# NaCl_rocksalt_100633                   {}                {}
# TiO2_anatase_9852                      {}                {}
# ZnS_wurtzite_67453                     {}                {}
# ZnS_zincblende_651455                  {}                {}
#
#                                        VoronoiNN0                VoronoiNN1  \
# Al2O3_corundum_9770                  {u'O': 12.0}                        {}
# CaF2_fluorite_60559                   {u'F': 8.0}                        {}
# CsCl_53847                           {u'Cl': 8.0}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 7.0}  {u'Zn': 9.0, u'Cu': 6.0}
# Fe3O4_spinel_26410                    {u'O': 6.0}              {u'O': 16.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}                        {}
# TiO2_anatase_9852                     {u'O': 6.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 6.0}                        {}
# ZnS_zincblende_651455                 {u'S': 4.0}                        {}
#
#                                         VoronoiNN2                 VoronoiNN3  \
# Al2O3_corundum_9770                             {}                         {}
# CaF2_fluorite_60559                             {}                         {}
# CsCl_53847                                      {}                         {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 10.0, u'Cu': 3.0}  {u'Zn': 10.0, u'Cu': 3.0}
# Fe3O4_spinel_26410                              {}                         {}
# NaCl_rocksalt_100633                            {}                         {}
# TiO2_anatase_9852                               {}                         {}
# ZnS_wurtzite_67453                              {}                         {}
# ZnS_zincblende_651455                           {}                         {}
#
#                               VoronoiNN_modified0       VoronoiNN_modified1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CaF2_fluorite_60559                   {u'F': 8.0}                        {}
# CsCl_53847                           {u'Cl': 8.0}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 6.0}  {u'Zn': 5.0, u'Cu': 6.0}
# Fe3O4_spinel_26410                    {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}                        {}
# TiO2_anatase_9852                     {u'O': 6.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
# ZnS_zincblende_651455                 {u'S': 4.0}                        {}
#
#                               VoronoiNN_modified2        VoronoiNN_modified3
# Al2O3_corundum_9770                            {}                         {}
# CaF2_fluorite_60559                            {}                         {}
# CsCl_53847                                     {}                         {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 9.0, u'Cu': 3.0}  {u'Zn': 10.0, u'Cu': 3.0}
# Fe3O4_spinel_26410                             {}                         {}
# NaCl_rocksalt_100633                           {}                         {}
# TiO2_anatase_9852                              {}                         {}
# ZnS_wurtzite_67453                             {}                         {}
# ZnS_zincblende_651455                          {}                         {}

# %%
nbf = NbFuncs(bm)
df = nbf.final()
df
# Out:
#                          BrunnerNN_real  BrunnerNN_reciprocal  \
# Al2O3_corundum_9770               3.000                   0.0
# CaF2_fluorite_60559               0.000                   0.0
# CsCl_53847                        0.000                   0.0
# Cu5Zn8_gamma_brass_2092           1.615                   0.0
# Fe3O4_spinel_26410                2.000                   2.0
# NaCl_rocksalt_100633              0.000                   0.0
# TiO2_anatase_9852                 2.000                   0.0
# ZnS_wurtzite_67453                2.000                   0.0
# ZnS_zincblende_651455             0.000                   0.0
# Total                            10.615                   2.0
#
#                          BrunnerNN_relative  CrystalNN  EconNN  JMolNN  \
# Al2O3_corundum_9770                   3.000      0.000   0.000   0.000
# CaF2_fluorite_60559                   0.000      0.000   0.000   8.000
# CsCl_53847                            0.000      0.000   0.000   8.000
# Cu5Zn8_gamma_brass_2092               1.615      0.462   0.154   0.154
# Fe3O4_spinel_26410                    2.000      2.000   2.000   2.000
# NaCl_rocksalt_100633                  0.000      0.000   0.000   6.000
# TiO2_anatase_9852                     2.000      0.000   0.000   0.000
# ZnS_wurtzite_67453                    2.000      0.000   0.000   0.000
# ZnS_zincblende_651455                 0.000      0.000   0.000   0.000
# Total                                10.615      2.462   2.154  24.154
#
#                          MinimumDistanceNN  MinimumOKeeffeNN  VoronoiNN  \
# Al2O3_corundum_9770                  0.000             0.000      6.000
# CaF2_fluorite_60559                  0.000             0.000      0.000
# CsCl_53847                           0.000             8.000      0.000
# Cu5Zn8_gamma_brass_2092              1.385             2.538      0.154
# Fe3O4_spinel_26410                   2.000             2.000      6.667
# NaCl_rocksalt_100633                 0.000             0.000      0.000
# TiO2_anatase_9852                    0.000             0.000      0.000
# ZnS_wurtzite_67453                   0.000             0.000      2.000
# ZnS_zincblende_651455                0.000             0.000      0.000
# Total                                3.385            12.538     14.821
#
#                          VoronoiNN_modified
# Al2O3_corundum_9770                     0.0
# CaF2_fluorite_60559                     0.0
# CsCl_53847                              0.0
# Cu5Zn8_gamma_brass_2092                 0.0
# Fe3O4_spinel_26410                      2.0
# NaCl_rocksalt_100633                    0.0
# TiO2_anatase_9852                       0.0
# ZnS_wurtzite_67453                      0.0
# ZnS_zincblende_651455                   0.0
# Total                                   2.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 12))

sns.set(font='Times New Roman')
sns.set(font_scale=1)

hm = sns.heatmap(df, annot=True, cmap="BuPu", vmax=10)

ax.set_xticklabels(df.columns.tolist(), rotation=45)
ax.set_yticklabels(df.index.tolist())

plt.savefig('common_binaries.png')
plt.show()
