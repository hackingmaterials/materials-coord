# %%
import pandas as pd
pd.set_option("display.max_columns",999) # display all columns
pd.set_option("display.max_rows", 999)

from pymatgen.analysis.local_env import BrunnerNN_reciprocal, BrunnerNN_relative, BrunnerNN_real, EconNN, JMolNN, \
                                        MinimumDistanceNN, MinimumOKeeffeNN, MinimumVIRENN, \
                                        VoronoiNN, VoronoiNN_modified, CrystalNN
from materialscoord.core import Benchmark, HumanInterpreter, NbFuncs

methods = [BrunnerNN_reciprocal(), BrunnerNN_relative(), BrunnerNN_real(), 
           EconNN(), JMolNN(), MinimumDistanceNN(), MinimumOKeeffeNN(), 
           VoronoiNN(), VoronoiNN_modified(), CrystalNN(), HumanInterpreter()]
#structure_groups = ["A2BX4", "ABX3", "ABX4", "common_binaries", "elemental", "laves", "mixed", "zeolites"]
structure_groups = ["elemental"]

bm = Benchmark(methods=methods, structure_groups=structure_groups, unique_sites=True,
               use_weights=False, cation_anion=True, anion_cation=False)
bm.benchmark()
# Out:
# /Users/hillarypan/AJResearch/cn_routines/codes/pymatgen/pymatgen/__init__.py:87: UserWarning:
# Pymatgen will drop Py2k support from v2019.1.1. Pls consult the documentation
# at https://www.pymatgen.org for more details.
#   at https://www.pymatgen.org for more details.""")
# Initialization successful.

# %%
report = bm.report()
report
# Out:
#                  BrunnerNN_real0 BrunnerNN_reciprocal0 BrunnerNN_relative0  \
# As_16518            {u'As': 3.0}          {u'As': 3.0}        {u'As': 3.0}
# C_diamond_52054      {u'C': 4.0}           {u'C': 4.0}         {u'C': 4.0}
# C_graphite_76767     {u'C': 9.0}           {u'C': 3.0}         {u'C': 9.0}
# Cu_52256           {u'Cu': 12.0}         {u'Cu': 12.0}       {u'Cu': 12.0}
# Ga_12174            {u'Ga': 4.0}         {u'Ga': 12.0}        {u'Ga': 4.0}
# Hg_104296           {u'Hg': 6.0}         {u'Hg': 12.0}        {u'Hg': 6.0}
# La_43573            {u'La': 2.0}         {u'La': 12.0}        {u'La': 2.0}
# Mg_52260            {u'Mg': 4.0}         {u'Mg': 12.0}        {u'Mg': 4.0}
# Mn_alpha_42743     {u'Mn': 12.0}         {u'Mn': 16.0}       {u'Mn': 12.0}
# Mn_beta_41775       {u'Mn': 6.0}         {u'Mn': 12.0}        {u'Mn': 6.0}
# P_black_23836        {u'P': 2.0}           {u'P': 3.0}         {u'P': 2.0}
# Se_gamma_23068      {u'Se': 6.0}          {u'Se': 2.0}        {u'Se': 6.0}
# Sm_76031            {u'Sm': 6.0}         {u'Sm': 12.0}        {u'Sm': 6.0}
# Sn_106072           {u'Sn': 4.0}          {u'Sn': 6.0}        {u'Sn': 4.0}
# U_alpha_16056        {u'U': 4.0}          {u'U': 16.0}         {u'U': 4.0}
# W_43667              {u'W': 8.0}          {u'W': 14.0}         {u'W': 8.0}
#
#                      CrystalNN0        EconNN0     HumanInterpreter0  \
# As_16518           {u'As': 3.0}  {u'As': 12.0}   {u'As': [3.0, 6.0]}
# C_diamond_52054     {u'C': 4.0}    {u'C': 4.0}           {u'C': 4.0}
# C_graphite_76767    {u'C': 3.0}    {u'C': 3.0}           {u'C': 3.0}
# Cu_52256          {u'Cu': 12.0}  {u'Cu': 18.0}         {u'Cu': 12.0}
# Ga_12174          {u'Ga': 12.0}  {u'Ga': 16.0}  {u'Ga': [4.0, 12.0]}
# Hg_104296          {u'Hg': 6.0}  {u'Hg': 12.0}          {u'Hg': 6.0}
# La_43573          {u'La': 12.0}  {u'La': 18.0}         {u'La': 12.0}
# Mg_52260          {u'Mg': 12.0}  {u'Mg': 18.0}         {u'Mg': 12.0}
# Mn_alpha_42743    {u'Mn': 16.0}  {u'Mn': 16.0}         {u'Mn': 16.0}
# Mn_beta_41775     {u'Mn': 12.0}  {u'Mn': 12.0}         {u'Mn': 12.0}
# P_black_23836       {u'P': 3.0}    {u'P': 3.0}           {u'P': 3.0}
# Se_gamma_23068     {u'Se': 2.0}   {u'Se': 6.0}          {u'Se': 3.0}
# Sm_76031          {u'Sm': 12.0}  {u'Sm': 18.0}         {u'Sm': 12.0}
# Sn_106072          {u'Sn': 6.0}  {u'Sn': 18.0}  {u'Sn': [6.0, 10.0]}
# U_alpha_16056      {u'U': 12.0}   {u'U': 16.0}   {u'U': [4.0, 12.0]}
# W_43667             {u'W': 8.0}   {u'W': 14.0}           {u'W': 8.0}
#
#                         JMolNN0 MinimumDistanceNN0 MinimumOKeeffeNN0  \
# As_16518           {u'As': 3.0}       {u'As': 3.0}      {u'As': 3.0}
# C_diamond_52054     {u'C': 4.0}        {u'C': 4.0}       {u'C': 4.0}
# C_graphite_76767    {u'C': 3.0}        {u'C': 3.0}       {u'C': 3.0}
# Cu_52256          {u'Cu': 12.0}      {u'Cu': 12.0}     {u'Cu': 12.0}
# Ga_12174          {u'Ga': 12.0}      {u'Ga': 12.0}     {u'Ga': 12.0}
# Hg_104296         {u'Hg': 12.0}       {u'Hg': 6.0}      {u'Hg': 6.0}
# La_43573          {u'La': 12.0}      {u'La': 12.0}     {u'La': 12.0}
# Mg_52260                     {}      {u'Mg': 12.0}     {u'Mg': 12.0}
# Mn_alpha_42743    {u'Mn': 16.0}      {u'Mn': 16.0}     {u'Mn': 16.0}
# Mn_beta_41775     {u'Mn': 12.0}       {u'Mn': 6.0}      {u'Mn': 6.0}
# P_black_23836                {}        {u'P': 3.0}       {u'P': 3.0}
# Se_gamma_23068     {u'Se': 2.0}       {u'Se': 2.0}      {u'Se': 2.0}
# Sm_76031          {u'Sm': 12.0}      {u'Sm': 12.0}     {u'Sm': 12.0}
# Sn_106072          {u'Sn': 6.0}       {u'Sn': 6.0}      {u'Sn': 6.0}
# U_alpha_16056      {u'U': 12.0}        {u'U': 4.0}       {u'U': 4.0}
# W_43667            {u'W': 14.0}        {u'W': 8.0}       {u'W': 8.0}
#
#                      VoronoiNN0 VoronoiNN_modified0
# As_16518          {u'As': 19.0}        {u'As': 6.0}
# C_diamond_52054    {u'C': 16.0}         {u'C': 4.0}
# C_graphite_76767   {u'C': 13.0}         {u'C': 3.0}
# Cu_52256          {u'Cu': 12.0}       {u'Cu': 12.0}
# Ga_12174          {u'Ga': 12.0}       {u'Ga': 12.0}
# Hg_104296         {u'Hg': 12.0}       {u'Hg': 12.0}
# La_43573          {u'La': 12.0}       {u'La': 12.0}
# Mg_52260          {u'Mg': 14.0}       {u'Mg': 12.0}
# Mn_alpha_42743    {u'Mn': 16.0}       {u'Mn': 16.0}
# Mn_beta_41775     {u'Mn': 12.0}       {u'Mn': 12.0}
# P_black_23836      {u'P': 15.0}         {u'P': 3.0}
# Se_gamma_23068    {u'Se': 16.0}        {u'Se': 6.0}
# Sm_76031          {u'Sm': 12.0}       {u'Sm': 12.0}
# Sn_106072         {u'Sn': 18.0}        {u'Sn': 6.0}
# U_alpha_16056      {u'U': 12.0}         {u'U': 4.0}
# W_43667            {u'W': 14.0}         {u'W': 8.0}

# %%
nbf = NbFuncs(bm)
df = nbf.final()
df
# Out:
#                   BrunnerNN_real  BrunnerNN_reciprocal  BrunnerNN_relative  \
# As_16518                   0.000                   0.0               0.000
# C_diamond_52054            0.000                   0.0               0.000
# C_graphite_76767           3.000                   0.0               3.000
# Cu_52256                   0.000                   0.0               0.000
# Ga_12174                   0.000                   0.0               0.000
# Hg_104296                  0.000                   6.0               0.000
# La_43573                   5.000                   0.0               5.000
# Mg_52260                   8.000                   0.0               8.000
# Mn_alpha_42743             0.138                   0.0               0.138
# Mn_beta_41775              2.400                   0.0               2.400
# P_black_23836              1.000                   0.0               1.000
# Se_gamma_23068             3.000                   1.0               3.000
# Sm_76031                   2.000                   0.0               2.000
# Sn_106072                  2.000                   0.0               2.000
# U_alpha_16056              0.000                   4.0               0.000
# W_43667                    0.000                   6.0               0.000
# Total                     26.538                  17.0              26.538
#
#                   CrystalNN  EconNN  JMolNN  MinimumDistanceNN  \
# As_16518                0.0     6.0     0.0                0.0
# C_diamond_52054         0.0     0.0     0.0                0.0
# C_graphite_76767        0.0     0.0     0.0                0.0
# Cu_52256                0.0     6.0     0.0                0.0
# Ga_12174                0.0     4.0     0.0                0.0
# Hg_104296               0.0     6.0     6.0                0.0
# La_43573                0.0     3.0     0.0                0.0
# Mg_52260                0.0     6.0    12.0                0.0
# Mn_alpha_42743          0.0     0.0     0.0                0.0
# Mn_beta_41775           0.0     0.0     0.0                2.4
# P_black_23836           0.0     0.0     3.0                0.0
# Se_gamma_23068          1.0     3.0     1.0                1.0
# Sm_76031                0.0     2.0     0.0                0.0
# Sn_106072               0.0     8.0     0.0                0.0
# U_alpha_16056           0.0     4.0     0.0                0.0
# W_43667                 0.0     6.0     6.0                0.0
# Total                   1.0    54.0    28.0                3.4
#
#                   MinimumOKeeffeNN  VoronoiNN  VoronoiNN_modified
# As_16518                       0.0       13.0                 0.0
# C_diamond_52054                0.0       12.0                 0.0
# C_graphite_76767               0.0        5.0                 0.0
# Cu_52256                       0.0        0.0                 0.0
# Ga_12174                       0.0        0.0                 0.0
# Hg_104296                      0.0       12.0                 6.0
# La_43573                       0.0        0.0                 0.0
# Mg_52260                       0.0        2.0                 0.0
# Mn_alpha_42743                 0.0        0.0                 0.0
# Mn_beta_41775                  2.4        0.0                 0.0
# P_black_23836                  0.0       12.0                 0.0
# Se_gamma_23068                 1.0       16.0                 3.0
# Sm_76031                       0.0        0.0                 0.0
# Sn_106072                      0.0        8.0                 0.0
# U_alpha_16056                  0.0        0.0                 0.0
# W_43667                        0.0        6.0                 0.0
# Total                          3.4       86.0                 9.0

# %%
test = nbf.total()
test
# Out:
#                   BrunnerNN_real  BrunnerNN_reciprocal  BrunnerNN_relative  \
# As_16518                     0.0                   0.0                 0.0
# C_diamond_52054              0.0                   0.0                 0.0
# C_graphite_76767            12.0                   0.0                12.0
# Cu_52256                     0.0                   0.0                 0.0
# Ga_12174                     0.0                   0.0                 0.0
# Hg_104296                    0.0                  18.0                 0.0
# La_43573                    20.0                   0.0                20.0
# Mg_52260                    16.0                   0.0                16.0
# Mn_alpha_42743               8.0                   0.0                 8.0
# Mn_beta_41775               48.0                   0.0                48.0
# P_black_23836                8.0                   0.0                 8.0
# Se_gamma_23068               9.0                   3.0                 9.0
# Sm_76031                    18.0                   0.0                18.0
# Sn_106072                    8.0                   0.0                 8.0
# U_alpha_16056                0.0                  16.0                 0.0
# W_43667                      0.0                  12.0                 0.0
#
#                   CrystalNN  EconNN  JMolNN  MinimumDistanceNN  \
# As_16518                0.0    36.0     0.0                0.0
# C_diamond_52054         0.0     0.0     0.0                0.0
# C_graphite_76767        0.0     0.0     0.0                0.0
# Cu_52256                0.0    24.0     0.0                0.0
# Ga_12174                0.0     8.0     0.0                0.0
# Hg_104296               0.0    18.0    18.0                0.0
# La_43573                0.0    12.0     0.0                0.0
# Mg_52260                0.0    12.0    24.0                0.0
# Mn_alpha_42743          0.0     0.0     0.0                0.0
# Mn_beta_41775           0.0     0.0     0.0               48.0
# P_black_23836           0.0     0.0    24.0                0.0
# Se_gamma_23068          3.0     9.0     3.0                3.0
# Sm_76031                0.0    18.0     0.0                0.0
# Sn_106072               0.0    32.0     0.0                0.0
# U_alpha_16056           0.0    16.0     0.0                0.0
# W_43667                 0.0    12.0    12.0                0.0
#
#                   MinimumOKeeffeNN  VoronoiNN  VoronoiNN_modified
# As_16518                       0.0       78.0                 0.0
# C_diamond_52054                0.0       96.0                 0.0
# C_graphite_76767               0.0       20.0                 0.0
# Cu_52256                       0.0        0.0                 0.0
# Ga_12174                       0.0        0.0                 0.0
# Hg_104296                      0.0       36.0                18.0
# La_43573                       0.0        0.0                 0.0
# Mg_52260                       0.0        4.0                 0.0
# Mn_alpha_42743                 0.0        0.0                 0.0
# Mn_beta_41775                 48.0        0.0                 0.0
# P_black_23836                  0.0       96.0                 0.0
# Se_gamma_23068                 3.0       48.0                 9.0
# Sm_76031                       0.0        0.0                 0.0
# Sn_106072                      0.0       32.0                 0.0
# U_alpha_16056                  0.0        0.0                 0.0
# W_43667                        0.0       12.0                 0.0

# %%
test.shape
# Out:
# (16, 10)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 15))

sns.set(font='Times New Roman')
sns.set(font_scale=1)

hm = sns.heatmap(df, annot=True, cmap="BuPu", vmax=10)

ax.set_xticklabels(df.columns.tolist(), rotation=60)
ax.set_yticklabels(df.index.tolist())

plt.savefig('cation_anion.png')
plt.show()
