# %%
import pandas as pd
pd.set_option("display.max_columns",999) # display all columns
pd.set_option("display.max_rows", 999)

from pymatgen.analysis.local_env import BrunnerNN_reciprocal, BrunnerNN_relative, BrunnerNN_real, EconNN, JMolNN, \
                                        MinimumDistanceNN, MinimumOKeeffeNN, MinimumVIRENN, \
                                        VoronoiNN, VoronoiNN_modified, CrystalNN
from materialscoord.core import Benchmark, HumanInterpreter, NbFuncs

methods = [BrunnerNN_reciprocal(), BrunnerNN_relative(), BrunnerNN_real(), 
           EconNN(), JMolNN(), MinimumDistanceNN(), MinimumOKeeffeNN(), 
           VoronoiNN(), VoronoiNN_modified(), CrystalNN(), HumanInterpreter()]
structure_groups = ["mixed"]
bm = Benchmark(methods=methods, structure_groups=structure_groups, unique_sites=True,
               use_weights=False, cation_anion=True, anion_cation=False)
bm.benchmark()
# Out:
# /Users/hillarypan/AJResearch/cn_routines/codes/pymatgen/pymatgen/__init__.py:87: UserWarning:
# Pymatgen will drop Py2k support from v2019.1.1. Pls consult the documentation
# at https://www.pymatgen.org for more details.
#   at https://www.pymatgen.org for more details.""")
# Initialization successful.

# %%
report = bm.report()
report
# Out:
#                                     BrunnerNN_real0          BrunnerNN_real1  \
# Ca2MgSi2O7_melilite_50065               {u'O': 8.0}              {u'O': 4.0}
# Ca5V3O12F_apatite_172997    {u'F': 3.0, u'O': 62.0}  {u'F': 3.0, u'O': 61.0}
# CuSbPbS3_buornonite_182267             {u'S': 32.0}              {u'S': 3.0}
# Y3Al5O12_garnet_93634                   {u'O': 4.0}              {u'O': 6.0}
#
#                                     BrunnerNN_real2          BrunnerNN_real3  \
# Ca2MgSi2O7_melilite_50065               {u'O': 4.0}                       {}
# Ca5V3O12F_apatite_172997    {u'F': 3.0, u'O': 63.0}  {u'F': 6.0, u'O': 59.0}
# CuSbPbS3_buornonite_182267              {u'S': 3.0}              {u'S': 8.0}
# Y3Al5O12_garnet_93634                   {u'O': 4.0}                       {}
#
#                                     BrunnerNN_real4   BrunnerNN_reciprocal0  \
# Ca2MgSi2O7_melilite_50065                        {}             {u'O': 8.0}
# Ca5V3O12F_apatite_172997    {u'F': 6.0, u'O': 60.0}  {u'O': 5.0, u'F': 1.0}
# CuSbPbS3_buornonite_182267              {u'S': 3.0}             {u'S': 4.0}
# Y3Al5O12_garnet_93634                            {}             {u'O': 8.0}
#
#                              BrunnerNN_reciprocal1   BrunnerNN_reciprocal2  \
# Ca2MgSi2O7_melilite_50065              {u'O': 4.0}             {u'O': 4.0}
# Ca5V3O12F_apatite_172997    {u'O': 6.0, u'F': 1.0}  {u'O': 6.0, u'F': 1.0}
# CuSbPbS3_buornonite_182267             {u'S': 3.0}             {u'S': 3.0}
# Y3Al5O12_garnet_93634                  {u'O': 6.0}             {u'O': 4.0}
#
#                            BrunnerNN_reciprocal3 BrunnerNN_reciprocal4  \
# Ca2MgSi2O7_melilite_50065                     {}                    {}
# Ca5V3O12F_apatite_172997             {u'O': 8.0}           {u'O': 8.0}
# CuSbPbS3_buornonite_182267           {u'S': 4.0}           {u'S': 1.0}
# Y3Al5O12_garnet_93634                         {}                    {}
#
#                                 BrunnerNN_relative0      BrunnerNN_relative1  \
# Ca2MgSi2O7_melilite_50065               {u'O': 8.0}              {u'O': 4.0}
# Ca5V3O12F_apatite_172997    {u'F': 3.0, u'O': 62.0}  {u'F': 3.0, u'O': 61.0}
# CuSbPbS3_buornonite_182267             {u'S': 32.0}              {u'S': 3.0}
# Y3Al5O12_garnet_93634                   {u'O': 4.0}              {u'O': 6.0}
#
#                                 BrunnerNN_relative2      BrunnerNN_relative3  \
# Ca2MgSi2O7_melilite_50065               {u'O': 4.0}                       {}
# Ca5V3O12F_apatite_172997    {u'F': 3.0, u'O': 63.0}  {u'F': 6.0, u'O': 59.0}
# CuSbPbS3_buornonite_182267              {u'S': 3.0}              {u'S': 8.0}
# Y3Al5O12_garnet_93634                   {u'O': 4.0}                       {}
#
#                                 BrunnerNN_relative4              CrystalNN0  \
# Ca2MgSi2O7_melilite_50065                        {}             {u'O': 8.0}
# Ca5V3O12F_apatite_172997    {u'F': 6.0, u'O': 60.0}  {u'O': 6.0, u'F': 1.0}
# CuSbPbS3_buornonite_182267              {u'S': 3.0}             {u'S': 4.0}
# Y3Al5O12_garnet_93634                            {}             {u'O': 8.0}
#
#                                         CrystalNN1              CrystalNN2  \
# Ca2MgSi2O7_melilite_50065              {u'O': 4.0}             {u'O': 4.0}
# Ca5V3O12F_apatite_172997    {u'O': 6.0, u'F': 1.0}  {u'O': 6.0, u'F': 1.0}
# CuSbPbS3_buornonite_182267             {u'S': 3.0}             {u'S': 3.0}
# Y3Al5O12_garnet_93634                  {u'O': 6.0}             {u'O': 4.0}
#
#                              CrystalNN3   CrystalNN4                 EconNN0  \
# Ca2MgSi2O7_melilite_50065            {}           {}             {u'O': 8.0}
# Ca5V3O12F_apatite_172997    {u'O': 8.0}  {u'O': 8.0}  {u'F': 1.0, u'O': 7.0}
# CuSbPbS3_buornonite_182267  {u'S': 4.0}  {u'S': 5.0}             {u'S': 4.0}
# Y3Al5O12_garnet_93634                {}           {}             {u'O': 8.0}
#
#                                            EconNN1                 EconNN2  \
# Ca2MgSi2O7_melilite_50065              {u'O': 4.0}             {u'O': 4.0}
# Ca5V3O12F_apatite_172997    {u'F': 1.0, u'O': 7.0}  {u'F': 1.0, u'O': 7.0}
# CuSbPbS3_buornonite_182267             {u'S': 4.0}             {u'S': 5.0}
# Y3Al5O12_garnet_93634                  {u'O': 6.0}             {u'O': 4.0}
#
#                                 EconNN3      EconNN4       HumanInterpreter0  \
# Ca2MgSi2O7_melilite_50065            {}           {}             {u'O': 8.0}
# Ca5V3O12F_apatite_172997    {u'O': 9.0}  {u'O': 9.0}  {u'O': 9.0, u'F': 0.0}
# CuSbPbS3_buornonite_182267  {u'S': 8.0}  {u'S': 8.0}             {u'S': 4.0}
# Y3Al5O12_garnet_93634                {}           {}             {u'O': 8.0}
#
#                                  HumanInterpreter1       HumanInterpreter2  \
# Ca2MgSi2O7_melilite_50065              {u'O': 4.0}             {u'O': 4.0}
# Ca5V3O12F_apatite_172997    {u'O': 6.0, u'F': 1.0}  {u'O': 4.0, u'F': 0.0}
# CuSbPbS3_buornonite_182267             {u'S': 3.0}             {u'S': 3.0}
# Y3Al5O12_garnet_93634                  {u'O': 6.0}             {u'O': 4.0}
#
#                                  HumanInterpreter3       HumanInterpreter4  \
# Ca2MgSi2O7_melilite_50065                       {}                      {}
# Ca5V3O12F_apatite_172997    {u'O': 0.0, u'F': 0.0}  {u'O': 0.0, u'F': 0.0}
# CuSbPbS3_buornonite_182267             {u'S': 8.0}             {u'S': 8.0}
# Y3Al5O12_garnet_93634                           {}                      {}
#
#                                 JMolNN0      JMolNN1      JMolNN2  \
# Ca2MgSi2O7_melilite_50065            {}  {u'O': 4.0}  {u'O': 4.0}
# Ca5V3O12F_apatite_172997             {}           {}           {}
# CuSbPbS3_buornonite_182267  {u'S': 4.0}  {u'S': 3.0}  {u'S': 3.0}
# Y3Al5O12_garnet_93634       {u'O': 8.0}  {u'O': 6.0}  {u'O': 4.0}
#
#                                 JMolNN3      JMolNN4      MinimumDistanceNN0  \
# Ca2MgSi2O7_melilite_50065            {}           {}             {u'O': 4.0}
# Ca5V3O12F_apatite_172997             {}           {}  {u'O': 5.0, u'F': 1.0}
# CuSbPbS3_buornonite_182267  {u'S': 4.0}  {u'S': 3.0}             {u'S': 3.0}
# Y3Al5O12_garnet_93634                {}           {}             {u'O': 8.0}
#
#                                 MinimumDistanceNN1      MinimumDistanceNN2  \
# Ca2MgSi2O7_melilite_50065              {u'O': 4.0}             {u'O': 4.0}
# Ca5V3O12F_apatite_172997    {u'O': 4.0, u'F': 1.0}  {u'O': 4.0, u'F': 1.0}
# CuSbPbS3_buornonite_182267             {u'S': 1.0}             {u'S': 1.0}
# Y3Al5O12_garnet_93634                  {u'O': 6.0}             {u'O': 4.0}
#
#                            MinimumDistanceNN3 MinimumDistanceNN4  \
# Ca2MgSi2O7_melilite_50065                  {}                 {}
# Ca5V3O12F_apatite_172997          {u'O': 5.0}        {u'O': 6.0}
# CuSbPbS3_buornonite_182267        {u'S': 1.0}        {u'S': 1.0}
# Y3Al5O12_garnet_93634                      {}                 {}
#
#                                  MinimumOKeeffeNN0       MinimumOKeeffeNN1  \
# Ca2MgSi2O7_melilite_50065              {u'O': 4.0}             {u'O': 4.0}
# Ca5V3O12F_apatite_172997    {u'F': 1.0, u'O': 5.0}  {u'F': 1.0, u'O': 4.0}
# CuSbPbS3_buornonite_182267             {u'S': 3.0}             {u'S': 1.0}
# Y3Al5O12_garnet_93634                  {u'O': 8.0}             {u'O': 6.0}
#
#                                  MinimumOKeeffeNN2 MinimumOKeeffeNN3  \
# Ca2MgSi2O7_melilite_50065              {u'O': 4.0}                {}
# Ca5V3O12F_apatite_172997    {u'F': 1.0, u'O': 4.0}       {u'O': 5.0}
# CuSbPbS3_buornonite_182267             {u'S': 1.0}       {u'S': 1.0}
# Y3Al5O12_garnet_93634                  {u'O': 4.0}                {}
#
#                            MinimumOKeeffeNN4              VoronoiNN0  \
# Ca2MgSi2O7_melilite_50065                 {}             {u'O': 9.0}
# Ca5V3O12F_apatite_172997         {u'O': 5.0}  {u'O': 9.0, u'F': 2.0}
# CuSbPbS3_buornonite_182267       {u'S': 1.0}             {u'S': 6.0}
# Y3Al5O12_garnet_93634                     {}             {u'O': 8.0}
#
#                                         VoronoiNN1              VoronoiNN2  \
# Ca2MgSi2O7_melilite_50065              {u'O': 8.0}            {u'O': 10.0}
# Ca5V3O12F_apatite_172997    {u'O': 9.0, u'F': 1.0}  {u'O': 9.0, u'F': 2.0}
# CuSbPbS3_buornonite_182267             {u'S': 8.0}             {u'S': 8.0}
# Y3Al5O12_garnet_93634                  {u'O': 6.0}            {u'O': 16.0}
#
#                               VoronoiNN3   VoronoiNN4     VoronoiNN_modified0  \
# Ca2MgSi2O7_melilite_50065             {}           {}             {u'O': 8.0}
# Ca5V3O12F_apatite_172997    {u'O': 10.0}  {u'O': 9.0}  {u'O': 6.0, u'F': 1.0}
# CuSbPbS3_buornonite_182267   {u'S': 8.0}  {u'S': 8.0}             {u'S': 4.0}
# Y3Al5O12_garnet_93634                 {}           {}             {u'O': 8.0}
#
#                                VoronoiNN_modified1     VoronoiNN_modified2  \
# Ca2MgSi2O7_melilite_50065              {u'O': 4.0}             {u'O': 4.0}
# Ca5V3O12F_apatite_172997    {u'O': 6.0, u'F': 1.0}  {u'O': 6.0, u'F': 1.0}
# CuSbPbS3_buornonite_182267             {u'S': 3.0}             {u'S': 3.0}
# Y3Al5O12_garnet_93634                  {u'O': 6.0}             {u'O': 4.0}
#
#                            VoronoiNN_modified3 VoronoiNN_modified4
# Ca2MgSi2O7_melilite_50065                   {}                  {}
# Ca5V3O12F_apatite_172997           {u'O': 8.0}         {u'O': 7.0}
# CuSbPbS3_buornonite_182267         {u'S': 4.0}         {u'S': 7.0}
# Y3Al5O12_garnet_93634                       {}                  {}

# %%
nbf = NbFuncs(bm)
df = nbf.final()
df
# Out:
#                             BrunnerNN_real  BrunnerNN_reciprocal  \
# Ca2MgSi2O7_melilite_50065            0.000                 0.000
# Ca5V3O12F_apatite_172997             2.500                 0.250
# CuSbPbS3_buornonite_182267          10.167                 1.833
# Y3Al5O12_garnet_93634                1.500                 0.000
# Total                               14.167                 2.083
#
#                             BrunnerNN_relative  CrystalNN  EconNN  JMolNN  \
# Ca2MgSi2O7_melilite_50065                0.000      0.000    0.00   3.200
# Ca5V3O12F_apatite_172997                 2.500      0.250    0.25   0.125
# CuSbPbS3_buornonite_182267              10.167      1.167    0.50   1.500
# Y3Al5O12_garnet_93634                    1.500      0.000    0.00   0.000
# Total                                   14.167      1.417    0.75   4.825
#
#                             MinimumDistanceNN  MinimumOKeeffeNN  VoronoiNN  \
# Ca2MgSi2O7_melilite_50065               1.600             1.600      3.600
# Ca5V3O12F_apatite_172997                0.250             0.250      0.750
# CuSbPbS3_buornonite_182267              3.333             3.333      3.167
# Y3Al5O12_garnet_93634                   0.000             0.000      4.500
# Total                                   5.183             5.183     12.017
#
#                             VoronoiNN_modified
# Ca2MgSi2O7_melilite_50065                0.000
# Ca5V3O12F_apatite_172997                 0.250
# CuSbPbS3_buornonite_182267               0.833
# Y3Al5O12_garnet_93634                    0.000
# Total                                    1.083

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 5))

sns.set(font='Times New Roman')
sns.set(font_scale=1)

hm = sns.heatmap(df, annot=True, cmap="BuPu", vmax=10)

ax.set_xticklabels(df.columns.tolist(), rotation=45)
ax.set_yticklabels(df.index.tolist())

plt.savefig('mixed.png')
plt.show()
