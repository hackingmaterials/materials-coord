# %%
import pandas as pd
pd.set_option("display.max_columns",999) # display all columns
pd.set_option("display.max_rows", 999)

from pymatgen.analysis.local_env import BrunnerNN_reciprocal, EconNN, JmolNN, \
                                        MinimumDistanceNN, MinimumOKeeffeNN, MinimumVIRENN, \
                                        VoronoiNN, VoronoiNN_modified, CrystalNN
from materialscoord.core import Benchmark, HumanInterpreter

methods = [MinimumDistanceNN(),  MinimumOKeeffeNN(), MinimumVIRENN(), JmolNN(), EconNN(), 
           BrunnerNN_reciprocal(), VoronoiNN(tol=0.5), CrystalNN(), HumanInterpreter()]
structure_groups = ["common_binaries"]

preset = Benchmark.from_preset(preset_name=structure_groups)
preset.benchmark(methods=methods)
# Out:
# /Users/hillarypan/pymatgen/pymatgen/io/cif.py:37: UserWarning: Please install optional dependency pybtex if youwant to extract references from CIF files.
#   warnings.warn("Please install optional dependency pybtex if you"
# /Users/hillarypan/pymatgen/pymatgen/io/cif.py:1106: UserWarning: Issues encountered while parsing CIF:
#   warnings.warn("Issues encountered while parsing CIF:")
# /Users/hillarypan/pymatgen/pymatgen/io/cif.py:1108: UserWarning: Some fractional co-ordinates rounded to ideal values to avoid finite precision errors.
#   warnings.warn(error)
# /Users/hillarypan/pymatgen/pymatgen/analysis/local_env.py:3419: UserWarning: CrystalNN: distance cutoffs set but no oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#   warnings.warn("CrystalNN: distance cutoffs set but no oxidation "
# /Users/hillarypan/pymatgen/pymatgen/analysis/local_env.py:3232: UserWarning: CrystalNN: cannot locate an appropriate radius, covalent or atomic radii will be used, this can lead to non-optimal results.
#   "CrystalNN: cannot locate an appropriate radius, "
#                          MinimumDistanceNN0  MinimumDistanceNN1  \
# Al2O3_corundum_9770                {'O': 6}                  {}
# CsCl_53847                        {'Cl': 8}                  {}
# Cu5Zn8_gamma_brass_2092  {'Zn': 6, 'Cu': 6}  {'Zn': 5, 'Cu': 3}
# Fe3O4_inv_spinel_26410             {'O': 6}            {'O': 4}
# NaCl_rocksalt_100633              {'Cl': 6}                  {}
# NiAs_5245                         {'As': 6}                  {}
# Pb3O4_22325                        {'O': 3}            {'O': 6}
# Th3P4_25724                        {'P': 8}                  {}
# TiO2_rutile_9852                   {'O': 6}                  {}
# ZnS_sphalerite_651455              {'S': 4}                  {}
# ZnS_wurtzite_67453                 {'S': 4}                  {}
#
#                          MinimumDistanceNN2  MinimumDistanceNN3  \
# Al2O3_corundum_9770                      {}                  {}
# CsCl_53847                               {}                  {}
# Cu5Zn8_gamma_brass_2092  {'Zn': 9, 'Cu': 3}  {'Zn': 4, 'Cu': 3}
# Fe3O4_inv_spinel_26410                   {}                  {}
# NaCl_rocksalt_100633                     {}                  {}
# NiAs_5245                                {}                  {}
# Pb3O4_22325                              {}                  {}
# Th3P4_25724                              {}                  {}
# TiO2_rutile_9852                         {}                  {}
# ZnS_sphalerite_651455                    {}                  {}
# ZnS_wurtzite_67453                       {}                  {}
#
#                           MinimumOKeeffeNN0   MinimumOKeeffeNN1  \
# Al2O3_corundum_9770                {'O': 6}                  {}
# CsCl_53847                               {}                  {}
# Cu5Zn8_gamma_brass_2092  {'Zn': 6, 'Cu': 6}  {'Zn': 5, 'Cu': 3}
# Fe3O4_inv_spinel_26410             {'O': 6}            {'O': 4}
# NaCl_rocksalt_100633              {'Cl': 6}                  {}
# NiAs_5245                         {'As': 6}                  {}
# Pb3O4_22325                        {'O': 3}            {'O': 6}
# Th3P4_25724                        {'P': 8}                  {}
# TiO2_rutile_9852                   {'O': 6}                  {}
# ZnS_sphalerite_651455              {'S': 4}                  {}
# ZnS_wurtzite_67453                 {'S': 4}                  {}
#
#                         MinimumOKeeffeNN2 MinimumOKeeffeNN3  \
# Al2O3_corundum_9770                    {}                {}
# CsCl_53847                             {}                {}
# Cu5Zn8_gamma_brass_2092         {'Zn': 9}         {'Zn': 4}
# Fe3O4_inv_spinel_26410                 {}                {}
# NaCl_rocksalt_100633                   {}                {}
# NiAs_5245                              {}                {}
# Pb3O4_22325                            {}                {}
# Th3P4_25724                            {}                {}
# TiO2_rutile_9852                       {}                {}
# ZnS_sphalerite_651455                  {}                {}
# ZnS_wurtzite_67453                     {}                {}
#
#                              MinimumVIRENN0      MinimumVIRENN1  \
# Al2O3_corundum_9770                {'O': 6}                  {}
# CsCl_53847                        {'Cl': 8}                  {}
# Cu5Zn8_gamma_brass_2092  {'Zn': 6, 'Cu': 6}  {'Zn': 5, 'Cu': 3}
# Fe3O4_inv_spinel_26410             {'O': 6}            {'O': 4}
# NaCl_rocksalt_100633              {'Cl': 6}                  {}
# NiAs_5245                         {'As': 6}                  {}
# Pb3O4_22325                        {'O': 3}            {'O': 6}
# Th3P4_25724                        {'P': 8}                  {}
# TiO2_rutile_9852                   {'O': 6}                  {}
# ZnS_sphalerite_651455              {'S': 4}                  {}
# ZnS_wurtzite_67453                 {'S': 4}                  {}
#
#                              MinimumVIRENN2      MinimumVIRENN3  \
# Al2O3_corundum_9770                      {}                  {}
# CsCl_53847                               {}                  {}
# Cu5Zn8_gamma_brass_2092  {'Zn': 9, 'Cu': 3}  {'Zn': 4, 'Cu': 3}
# Fe3O4_inv_spinel_26410                   {}                  {}
# NaCl_rocksalt_100633                     {}                  {}
# NiAs_5245                                {}                  {}
# Pb3O4_22325                              {}                  {}
# Th3P4_25724                              {}                  {}
# TiO2_rutile_9852                         {}                  {}
# ZnS_sphalerite_651455                    {}                  {}
# ZnS_wurtzite_67453                       {}                  {}
#
#                                     JmolNN0             JmolNN1  \
# Al2O3_corundum_9770                {'O': 6}                  {}
# CsCl_53847                               {}                  {}
# Cu5Zn8_gamma_brass_2092  {'Zn': 6, 'Cu': 7}  {'Zn': 7, 'Cu': 6}
# Fe3O4_inv_spinel_26410             {'O': 6}            {'O': 4}
# NaCl_rocksalt_100633                     {}                  {}
# NiAs_5245                         {'As': 6}                  {}
# Pb3O4_22325                        {'O': 3}            {'O': 6}
# Th3P4_25724                        {'P': 8}                  {}
# TiO2_rutile_9852                   {'O': 6}                  {}
# ZnS_sphalerite_651455              {'S': 4}                  {}
# ZnS_wurtzite_67453                 {'S': 4}                  {}
#
#                                      JmolNN2              JmolNN3  \
# Al2O3_corundum_9770                       {}                   {}
# CsCl_53847                                {}                   {}
# Cu5Zn8_gamma_brass_2092  {'Zn': 10, 'Cu': 3}  {'Zn': 10, 'Cu': 3}
# Fe3O4_inv_spinel_26410                    {}                   {}
# NaCl_rocksalt_100633                      {}                   {}
# NiAs_5245                                 {}                   {}
# Pb3O4_22325                               {}                   {}
# Th3P4_25724                               {}                   {}
# TiO2_rutile_9852                          {}                   {}
# ZnS_sphalerite_651455                     {}                   {}
# ZnS_wurtzite_67453                        {}                   {}
#
#                                     EconNN0             EconNN1  \
# Al2O3_corundum_9770                {'O': 6}                  {}
# CsCl_53847                        {'Cl': 8}                  {}
# Cu5Zn8_gamma_brass_2092  {'Zn': 6, 'Cu': 7}  {'Zn': 9, 'Cu': 6}
# Fe3O4_inv_spinel_26410             {'O': 6}            {'O': 4}
# NaCl_rocksalt_100633              {'Cl': 6}                  {}
# NiAs_5245                         {'As': 6}                  {}
# Pb3O4_22325                        {'O': 4}            {'O': 6}
# Th3P4_25724                        {'P': 8}                  {}
# TiO2_rutile_9852                   {'O': 6}                  {}
# ZnS_sphalerite_651455              {'S': 4}                  {}
# ZnS_wurtzite_67453                 {'S': 4}                  {}
#
#                                      EconNN2              EconNN3  \
# Al2O3_corundum_9770                       {}                   {}
# CsCl_53847                                {}                   {}
# Cu5Zn8_gamma_brass_2092  {'Zn': 10, 'Cu': 3}  {'Zn': 10, 'Cu': 3}
# Fe3O4_inv_spinel_26410                    {}                   {}
# NaCl_rocksalt_100633                      {}                   {}
# NiAs_5245                                 {}                   {}
# Pb3O4_22325                               {}                   {}
# Th3P4_25724                               {}                   {}
# TiO2_rutile_9852                          {}                   {}
# ZnS_sphalerite_651455                     {}                   {}
# ZnS_wurtzite_67453                        {}                   {}
#
#                         BrunnerNN_reciprocal0 BrunnerNN_reciprocal1  \
# Al2O3_corundum_9770                  {'O': 6}                    {}
# CsCl_53847                          {'Cl': 8}                    {}
# Cu5Zn8_gamma_brass_2092    {'Zn': 6, 'Cu': 6}    {'Zn': 5, 'Cu': 6}
# Fe3O4_inv_spinel_26410               {'O': 6}              {'O': 4}
# NaCl_rocksalt_100633                {'Cl': 6}                    {}
# NiAs_5245                           {'As': 6}                    {}
# Pb3O4_22325                          {'O': 3}              {'O': 6}
# Th3P4_25724                          {'P': 8}                    {}
# TiO2_rutile_9852                     {'O': 6}                    {}
# ZnS_sphalerite_651455                {'S': 4}                    {}
# ZnS_wurtzite_67453                   {'S': 4}                    {}
#
#                         BrunnerNN_reciprocal2 BrunnerNN_reciprocal3  \
# Al2O3_corundum_9770                        {}                    {}
# CsCl_53847                                 {}                    {}
# Cu5Zn8_gamma_brass_2092    {'Zn': 9, 'Cu': 3}   {'Zn': 10, 'Cu': 3}
# Fe3O4_inv_spinel_26410                     {}                    {}
# NaCl_rocksalt_100633                       {}                    {}
# NiAs_5245                                  {}                    {}
# Pb3O4_22325                                {}                    {}
# Th3P4_25724                                {}                    {}
# TiO2_rutile_9852                           {}                    {}
# ZnS_sphalerite_651455                      {}                    {}
# ZnS_wurtzite_67453                         {}                    {}
#
#                                  VoronoiNN0          VoronoiNN1  \
# Al2O3_corundum_9770                {'O': 6}                  {}
# CsCl_53847                        {'Cl': 8}                  {}
# Cu5Zn8_gamma_brass_2092  {'Cu': 6, 'Zn': 6}  {'Zn': 5, 'Cu': 6}
# Fe3O4_inv_spinel_26410             {'O': 6}            {'O': 4}
# NaCl_rocksalt_100633              {'Cl': 6}                  {}
# NiAs_5245                         {'As': 6}                  {}
# Pb3O4_22325                        {'O': 3}            {'O': 6}
# Th3P4_25724                        {'P': 8}                  {}
# TiO2_rutile_9852                   {'O': 6}                  {}
# ZnS_sphalerite_651455              {'S': 4}                  {}
# ZnS_wurtzite_67453                 {'S': 4}                  {}
#
#                                  VoronoiNN2           VoronoiNN3  \
# Al2O3_corundum_9770                      {}                   {}
# CsCl_53847                               {}                   {}
# Cu5Zn8_gamma_brass_2092  {'Cu': 3, 'Zn': 9}  {'Cu': 3, 'Zn': 10}
# Fe3O4_inv_spinel_26410                   {}                   {}
# NaCl_rocksalt_100633                     {}                   {}
# NiAs_5245                                {}                   {}
# Pb3O4_22325                              {}                   {}
# Th3P4_25724                              {}                   {}
# TiO2_rutile_9852                         {}                   {}
# ZnS_sphalerite_651455                    {}                   {}
# ZnS_wurtzite_67453                       {}                   {}
#
#                                  CrystalNN0          CrystalNN1 CrystalNN2  \
# Al2O3_corundum_9770                {'O': 6}                  {}         {}
# CsCl_53847                        {'Cl': 8}                  {}         {}
# Cu5Zn8_gamma_brass_2092  {'Cu': 6, 'Zn': 6}  {'Cu': 6, 'Zn': 5}  {'Zn': 9}
# Fe3O4_inv_spinel_26410             {'O': 6}            {'O': 4}         {}
# NaCl_rocksalt_100633              {'Cl': 6}                  {}         {}
# NiAs_5245                         {'As': 6}                  {}         {}
# Pb3O4_22325                        {'O': 3}            {'O': 6}         {}
# Th3P4_25724                        {'P': 8}                  {}         {}
# TiO2_rutile_9852                   {'O': 6}                  {}         {}
# ZnS_sphalerite_651455              {'S': 4}                  {}         {}
# ZnS_wurtzite_67453                 {'S': 4}                  {}         {}
#
#                                   CrystalNN3       HumanInterpreter0  \
# Al2O3_corundum_9770                       {}              {'O': 6.0}
# CsCl_53847                                {}             {'Cl': 8.0}
# Cu5Zn8_gamma_brass_2092  {'Zn': 10, 'Cu': 3}  {'Zn': 6.0, 'Cu': 6.0}
# Fe3O4_inv_spinel_26410                    {}              {'O': 6.0}
# NaCl_rocksalt_100633                      {}             {'Cl': 6.0}
# NiAs_5245                                 {}             {'As': 6.0}
# Pb3O4_22325                               {}              {'O': 3.0}
# Th3P4_25724                               {}              {'P': 8.0}
# TiO2_rutile_9852                          {}              {'O': 6.0}
# ZnS_sphalerite_651455                     {}              {'S': 4.0}
# ZnS_wurtzite_67453                        {}              {'S': 4.0}
#
#                               HumanInterpreter1       HumanInterpreter2  \
# Al2O3_corundum_9770                          {}                      {}
# CsCl_53847                                   {}                      {}
# Cu5Zn8_gamma_brass_2092  {'Zn': 5.0, 'Cu': 6.0}  {'Zn': 9.0, 'Cu': 3.0}
# Fe3O4_inv_spinel_26410               {'O': 4.0}                      {}
# NaCl_rocksalt_100633                         {}                      {}
# NiAs_5245                                    {}                      {}
# Pb3O4_22325                          {'O': 6.0}                      {}
# Th3P4_25724                                  {}                      {}
# TiO2_rutile_9852                             {}                      {}
# ZnS_sphalerite_651455                        {}                      {}
# ZnS_wurtzite_67453                           {}                      {}
#
#                                HumanInterpreter3
# Al2O3_corundum_9770                           {}
# CsCl_53847                                    {}
# Cu5Zn8_gamma_brass_2092  {'Zn': 10.0, 'Cu': 3.0}
# Fe3O4_inv_spinel_26410                        {}
# NaCl_rocksalt_100633                          {}
# NiAs_5245                                     {}
# Pb3O4_22325                                   {}
# Th3P4_25724                                   {}
# TiO2_rutile_9852                              {}
# ZnS_sphalerite_651455                         {}
# ZnS_wurtzite_67453                            {}

# %%
df = preset.score(methods)
df

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 12))

sns.set(font='Times New Roman')
sns.set(font_scale=2)

hm = sns.heatmap(df, annot=True, cmap="BuPu", vmax=10)

ax.set_xticklabels(df.columns.tolist(), rotation=45)
ax.set_yticklabels(df.index.tolist())

plt.savefig('common_binaries.png')
plt.show()
