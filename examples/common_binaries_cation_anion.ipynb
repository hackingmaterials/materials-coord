# %%
import pandas as pd
pd.set_option("display.max_columns",999) # display all columns
pd.set_option("display.max_rows", 999)

from pymatgen.analysis.local_env import BrunnerNN_reciprocal, EconNN, JMolNN, \
                                        MinimumDistanceNN, MinimumOKeeffeNN, MinimumVIRENN, \
                                        VoronoiNN, VoronoiNN_modified, CrystalNN
from materialscoord.core import Benchmark, HumanInterpreter

methods = [BrunnerNN_reciprocal(), EconNN(), JMolNN(), CrystalNN(), VoronoiNN(tol=0.5),
           MinimumDistanceNN(), MinimumOKeeffeNN(), MinimumVIRENN(),
           HumanInterpreter()]
structure_groups = ["common_binaries"]

preset = Benchmark.from_preset(preset_name=structure_groups)
preset.benchmark(methods=methods)
# Out:
# /Users/hillarypan/AJResearch/cn_routines/codes/pymatgen/pymatgen/__init__.py:89: UserWarning:
# Pymatgen will drop Py2k support from v2019.1.1. Pls consult the documentation
# at https://www.pymatgen.org for more details.
#   at https://www.pymatgen.org for more details.""")
#                             BrunnerNN_reciprocal0     BrunnerNN_reciprocal1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CsCl_53847                           {u'Cl': 8.0}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 6.0}  {u'Zn': 5.0, u'Cu': 6.0}
# Fe3O4_inv_spinel_26410                {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}                        {}
# NiAs_5245                            {u'As': 6.0}                        {}
# Pb3O4_22325                           {u'O': 3.0}               {u'O': 6.0}
# Th3P4_25724                           {u'P': 8.0}                        {}
# TiO2_rutile_9852                      {u'O': 6.0}                        {}
# ZnS_sphalerite_651455                 {u'S': 4.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
#
#                             BrunnerNN_reciprocal2      BrunnerNN_reciprocal3  \
# Al2O3_corundum_9770                            {}                         {}
# CsCl_53847                                     {}                         {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 9.0, u'Cu': 3.0}  {u'Zn': 10.0, u'Cu': 3.0}
# Fe3O4_inv_spinel_26410                         {}                         {}
# NaCl_rocksalt_100633                           {}                         {}
# NiAs_5245                                      {}                         {}
# Pb3O4_22325                                    {}                         {}
# Th3P4_25724                                    {}                         {}
# TiO2_rutile_9852                               {}                         {}
# ZnS_sphalerite_651455                          {}                         {}
# ZnS_wurtzite_67453                             {}                         {}
#
#                                        CrystalNN0                CrystalNN1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CsCl_53847                           {u'Cl': 8.0}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 6.0}  {u'Zn': 5.0, u'Cu': 6.0}
# Fe3O4_inv_spinel_26410                {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}                        {}
# NiAs_5245                            {u'As': 6.0}                        {}
# Pb3O4_22325                           {u'O': 3.0}               {u'O': 6.0}
# Th3P4_25724                           {u'P': 8.0}                        {}
# TiO2_rutile_9852                      {u'O': 6.0}                        {}
# ZnS_sphalerite_651455                 {u'S': 4.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
#
#                            CrystalNN2                 CrystalNN3  \
# Al2O3_corundum_9770                {}                         {}
# CsCl_53847                         {}                         {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 9.0}  {u'Zn': 10.0, u'Cu': 3.0}
# Fe3O4_inv_spinel_26410             {}                         {}
# NaCl_rocksalt_100633               {}                         {}
# NiAs_5245                          {}                         {}
# Pb3O4_22325                        {}                         {}
# Th3P4_25724                        {}                         {}
# TiO2_rutile_9852                   {}                         {}
# ZnS_sphalerite_651455              {}                         {}
# ZnS_wurtzite_67453                 {}                         {}
#
#                                           EconNN0                   EconNN1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CsCl_53847                           {u'Cl': 8.0}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 7.0}  {u'Zn': 9.0, u'Cu': 6.0}
# Fe3O4_inv_spinel_26410                {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}                        {}
# NiAs_5245                            {u'As': 6.0}                        {}
# Pb3O4_22325                           {u'O': 4.0}               {u'O': 6.0}
# Th3P4_25724                           {u'P': 8.0}                        {}
# TiO2_rutile_9852                      {u'O': 6.0}                        {}
# ZnS_sphalerite_651455                 {u'S': 4.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
#
#                                            EconNN2                    EconNN3  \
# Al2O3_corundum_9770                             {}                         {}
# CsCl_53847                                      {}                         {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 10.0, u'Cu': 3.0}  {u'Zn': 10.0, u'Cu': 3.0}
# Fe3O4_inv_spinel_26410                          {}                         {}
# NaCl_rocksalt_100633                            {}                         {}
# NiAs_5245                                       {}                         {}
# Pb3O4_22325                                     {}                         {}
# Th3P4_25724                                     {}                         {}
# TiO2_rutile_9852                                {}                         {}
# ZnS_sphalerite_651455                           {}                         {}
# ZnS_wurtzite_67453                              {}                         {}
#
#                                 HumanInterpreter0         HumanInterpreter1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CsCl_53847                           {u'Cl': 8.0}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 6.0}  {u'Zn': 5.0, u'Cu': 6.0}
# Fe3O4_inv_spinel_26410                {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}                        {}
# NiAs_5245                            {u'As': 6.0}                        {}
# Pb3O4_22325                           {u'O': 3.0}               {u'O': 6.0}
# Th3P4_25724                           {u'P': 8.0}                        {}
# TiO2_rutile_9852                      {u'O': 6.0}                        {}
# ZnS_sphalerite_651455                 {u'S': 4.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
#
#                                 HumanInterpreter2          HumanInterpreter3  \
# Al2O3_corundum_9770                            {}                         {}
# CsCl_53847                                     {}                         {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 9.0, u'Cu': 3.0}  {u'Zn': 10.0, u'Cu': 3.0}
# Fe3O4_inv_spinel_26410                         {}                         {}
# NaCl_rocksalt_100633                           {}                         {}
# NiAs_5245                                      {}                         {}
# Pb3O4_22325                                    {}                         {}
# Th3P4_25724                                    {}                         {}
# TiO2_rutile_9852                               {}                         {}
# ZnS_sphalerite_651455                          {}                         {}
# ZnS_wurtzite_67453                             {}                         {}
#
#                                           JMolNN0                   JMolNN1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CsCl_53847                                     {}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 7.0}  {u'Zn': 7.0, u'Cu': 6.0}
# Fe3O4_inv_spinel_26410                {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633                           {}                        {}
# NiAs_5245                            {u'As': 6.0}                        {}
# Pb3O4_22325                           {u'O': 3.0}               {u'O': 6.0}
# Th3P4_25724                           {u'P': 8.0}                        {}
# TiO2_rutile_9852                      {u'O': 6.0}                        {}
# ZnS_sphalerite_651455                 {u'S': 4.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
#
#                                            JMolNN2                    JMolNN3  \
# Al2O3_corundum_9770                             {}                         {}
# CsCl_53847                                      {}                         {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 10.0, u'Cu': 3.0}  {u'Zn': 10.0, u'Cu': 3.0}
# Fe3O4_inv_spinel_26410                          {}                         {}
# NaCl_rocksalt_100633                            {}                         {}
# NiAs_5245                                       {}                         {}
# Pb3O4_22325                                     {}                         {}
# Th3P4_25724                                     {}                         {}
# TiO2_rutile_9852                                {}                         {}
# ZnS_sphalerite_651455                           {}                         {}
# ZnS_wurtzite_67453                              {}                         {}
#
#                                MinimumDistanceNN0        MinimumDistanceNN1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CsCl_53847                           {u'Cl': 8.0}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 6.0}  {u'Zn': 5.0, u'Cu': 3.0}
# Fe3O4_inv_spinel_26410                {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}                        {}
# NiAs_5245                            {u'As': 6.0}                        {}
# Pb3O4_22325                           {u'O': 3.0}               {u'O': 6.0}
# Th3P4_25724                           {u'P': 8.0}                        {}
# TiO2_rutile_9852                      {u'O': 6.0}                        {}
# ZnS_sphalerite_651455                 {u'S': 4.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
#
#                                MinimumDistanceNN2        MinimumDistanceNN3  \
# Al2O3_corundum_9770                            {}                        {}
# CsCl_53847                                     {}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 9.0, u'Cu': 3.0}  {u'Zn': 4.0, u'Cu': 3.0}
# Fe3O4_inv_spinel_26410                         {}                        {}
# NaCl_rocksalt_100633                           {}                        {}
# NiAs_5245                                      {}                        {}
# Pb3O4_22325                                    {}                        {}
# Th3P4_25724                                    {}                        {}
# TiO2_rutile_9852                               {}                        {}
# ZnS_sphalerite_651455                          {}                        {}
# ZnS_wurtzite_67453                             {}                        {}
#
#                                 MinimumOKeeffeNN0         MinimumOKeeffeNN1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CsCl_53847                                     {}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 6.0}  {u'Zn': 5.0, u'Cu': 3.0}
# Fe3O4_inv_spinel_26410                {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}                        {}
# NiAs_5245                            {u'As': 6.0}                        {}
# Pb3O4_22325                           {u'O': 3.0}               {u'O': 6.0}
# Th3P4_25724                           {u'P': 8.0}                        {}
# TiO2_rutile_9852                      {u'O': 6.0}                        {}
# ZnS_sphalerite_651455                 {u'S': 4.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
#
#                         MinimumOKeeffeNN2 MinimumOKeeffeNN3  \
# Al2O3_corundum_9770                    {}                {}
# CsCl_53847                             {}                {}
# Cu5Zn8_gamma_brass_2092      {u'Zn': 9.0}      {u'Zn': 4.0}
# Fe3O4_inv_spinel_26410                 {}                {}
# NaCl_rocksalt_100633                   {}                {}
# NiAs_5245                              {}                {}
# Pb3O4_22325                            {}                {}
# Th3P4_25724                            {}                {}
# TiO2_rutile_9852                       {}                {}
# ZnS_sphalerite_651455                  {}                {}
# ZnS_wurtzite_67453                     {}                {}
#
#                                    MinimumVIRENN0            MinimumVIRENN1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CsCl_53847                           {u'Cl': 8.0}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 6.0}  {u'Zn': 5.0, u'Cu': 3.0}
# Fe3O4_inv_spinel_26410                {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}                        {}
# NiAs_5245                            {u'As': 6.0}                        {}
# Pb3O4_22325                           {u'O': 3.0}               {u'O': 6.0}
# Th3P4_25724                           {u'P': 8.0}                        {}
# TiO2_rutile_9852                      {u'O': 6.0}                        {}
# ZnS_sphalerite_651455                 {u'S': 4.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
#
#                                    MinimumVIRENN2            MinimumVIRENN3  \
# Al2O3_corundum_9770                            {}                        {}
# CsCl_53847                                     {}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 9.0, u'Cu': 3.0}  {u'Zn': 4.0, u'Cu': 3.0}
# Fe3O4_inv_spinel_26410                         {}                        {}
# NaCl_rocksalt_100633                           {}                        {}
# NiAs_5245                                      {}                        {}
# Pb3O4_22325                                    {}                        {}
# Th3P4_25724                                    {}                        {}
# TiO2_rutile_9852                               {}                        {}
# ZnS_sphalerite_651455                          {}                        {}
# ZnS_wurtzite_67453                             {}                        {}
#
#                                        VoronoiNN0                VoronoiNN1  \
# Al2O3_corundum_9770                   {u'O': 6.0}                        {}
# CsCl_53847                           {u'Cl': 8.0}                        {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 6.0}  {u'Zn': 5.0, u'Cu': 6.0}
# Fe3O4_inv_spinel_26410                {u'O': 6.0}               {u'O': 4.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}                        {}
# NiAs_5245                            {u'As': 6.0}                        {}
# Pb3O4_22325                           {u'O': 3.0}               {u'O': 6.0}
# Th3P4_25724                           {u'P': 8.0}                        {}
# TiO2_rutile_9852                      {u'O': 6.0}                        {}
# ZnS_sphalerite_651455                 {u'S': 4.0}                        {}
# ZnS_wurtzite_67453                    {u'S': 4.0}                        {}
#
#                                        VoronoiNN2                 VoronoiNN3
# Al2O3_corundum_9770                            {}                         {}
# CsCl_53847                                     {}                         {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 9.0, u'Cu': 3.0}  {u'Zn': 10.0, u'Cu': 3.0}
# Fe3O4_inv_spinel_26410                         {}                         {}
# NaCl_rocksalt_100633                           {}                         {}
# NiAs_5245                                      {}                         {}
# Pb3O4_22325                                    {}                         {}
# Th3P4_25724                                    {}                         {}
# TiO2_rutile_9852                               {}                         {}
# ZnS_sphalerite_651455                          {}                         {}
# ZnS_wurtzite_67453                             {}                         {}

# %%
df = preset.score(methods)
df
# Out:
#                          BrunnerNN_reciprocal  CrystalNN  EconNN  JMolNN  \
# Al2O3_corundum_9770                       0.0      0.000   0.000   0.000
# CsCl_53847                                0.0      0.000   0.000   8.000
# Cu5Zn8_gamma_brass_2092                   0.0      0.462   2.154   1.231
# Fe3O4_inv_spinel_26410                    0.0      0.000   0.000   0.000
# NaCl_rocksalt_100633                      0.0      0.000   0.000   6.000
# NiAs_5245                                 0.0      0.000   0.000   0.000
# Pb3O4_22325                               0.0      0.000   0.667   0.000
# Th3P4_25724                               0.0      0.000   0.000   0.000
# TiO2_rutile_9852                          0.0      0.000   0.000   0.000
# ZnS_sphalerite_651455                     0.0      0.000   0.000   0.000
# ZnS_wurtzite_67453                        0.0      0.000   0.000   0.000
# Total                                     0.0      0.462   2.821  15.231
#
#                          MinimumDistanceNN  MinimumOKeeffeNN  MinimumVIRENN  \
# Al2O3_corundum_9770                  0.000             0.000          0.000
# CsCl_53847                           0.000             8.000          0.000
# Cu5Zn8_gamma_brass_2092              2.769             3.923          2.769
# Fe3O4_inv_spinel_26410               0.000             0.000          0.000
# NaCl_rocksalt_100633                 0.000             0.000          0.000
# NiAs_5245                            0.000             0.000          0.000
# Pb3O4_22325                          0.000             0.000          0.000
# Th3P4_25724                          0.000             0.000          0.000
# TiO2_rutile_9852                     0.000             0.000          0.000
# ZnS_sphalerite_651455                0.000             0.000          0.000
# ZnS_wurtzite_67453                   0.000             0.000          0.000
# Total                                2.769            11.923          2.769
#
#                          VoronoiNN
# Al2O3_corundum_9770            0.0
# CsCl_53847                     0.0
# Cu5Zn8_gamma_brass_2092        0.0
# Fe3O4_inv_spinel_26410         0.0
# NaCl_rocksalt_100633           0.0
# NiAs_5245                      0.0
# Pb3O4_22325                    0.0
# Th3P4_25724                    0.0
# TiO2_rutile_9852               0.0
# ZnS_sphalerite_651455          0.0
# ZnS_wurtzite_67453             0.0
# Total                          0.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 12))

sns.set(font='Times New Roman')
sns.set(font_scale=2)

hm = sns.heatmap(df, annot=True, cmap="BuPu", vmax=10)

ax.set_xticklabels(df.columns.tolist(), rotation=45)
ax.set_yticklabels(df.index.tolist())

plt.savefig('common_binaries.png')
plt.show()
