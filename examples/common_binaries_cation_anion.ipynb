# %%
import pandas as pd
pd.set_option("display.max_columns",999) # display all columns
pd.set_option("display.max_rows", 999)

from pymatgen.analysis.local_env import BrunnerNN_reciprocal, EconNN, JMolNN, \
                                        MinimumDistanceNN, MinimumOKeeffeNN, MinimumVIRENN, \
                                        VoronoiNN, VoronoiNN_modified, CrystalNN
from materialscoord.core import Benchmark, HumanInterpreter

methods = [BrunnerNN_reciprocal(), HumanInterpreter()]
# Out:
# /Users/hillarypan/AJResearch/cn_routines/codes/pymatgen/pymatgen/__init__.py:89: UserWarning:
# Pymatgen will drop Py2k support from v2019.1.1. Pls consult the documentation
# at https://www.pymatgen.org for more details.
#   at https://www.pymatgen.org for more details.""")

# %%
preset = Benchmark.from_preset(["elemental"])
preset.benchmark(methods=methods)
# Out:
#                             BrunnerNN_reciprocal0     BrunnerNN_reciprocal1  \
# Al2O3_corundum_9770                   {u'O': 6.0}              {u'Al': 4.0}
# As_alpha_16518                       {u'As': 3.0}                        {}
# C_diamond_52054                       {u'C': 4.0}                        {}
# C_graphite_76767                      {u'C': 3.0}               {u'C': 3.0}
# CsCl_53847               {u'Cs': 6.0, u'Cl': 8.0}  {u'Cs': 8.0, u'Cl': 6.0}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 6.0}  {u'Zn': 5.0, u'Cu': 6.0}
# Cu_52256                            {u'Cu': 12.0}                        {}
# Fe3O4_inv_spinel_26410                {u'O': 6.0}               {u'O': 4.0}
# Ga_12174                            {u'Ga': 12.0}                        {}
# Hg_alpha_104296                     {u'Hg': 12.0}                        {}
# La_43573                            {u'La': 12.0}             {u'La': 12.0}
# Mg_52260                            {u'Mg': 12.0}                        {}
# Mn_alpha_42743                      {u'Mn': 16.0}             {u'Mn': 16.0}
# Mn_beta_41775                       {u'Mn': 12.0}             {u'Mn': 12.0}
# NaCl_rocksalt_100633                 {u'Cl': 6.0}              {u'Na': 6.0}
# NiAs_5245                {u'Ni': 2.0, u'As': 6.0}              {u'Ni': 6.0}
# P_black_23836                         {u'P': 3.0}                        {}
# Pb3O4_22325                           {u'O': 3.0}               {u'O': 6.0}
# Se_trigonal_23068                    {u'Se': 2.0}                        {}
# Sm_76031                            {u'Sm': 12.0}             {u'Sm': 12.0}
# Sn_beta_106072                       {u'Sn': 6.0}                        {}
# Th3P4_25724                           {u'P': 8.0}   {u'P': 3.0, u'Th': 6.0}
# TiO2_rutile_9852                      {u'O': 6.0}              {u'Ti': 3.0}
# U_alpha_16056                        {u'U': 16.0}                        {}
# W_alpha_43667                        {u'W': 14.0}                        {}
# ZnS_sphalerite_651455                 {u'S': 4.0}              {u'Zn': 4.0}
# ZnS_wurtzite_67453                    {u'S': 4.0}              {u'Zn': 4.0}
#
#                             BrunnerNN_reciprocal2      BrunnerNN_reciprocal3  \
# Al2O3_corundum_9770                            {}                         {}
# As_alpha_16518                                 {}                         {}
# C_diamond_52054                                {}                         {}
# C_graphite_76767                               {}                         {}
# CsCl_53847                                     {}                         {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 9.0, u'Cu': 3.0}  {u'Zn': 10.0, u'Cu': 3.0}
# Cu_52256                                       {}                         {}
# Fe3O4_inv_spinel_26410               {u'Fe': 4.0}                         {}
# Ga_12174                                       {}                         {}
# Hg_alpha_104296                                {}                         {}
# La_43573                                       {}                         {}
# Mg_52260                                       {}                         {}
# Mn_alpha_42743                      {u'Mn': 13.0}              {u'Mn': 12.0}
# Mn_beta_41775                                  {}                         {}
# NaCl_rocksalt_100633                           {}                         {}
# NiAs_5245                                      {}                         {}
# P_black_23836                                  {}                         {}
# Pb3O4_22325                          {u'Pb': 3.0}               {u'Pb': 3.0}
# Se_trigonal_23068                              {}                         {}
# Sm_76031                                       {}                         {}
# Sn_beta_106072                                 {}                         {}
# Th3P4_25724                                    {}                         {}
# TiO2_rutile_9852                               {}                         {}
# U_alpha_16056                                  {}                         {}
# W_alpha_43667                                  {}                         {}
# ZnS_sphalerite_651455                          {}                         {}
# ZnS_wurtzite_67453                             {}                         {}
#
#                                 HumanInterpreter0         HumanInterpreter1  \
# Al2O3_corundum_9770       {u'Al': 0.0, u'O': 6.0}   {u'Al': 4.0, u'O': 0.0}
# As_alpha_16518                       {u'As': 3.0}                        {}
# C_diamond_52054                       {u'C': 4.0}                        {}
# C_graphite_76767                      {u'C': 3.0}               {u'C': 3.0}
# CsCl_53847               {u'Cs': 0.0, u'Cl': 8.0}  {u'Cs': 8.0, u'Cl': 0.0}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 6.0, u'Cu': 6.0}  {u'Zn': 5.0, u'Cu': 6.0}
# Cu_52256                            {u'Cu': 12.0}                        {}
# Fe3O4_inv_spinel_26410    {u'Fe': 0.0, u'O': 4.0}   {u'Fe': 0.0, u'O': 6.0}
# Ga_12174                            {u'Ga': 12.0}                        {}
# Hg_alpha_104296                      {u'Hg': 6.0}                        {}
# La_43573                            {u'La': 12.0}             {u'La': 12.0}
# Mg_52260                            {u'Mg': 12.0}                        {}
# Mn_alpha_42743                      {u'Mn': 16.0}             {u'Mn': 16.0}
# Mn_beta_41775                       {u'Mn': 12.0}             {u'Mn': 12.0}
# NaCl_rocksalt_100633     {u'Na': 0.0, u'Cl': 6.0}  {u'Na': 6.0, u'Cl': 0.0}
# NiAs_5245                {u'Ni': 0.0, u'As': 6.0}  {u'Ni': 6.0, u'As': 0.0}
# P_black_23836                         {u'P': 3.0}                        {}
# Pb3O4_22325               {u'Pb': 0.0, u'O': 6.0}   {u'Pb': 0.0, u'O': 3.0}
# Se_trigonal_23068                    {u'Se': 2.0}                        {}
# Sm_76031                            {u'Sm': 12.0}             {u'Sm': 12.0}
# Sn_beta_106072                       {u'Sn': 6.0}                        {}
# Th3P4_25724               {u'P': 8.0, u'Th': 0.0}   {u'P': 0.0, u'Th': 6.0}
# TiO2_rutile_9852          {u'O': 6.0, u'Ti': 0.0}   {u'O': 0.0, u'Ti': 3.0}
# U_alpha_16056                 {u'U': [4.0, 12.0]}                        {}
# W_alpha_43667                         {u'W': 8.0}                        {}
# ZnS_sphalerite_651455     {u'S': 4.0, u'Zn': 0.0}   {u'S': 0.0, u'Zn': 4.0}
# ZnS_wurtzite_67453        {u'Zn': 0.0, u'S': 4.0}   {u'Zn': 4.0, u'S': 0.0}
#
#                                 HumanInterpreter2          HumanInterpreter3
# Al2O3_corundum_9770                            {}                         {}
# As_alpha_16518                                 {}                         {}
# C_diamond_52054                                {}                         {}
# C_graphite_76767                               {}                         {}
# CsCl_53847                                     {}                         {}
# Cu5Zn8_gamma_brass_2092  {u'Zn': 9.0, u'Cu': 3.0}  {u'Zn': 10.0, u'Cu': 3.0}
# Cu_52256                                       {}                         {}
# Fe3O4_inv_spinel_26410    {u'Fe': 4.0, u'O': 0.0}                         {}
# Ga_12174                                       {}                         {}
# Hg_alpha_104296                                {}                         {}
# La_43573                                       {}                         {}
# Mg_52260                                       {}                         {}
# Mn_alpha_42743                      {u'Mn': 13.0}              {u'Mn': 12.0}
# Mn_beta_41775                                  {}                         {}
# NaCl_rocksalt_100633                           {}                         {}
# NiAs_5245                                      {}                         {}
# P_black_23836                                  {}                         {}
# Pb3O4_22325               {u'Pb': 3.0, u'O': 0.0}    {u'Pb': 3.0, u'O': 0.0}
# Se_trigonal_23068                              {}                         {}
# Sm_76031                                       {}                         {}
# Sn_beta_106072                                 {}                         {}
# Th3P4_25724                                    {}                         {}
# TiO2_rutile_9852                               {}                         {}
# U_alpha_16056                                  {}                         {}
# W_alpha_43667                                  {}                         {}
# ZnS_sphalerite_651455                          {}                         {}
# ZnS_wurtzite_67453                             {}                         {}

# %%
df = bm.score(methods)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4750f51150be> in <module>()
# ----> 1 df = bm.score(methods)
#       2 df
#
# NameError: name 'bm' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 12))

sns.set(font='Times New Roman')
sns.set(font_scale=2)

hm = sns.heatmap(df, annot=True, cmap="BuPu", vmax=10)

ax.set_xticklabels(df.columns.tolist(), rotation=45)
ax.set_yticklabels(df.index.tolist())

plt.savefig('common_binaries.png')
plt.show()
