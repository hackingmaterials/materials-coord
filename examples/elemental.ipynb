# %%
import pandas as pd
pd.set_option("display.max_columns",999) # display all columns
pd.set_option("display.max_rows", 999)

from pymatgen.analysis.local_env import BrunnerNN_reciprocal, BrunnerNN_relative, BrunnerNN_real, EconNN, JMolNN, \
                                        MinimumDistanceNN, MinimumOKeeffeNN, MinimumVIRENN, \
                                        VoronoiNN, VoronoiNN_modified, CrystalNN
from materialscoord.core import Benchmark, HumanInterpreter, NbFuncs

methods = [BrunnerNN_relative(), EconNN(), JMolNN(), MinimumDistanceNN(), MinimumOKeeffeNN(), 
           VoronoiNN(), VoronoiNN_modified(), CrystalNN(), HumanInterpreter()]
structure_groups = ["elemental"]
bm = Benchmark(methods=methods, structure_groups=structure_groups, unique_sites=True,
               use_weights=False, cation_anion=True, anion_cation=False)
bm.benchmark()
# Out:
# /Users/hillarypan/AJResearch/cn_routines/codes/pymatgen/pymatgen/__init__.py:87: UserWarning:
# Pymatgen will drop Py2k support from v2019.1.1. Pls consult the documentation
# at https://www.pymatgen.org for more details.
#   at https://www.pymatgen.org for more details.""")
# Initialization successful.
# [(u'P', {u'P': 2.0})]
# [(u'Cu', {u'Cu': 12.0})]
# [(u'La', {u'La': 2.0}), (u'La', {u'La': 6.0})]
# [(u'Mg', {u'Mg': 4.0})]
# [(u'Hg', {u'Hg': 6.0})]
# [(u'Mn', {u'Mn': 12.0}), (u'Mn', {u'Mn': 3.0}), (u'Mn', {u'Mn': 3.0}), (u'Mn', {u'Mn': 6.0})]
# [(u'Ga', {u'Ga': 4.0})]
# [(u'Sm', {u'Sm': 6.0}), (u'Sm', {u'Sm': 3.0})]
# [(u'Se', {u'Se': 6.0})]
# [(u'Sn', {u'Sn': 4.0})]
# [(u'U', {u'U': 4.0})]
# [(u'C', {u'C': 9.0}), (u'C', {u'C': 9.0})]
# [(u'C', {u'C': 4.0})]
# [(u'Mn', {u'Mn': 6.0}), (u'Mn', {u'Mn': 8.0})]
# [(u'As', {u'As': 3.0})]
# [(u'W', {u'W': 8.0})]
# [(u'P', {u'P': 3.0})]
# [(u'Cu', {u'Cu': 18.0})]
# [(u'La', {u'La': 18.0}), (u'La', {u'La': 18.0})]
# [(u'Mg', {u'Mg': 18.0})]
# [(u'Hg', {u'Hg': 12.0})]
# [(u'Mn', {u'Mn': 16.0}), (u'Mn', {u'Mn': 16.0}), (u'Mn', {u'Mn': 15.0}), (u'Mn', {u'Mn': 12.0})]
# [(u'Ga', {u'Ga': 16.0})]
# [(u'Sm', {u'Sm': 18.0}), (u'Sm', {u'Sm': 18.0})]
# [(u'Se', {u'Se': 6.0})]
# [(u'Sn', {u'Sn': 18.0})]
# [(u'U', {u'U': 16.0})]
# [(u'C', {u'C': 3.0}), (u'C', {u'C': 3.0})]
# [(u'C', {u'C': 4.0})]
# [(u'Mn', {u'Mn': 12.0}), (u'Mn', {u'Mn': 14.0})]
# [(u'As', {u'As': 12.0})]
# [(u'W', {u'W': 14.0})]
# [(u'P', {})]
# [(u'Cu', {u'Cu': 12.0})]
# [(u'La', {u'La': 12.0}), (u'La', {u'La': 12.0})]
# [(u'Mg', {})]
# [(u'Hg', {u'Hg': 12.0})]
# [(u'Mn', {u'Mn': 16.0}), (u'Mn', {u'Mn': 16.0}), (u'Mn', {u'Mn': 13.0}), (u'Mn', {u'Mn': 12.0})]
# [(u'Ga', {u'Ga': 12.0})]
# [(u'Sm', {u'Sm': 12.0}), (u'Sm', {u'Sm': 12.0})]
# [(u'Se', {u'Se': 2.0})]
# [(u'Sn', {u'Sn': 6.0})]
# [(u'U', {u'U': 12.0})]
# [(u'C', {u'C': 3.0}), (u'C', {u'C': 3.0})]
# [(u'C', {u'C': 4.0})]
# [(u'Mn', {u'Mn': 12.0}), (u'Mn', {u'Mn': 12.0})]
# [(u'As', {u'As': 3.0})]
# [(u'W', {u'W': 14.0})]
# [(u'P', {u'P': 3.0})]
# [(u'Cu', {u'Cu': 12.0})]
# [(u'La', {u'La': 12.0}), (u'La', {u'La': 12.0})]
# [(u'Mg', {u'Mg': 12.0})]
# [(u'Hg', {u'Hg': 6.0})]
# [(u'Mn', {u'Mn': 16.0}), (u'Mn', {u'Mn': 10.0}), (u'Mn', {u'Mn': 4.0}), (u'Mn', {u'Mn': 4.0})]
# [(u'Ga', {u'Ga': 12.0})]
# [(u'Sm', {u'Sm': 12.0}), (u'Sm', {u'Sm': 12.0})]
# [(u'Se', {u'Se': 2.0})]
# [(u'Sn', {u'Sn': 6.0})]
# [(u'U', {u'U': 4.0})]
# [(u'C', {u'C': 3.0}), (u'C', {u'C': 3.0})]
# [(u'C', {u'C': 4.0})]
# [(u'Mn', {u'Mn': 6.0}), (u'Mn', {u'Mn': 12.0})]
# [(u'As', {u'As': 3.0})]
# [(u'W', {u'W': 8.0})]
# [(u'P', {u'P': 3.0})]
# [(u'Cu', {u'Cu': 12.0})]
# [(u'La', {u'La': 12.0}), (u'La', {u'La': 12.0})]
# [(u'Mg', {u'Mg': 12.0})]
# [(u'Hg', {u'Hg': 6.0})]
# [(u'Mn', {u'Mn': 16.0}), (u'Mn', {u'Mn': 10.0}), (u'Mn', {u'Mn': 4.0}), (u'Mn', {u'Mn': 4.0})]
# [(u'Ga', {u'Ga': 12.0})]
# [(u'Sm', {u'Sm': 12.0}), (u'Sm', {u'Sm': 12.0})]
# [(u'Se', {u'Se': 2.0})]
# [(u'Sn', {u'Sn': 6.0})]
# [(u'U', {u'U': 4.0})]
# [(u'C', {u'C': 3.0}), (u'C', {u'C': 3.0})]
# [(u'C', {u'C': 4.0})]
# [(u'Mn', {u'Mn': 6.0}), (u'Mn', {u'Mn': 12.0})]
# [(u'As', {u'As': 3.0})]
# [(u'W', {u'W': 8.0})]
# [(u'P', {u'P': 15.0})]
# [(u'Cu', {u'Cu': 12.0})]
# [(u'La', {u'La': 12.0}), (u'La', {u'La': 12.0})]
# [(u'Mg', {u'Mg': 14.0})]
# [(u'Hg', {u'Hg': 12.0})]
# [(u'Mn', {u'Mn': 16.0}), (u'Mn', {u'Mn': 16.0}), (u'Mn', {u'Mn': 14.0}), (u'Mn', {u'Mn': 12.0})]
# [(u'Ga', {u'Ga': 12.0})]
# [(u'Sm', {u'Sm': 12.0}), (u'Sm', {u'Sm': 12.0})]
# [(u'Se', {u'Se': 16.0})]
# [(u'Sn', {u'Sn': 18.0})]
# [(u'U', {u'U': 12.0})]
# [(u'C', {u'C': 13.0}), (u'C', {u'C': 17.0})]
# [(u'C', {u'C': 16.0})]
# [(u'Mn', {u'Mn': 12.0}), (u'Mn', {u'Mn': 14.0})]
# [(u'As', {u'As': 19.0})]
# [(u'W', {u'W': 14.0})]
# [(u'P', {u'P': 3.0})]
# [(u'Cu', {u'Cu': 12.0})]
# [(u'La', {u'La': 12.0}), (u'La', {u'La': 12.0})]
# [(u'Mg', {u'Mg': 12.0})]
# [(u'Hg', {u'Hg': 12.0})]
# [(u'Mn', {u'Mn': 16.0}), (u'Mn', {u'Mn': 10.0}), (u'Mn', {u'Mn': 12.0}), (u'Mn', {u'Mn': 6.0})]
# [(u'Ga', {u'Ga': 12.0})]
# [(u'Sm', {u'Sm': 12.0}), (u'Sm', {u'Sm': 12.0})]
# [(u'Se', {u'Se': 6.0})]
# [(u'Sn', {u'Sn': 6.0})]
# [(u'U', {u'U': 4.0})]
# [(u'C', {u'C': 3.0}), (u'C', {u'C': 3.0})]
# [(u'C', {u'C': 4.0})]
# [(u'Mn', {u'Mn': 12.0}), (u'Mn', {u'Mn': 12.0})]
# [(u'As', {u'As': 6.0})]
# [(u'W', {u'W': 8.0})]
# [(u'P', {u'P': 3.0})]
# [(u'Cu', {u'Cu': 12.0})]
# [(u'La', {u'La': 12.0}), (u'La', {u'La': 12.0})]
# [(u'Mg', {u'Mg': 12.0})]
# [(u'Hg', {u'Hg': 6.0})]
# [(u'Mn', {u'Mn': 16.0}), (u'Mn', {u'Mn': 16.0}), (u'Mn', {u'Mn': 13.0}), (u'Mn', {u'Mn': 12.0})]
# [(u'Ga', {u'Ga': 12.0})]
# [(u'Sm', {u'Sm': 12.0}), (u'Sm', {u'Sm': 12.0})]
# [(u'Se', {u'Se': 2.0})]
# [(u'Sn', {u'Sn': 6.0})]
# [(u'U', {u'U': 12.0})]
# [(u'C', {u'C': 3.0}), (u'C', {u'C': 3.0})]
# [(u'C', {u'C': 4.0})]
# [(u'Mn', {u'Mn': 12.0}), (u'Mn', {u'Mn': 12.0})]
# [(u'As', {u'As': 3.0})]
# [(u'W', {u'W': 8.0})]
# [(u'P', {'P': 3.0})]
# [(u'Cu', {'Cu': 12.0})]
# [(u'La', {'La': 12.0}), (u'La', {'La': 12.0})]
# [(u'Mg', {'Mg': 12.0})]
# [(u'Hg', {'Hg': 6.0})]
# [(u'Mn', {'Mn': 16.0}), (u'Mn', {'Mn': 16.0}), (u'Mn', {'Mn': 13.0}), (u'Mn', {'Mn': 12.0})]
# [(u'Ga', {'Ga': 12.0})]
# [(u'Sm', {'Sm': 12.0}), (u'Sm', {'Sm': 12.0})]
# [(u'Se', {'Se': 3.0})]
# [(u'Sn', {'Sn': 6.0})]
# [(u'U', {'U': [4.0, 12.0]})]
# [(u'C', {'C': 3.0}), (u'C', {'C': 3.0})]
# [(u'C', {'C': 4.0})]
# [(u'Mn', {'Mn': 12.0}), (u'Mn', {'Mn': 12.0})]
# [(u'As', {'As': 3.0})]
# [(u'W', {'W': 8.0})]
# 4

# %%
report = bm.report()
report
# Out:
#                  BrunnerNN_relative0 BrunnerNN_relative1 BrunnerNN_relative2  \
# As_16518                {u'As': 3.0}                  {}                  {}
# C_diamond_52054          {u'C': 4.0}                  {}                  {}
# C_graphite_76767         {u'C': 9.0}         {u'C': 9.0}                  {}
# Cu_52256               {u'Cu': 12.0}                  {}                  {}
# Ga_12174                {u'Ga': 4.0}                  {}                  {}
# Hg_104296               {u'Hg': 6.0}                  {}                  {}
# La_43573                {u'La': 2.0}        {u'La': 6.0}                  {}
# Mg_52260                {u'Mg': 4.0}                  {}                  {}
# Mn_alpha_42743         {u'Mn': 12.0}        {u'Mn': 3.0}        {u'Mn': 3.0}
# Mn_beta_41775           {u'Mn': 6.0}        {u'Mn': 8.0}                  {}
# P_black_23836            {u'P': 2.0}                  {}                  {}
# Se_gamma_23068          {u'Se': 6.0}                  {}                  {}
# Sm_76031                {u'Sm': 6.0}        {u'Sm': 3.0}                  {}
# Sn_106072               {u'Sn': 4.0}                  {}                  {}
# U_alpha_16056            {u'U': 4.0}                  {}                  {}
# W_43667                  {u'W': 8.0}                  {}                  {}
#
#                  BrunnerNN_relative3     CrystalNN0     CrystalNN1  \
# As_16518                          {}   {u'As': 3.0}             {}
# C_diamond_52054                   {}    {u'C': 4.0}             {}
# C_graphite_76767                  {}    {u'C': 3.0}    {u'C': 3.0}
# Cu_52256                          {}  {u'Cu': 12.0}             {}
# Ga_12174                          {}  {u'Ga': 12.0}             {}
# Hg_104296                         {}   {u'Hg': 6.0}             {}
# La_43573                          {}  {u'La': 12.0}  {u'La': 12.0}
# Mg_52260                          {}  {u'Mg': 12.0}             {}
# Mn_alpha_42743          {u'Mn': 6.0}  {u'Mn': 16.0}  {u'Mn': 16.0}
# Mn_beta_41775                     {}  {u'Mn': 12.0}  {u'Mn': 12.0}
# P_black_23836                     {}    {u'P': 3.0}             {}
# Se_gamma_23068                    {}   {u'Se': 2.0}             {}
# Sm_76031                          {}  {u'Sm': 12.0}  {u'Sm': 12.0}
# Sn_106072                         {}   {u'Sn': 6.0}             {}
# U_alpha_16056                     {}   {u'U': 12.0}             {}
# W_43667                           {}    {u'W': 8.0}             {}
#
#                      CrystalNN2     CrystalNN3        EconNN0        EconNN1  \
# As_16518                     {}             {}  {u'As': 12.0}             {}
# C_diamond_52054              {}             {}    {u'C': 4.0}             {}
# C_graphite_76767             {}             {}    {u'C': 3.0}    {u'C': 3.0}
# Cu_52256                     {}             {}  {u'Cu': 18.0}             {}
# Ga_12174                     {}             {}  {u'Ga': 16.0}             {}
# Hg_104296                    {}             {}  {u'Hg': 12.0}             {}
# La_43573                     {}             {}  {u'La': 18.0}  {u'La': 18.0}
# Mg_52260                     {}             {}  {u'Mg': 18.0}             {}
# Mn_alpha_42743    {u'Mn': 13.0}  {u'Mn': 12.0}  {u'Mn': 16.0}  {u'Mn': 16.0}
# Mn_beta_41775                {}             {}  {u'Mn': 12.0}  {u'Mn': 14.0}
# P_black_23836                {}             {}    {u'P': 3.0}             {}
# Se_gamma_23068               {}             {}   {u'Se': 6.0}             {}
# Sm_76031                     {}             {}  {u'Sm': 18.0}  {u'Sm': 18.0}
# Sn_106072                    {}             {}  {u'Sn': 18.0}             {}
# U_alpha_16056                {}             {}   {u'U': 16.0}             {}
# W_43667                      {}             {}   {u'W': 14.0}             {}
#
#                         EconNN2        EconNN3    HumanInterpreter0  \
# As_16518                     {}             {}         {u'As': 3.0}
# C_diamond_52054              {}             {}          {u'C': 4.0}
# C_graphite_76767             {}             {}          {u'C': 3.0}
# Cu_52256                     {}             {}        {u'Cu': 12.0}
# Ga_12174                     {}             {}        {u'Ga': 12.0}
# Hg_104296                    {}             {}         {u'Hg': 6.0}
# La_43573                     {}             {}        {u'La': 12.0}
# Mg_52260                     {}             {}        {u'Mg': 12.0}
# Mn_alpha_42743    {u'Mn': 15.0}  {u'Mn': 12.0}        {u'Mn': 16.0}
# Mn_beta_41775                {}             {}        {u'Mn': 12.0}
# P_black_23836                {}             {}          {u'P': 3.0}
# Se_gamma_23068               {}             {}         {u'Se': 3.0}
# Sm_76031                     {}             {}        {u'Sm': 12.0}
# Sn_106072                    {}             {}         {u'Sn': 6.0}
# U_alpha_16056                {}             {}  {u'U': [4.0, 12.0]}
# W_43667                      {}             {}          {u'W': 8.0}
#
#                  HumanInterpreter1 HumanInterpreter2 HumanInterpreter3  \
# As_16518                        {}                {}                {}
# C_diamond_52054                 {}                {}                {}
# C_graphite_76767       {u'C': 3.0}                {}                {}
# Cu_52256                        {}                {}                {}
# Ga_12174                        {}                {}                {}
# Hg_104296                       {}                {}                {}
# La_43573             {u'La': 12.0}                {}                {}
# Mg_52260                        {}                {}                {}
# Mn_alpha_42743       {u'Mn': 16.0}     {u'Mn': 13.0}     {u'Mn': 12.0}
# Mn_beta_41775        {u'Mn': 12.0}                {}                {}
# P_black_23836                   {}                {}                {}
# Se_gamma_23068                  {}                {}                {}
# Sm_76031             {u'Sm': 12.0}                {}                {}
# Sn_106072                       {}                {}                {}
# U_alpha_16056                   {}                {}                {}
# W_43667                         {}                {}                {}
#
#                         JMolNN0        JMolNN1        JMolNN2        JMolNN3  \
# As_16518           {u'As': 3.0}             {}             {}             {}
# C_diamond_52054     {u'C': 4.0}             {}             {}             {}
# C_graphite_76767    {u'C': 3.0}    {u'C': 3.0}             {}             {}
# Cu_52256          {u'Cu': 12.0}             {}             {}             {}
# Ga_12174          {u'Ga': 12.0}             {}             {}             {}
# Hg_104296         {u'Hg': 12.0}             {}             {}             {}
# La_43573          {u'La': 12.0}  {u'La': 12.0}             {}             {}
# Mg_52260                     {}             {}             {}             {}
# Mn_alpha_42743    {u'Mn': 16.0}  {u'Mn': 16.0}  {u'Mn': 13.0}  {u'Mn': 12.0}
# Mn_beta_41775     {u'Mn': 12.0}  {u'Mn': 12.0}             {}             {}
# P_black_23836                {}             {}             {}             {}
# Se_gamma_23068     {u'Se': 2.0}             {}             {}             {}
# Sm_76031          {u'Sm': 12.0}  {u'Sm': 12.0}             {}             {}
# Sn_106072          {u'Sn': 6.0}             {}             {}             {}
# U_alpha_16056      {u'U': 12.0}             {}             {}             {}
# W_43667            {u'W': 14.0}             {}             {}             {}
#
#                  MinimumDistanceNN0 MinimumDistanceNN1 MinimumDistanceNN2  \
# As_16518               {u'As': 3.0}                 {}                 {}
# C_diamond_52054         {u'C': 4.0}                 {}                 {}
# C_graphite_76767        {u'C': 3.0}        {u'C': 3.0}                 {}
# Cu_52256              {u'Cu': 12.0}                 {}                 {}
# Ga_12174              {u'Ga': 12.0}                 {}                 {}
# Hg_104296              {u'Hg': 6.0}                 {}                 {}
# La_43573              {u'La': 12.0}      {u'La': 12.0}                 {}
# Mg_52260              {u'Mg': 12.0}                 {}                 {}
# Mn_alpha_42743        {u'Mn': 16.0}      {u'Mn': 10.0}       {u'Mn': 4.0}
# Mn_beta_41775          {u'Mn': 6.0}      {u'Mn': 12.0}                 {}
# P_black_23836           {u'P': 3.0}                 {}                 {}
# Se_gamma_23068         {u'Se': 2.0}                 {}                 {}
# Sm_76031              {u'Sm': 12.0}      {u'Sm': 12.0}                 {}
# Sn_106072              {u'Sn': 6.0}                 {}                 {}
# U_alpha_16056           {u'U': 4.0}                 {}                 {}
# W_43667                 {u'W': 8.0}                 {}                 {}
#
#                  MinimumDistanceNN3 MinimumOKeeffeNN0 MinimumOKeeffeNN1  \
# As_16518                         {}      {u'As': 3.0}                {}
# C_diamond_52054                  {}       {u'C': 4.0}                {}
# C_graphite_76767                 {}       {u'C': 3.0}       {u'C': 3.0}
# Cu_52256                         {}     {u'Cu': 12.0}                {}
# Ga_12174                         {}     {u'Ga': 12.0}                {}
# Hg_104296                        {}      {u'Hg': 6.0}                {}
# La_43573                         {}     {u'La': 12.0}     {u'La': 12.0}
# Mg_52260                         {}     {u'Mg': 12.0}                {}
# Mn_alpha_42743         {u'Mn': 4.0}     {u'Mn': 16.0}     {u'Mn': 10.0}
# Mn_beta_41775                    {}      {u'Mn': 6.0}     {u'Mn': 12.0}
# P_black_23836                    {}       {u'P': 3.0}                {}
# Se_gamma_23068                   {}      {u'Se': 2.0}                {}
# Sm_76031                         {}     {u'Sm': 12.0}     {u'Sm': 12.0}
# Sn_106072                        {}      {u'Sn': 6.0}                {}
# U_alpha_16056                    {}       {u'U': 4.0}                {}
# W_43667                          {}       {u'W': 8.0}                {}
#
#                  MinimumOKeeffeNN2 MinimumOKeeffeNN3     VoronoiNN0  \
# As_16518                        {}                {}  {u'As': 19.0}
# C_diamond_52054                 {}                {}   {u'C': 16.0}
# C_graphite_76767                {}                {}   {u'C': 13.0}
# Cu_52256                        {}                {}  {u'Cu': 12.0}
# Ga_12174                        {}                {}  {u'Ga': 12.0}
# Hg_104296                       {}                {}  {u'Hg': 12.0}
# La_43573                        {}                {}  {u'La': 12.0}
# Mg_52260                        {}                {}  {u'Mg': 14.0}
# Mn_alpha_42743        {u'Mn': 4.0}      {u'Mn': 4.0}  {u'Mn': 16.0}
# Mn_beta_41775                   {}                {}  {u'Mn': 12.0}
# P_black_23836                   {}                {}   {u'P': 15.0}
# Se_gamma_23068                  {}                {}  {u'Se': 16.0}
# Sm_76031                        {}                {}  {u'Sm': 12.0}
# Sn_106072                       {}                {}  {u'Sn': 18.0}
# U_alpha_16056                   {}                {}   {u'U': 12.0}
# W_43667                         {}                {}   {u'W': 14.0}
#
#                      VoronoiNN1     VoronoiNN2     VoronoiNN3  \
# As_16518                     {}             {}             {}
# C_diamond_52054              {}             {}             {}
# C_graphite_76767   {u'C': 17.0}             {}             {}
# Cu_52256                     {}             {}             {}
# Ga_12174                     {}             {}             {}
# Hg_104296                    {}             {}             {}
# La_43573          {u'La': 12.0}             {}             {}
# Mg_52260                     {}             {}             {}
# Mn_alpha_42743    {u'Mn': 16.0}  {u'Mn': 14.0}  {u'Mn': 12.0}
# Mn_beta_41775     {u'Mn': 14.0}             {}             {}
# P_black_23836                {}             {}             {}
# Se_gamma_23068               {}             {}             {}
# Sm_76031          {u'Sm': 12.0}             {}             {}
# Sn_106072                    {}             {}             {}
# U_alpha_16056                {}             {}             {}
# W_43667                      {}             {}             {}
#
#                  VoronoiNN_modified0 VoronoiNN_modified1 VoronoiNN_modified2  \
# As_16518                {u'As': 6.0}                  {}                  {}
# C_diamond_52054          {u'C': 4.0}                  {}                  {}
# C_graphite_76767         {u'C': 3.0}         {u'C': 3.0}                  {}
# Cu_52256               {u'Cu': 12.0}                  {}                  {}
# Ga_12174               {u'Ga': 12.0}                  {}                  {}
# Hg_104296              {u'Hg': 12.0}                  {}                  {}
# La_43573               {u'La': 12.0}       {u'La': 12.0}                  {}
# Mg_52260               {u'Mg': 12.0}                  {}                  {}
# Mn_alpha_42743         {u'Mn': 16.0}       {u'Mn': 10.0}       {u'Mn': 12.0}
# Mn_beta_41775          {u'Mn': 12.0}       {u'Mn': 12.0}                  {}
# P_black_23836            {u'P': 3.0}                  {}                  {}
# Se_gamma_23068          {u'Se': 6.0}                  {}                  {}
# Sm_76031               {u'Sm': 12.0}       {u'Sm': 12.0}                  {}
# Sn_106072               {u'Sn': 6.0}                  {}                  {}
# U_alpha_16056            {u'U': 4.0}                  {}                  {}
# W_43667                  {u'W': 8.0}                  {}                  {}
#
#                  VoronoiNN_modified3
# As_16518                          {}
# C_diamond_52054                   {}
# C_graphite_76767                  {}
# Cu_52256                          {}
# Ga_12174                          {}
# Hg_104296                         {}
# La_43573                          {}
# Mg_52260                          {}
# Mn_alpha_42743          {u'Mn': 6.0}
# Mn_beta_41775                     {}
# P_black_23836                     {}
# Se_gamma_23068                    {}
# Sm_76031                          {}
# Sn_106072                         {}
# U_alpha_16056                     {}
# W_43667                           {}

# %%
nbf = NbFuncs(bm)
df = nbf.final()
df
# Out:
#                   BrunnerNN_relative  CrystalNN  EconNN  JMolNN  \
# As_16518                       0.000        0.0   9.000     0.0
# C_diamond_52054                0.000        0.0   0.000     0.0
# C_graphite_76767               6.000        0.0   0.000     0.0
# Cu_52256                       0.000        0.0   6.000     0.0
# Ga_12174                       8.000        0.0   4.000     0.0
# Hg_104296                      0.000        0.0   6.000     6.0
# La_43573                       8.000        0.0   6.000     0.0
# Mg_52260                       8.000        0.0   6.000    12.0
# Mn_alpha_42743                 8.552        0.0   0.828     0.0
# Mn_beta_41775                  4.800        0.0   1.200     0.0
# P_black_23836                  1.000        0.0   0.000     3.0
# Se_gamma_23068                 3.000        1.0   3.000     1.0
# Sm_76031                       8.000        0.0   6.000     0.0
# Sn_106072                      2.000        0.0  12.000     0.0
# U_alpha_16056                  0.000        0.0   4.000     0.0
# W_43667                        0.000        0.0   6.000     6.0
# Total                         57.352        1.0  70.028    28.0
#
#                   MinimumDistanceNN  MinimumOKeeffeNN  VoronoiNN  \
# As_16518                      0.000             0.000     19.000
# C_diamond_52054               0.000             0.000     12.000
# C_graphite_76767              0.000             0.000     12.000
# Cu_52256                      0.000             0.000      0.000
# Ga_12174                      0.000             0.000      0.000
# Hg_104296                     0.000             0.000     12.000
# La_43573                      0.000             0.000      0.000
# Mg_52260                      0.000             0.000      2.000
# Mn_alpha_42743                7.862             7.862      4.138
# Mn_beta_41775                 2.400             2.400      1.200
# P_black_23836                 0.000             0.000     12.000
# Se_gamma_23068                1.000             1.000     16.000
# Sm_76031                      0.000             0.000      0.000
# Sn_106072                     0.000             0.000     12.000
# U_alpha_16056                 0.000             0.000      0.000
# W_43667                       0.000             0.000      6.000
# Total                        11.262            11.262    108.338
#
#                   VoronoiNN_modified
# As_16518                       3.000
# C_diamond_52054                0.000
# C_graphite_76767               0.000
# Cu_52256                       0.000
# Ga_12174                       0.000
# Hg_104296                      6.000
# La_43573                       0.000
# Mg_52260                       0.000
# Mn_alpha_42743                 3.724
# Mn_beta_41775                  0.000
# P_black_23836                  0.000
# Se_gamma_23068                 3.000
# Sm_76031                       0.000
# Sn_106072                      0.000
# U_alpha_16056                  0.000
# W_43667                        0.000
# Total                         15.724

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 12))

sns.set(font='Times New Roman')
sns.set(font_scale=2)

hm = sns.heatmap(df, annot=True, cmap="BuPu", vmax=10)

ax.set_xticklabels(df.columns.tolist(), rotation=45)
ax.set_yticklabels(df.index.tolist())

plt.savefig('elemental.png')
plt.show()
