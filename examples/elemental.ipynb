# %%
import pandas as pd
pd.set_option("display.max_columns",999) # display all columns
pd.set_option("display.max_rows", 999)

from pymatgen.analysis.local_env import BrunnerNN_reciprocal, EconNN, JmolNN, \
                                        MinimumDistanceNN, MinimumOKeeffeNN, MinimumVIRENN, \
                                        VoronoiNN, VoronoiNN_modified, CrystalNN
from materialscoord.core import Benchmark, HumanInterpreter

methods = [BrunnerNN_reciprocal(), EconNN(), JmolNN(), CrystalNN(), VoronoiNN(tol=0.5),
           MinimumDistanceNN(), MinimumOKeeffeNN(), MinimumVIRENN(),
           HumanInterpreter()]
structure_groups = ["elemental"]

preset = Benchmark.from_preset(preset_name=structure_groups)
preset.benchmark(methods=methods)
# Out:
# /Users/hillarypan/AJResearch/cn_routines/codes/pymatgen/pymatgen/__init__.py:89: UserWarning:
# Pymatgen will drop Py2k support from v2019.1.1. Pls consult the documentation
# at https://www.pymatgen.org for more details.
#   at https://www.pymatgen.org for more details.""")
#                   BrunnerNN_reciprocal0 BrunnerNN_reciprocal1  \
# As_alpha_16518             {u'As': 3.0}                    {}
# C_diamond_52054             {u'C': 4.0}                    {}
# C_graphite_76767            {u'C': 3.0}           {u'C': 3.0}
# Cu_52256                  {u'Cu': 12.0}                    {}
# Ga_12174                  {u'Ga': 12.0}                    {}
# Hg_alpha_104296           {u'Hg': 12.0}                    {}
# La_43573                  {u'La': 12.0}         {u'La': 12.0}
# Mg_52260                  {u'Mg': 12.0}                    {}
# Mn_alpha_42743            {u'Mn': 16.0}         {u'Mn': 16.0}
# Mn_beta_41775             {u'Mn': 12.0}         {u'Mn': 12.0}
# P_black_23836               {u'P': 3.0}                    {}
# Se_trigonal_23068          {u'Se': 2.0}                    {}
# Sm_76031                  {u'Sm': 12.0}         {u'Sm': 12.0}
# Sn_beta_106072             {u'Sn': 6.0}                    {}
# U_alpha_16056              {u'U': 16.0}                    {}
# W_alpha_43667              {u'W': 14.0}                    {}
#
#                   BrunnerNN_reciprocal2 BrunnerNN_reciprocal3     CrystalNN0  \
# As_alpha_16518                       {}                    {}   {u'As': 3.0}
# C_diamond_52054                      {}                    {}    {u'C': 4.0}
# C_graphite_76767                     {}                    {}    {u'C': 3.0}
# Cu_52256                             {}                    {}  {u'Cu': 12.0}
# Ga_12174                             {}                    {}  {u'Ga': 12.0}
# Hg_alpha_104296                      {}                    {}   {u'Hg': 6.0}
# La_43573                             {}                    {}  {u'La': 12.0}
# Mg_52260                             {}                    {}  {u'Mg': 12.0}
# Mn_alpha_42743            {u'Mn': 13.0}         {u'Mn': 12.0}  {u'Mn': 16.0}
# Mn_beta_41775                        {}                    {}  {u'Mn': 12.0}
# P_black_23836                        {}                    {}    {u'P': 3.0}
# Se_trigonal_23068                    {}                    {}   {u'Se': 2.0}
# Sm_76031                             {}                    {}  {u'Sm': 12.0}
# Sn_beta_106072                       {}                    {}   {u'Sn': 6.0}
# U_alpha_16056                        {}                    {}   {u'U': 12.0}
# W_alpha_43667                        {}                    {}    {u'W': 8.0}
#
#                       CrystalNN1     CrystalNN2     CrystalNN3        EconNN0  \
# As_alpha_16518                {}             {}             {}  {u'As': 12.0}
# C_diamond_52054               {}             {}             {}    {u'C': 4.0}
# C_graphite_76767     {u'C': 3.0}             {}             {}    {u'C': 3.0}
# Cu_52256                      {}             {}             {}  {u'Cu': 18.0}
# Ga_12174                      {}             {}             {}  {u'Ga': 16.0}
# Hg_alpha_104296               {}             {}             {}  {u'Hg': 12.0}
# La_43573           {u'La': 12.0}             {}             {}  {u'La': 18.0}
# Mg_52260                      {}             {}             {}  {u'Mg': 18.0}
# Mn_alpha_42743     {u'Mn': 16.0}  {u'Mn': 13.0}  {u'Mn': 12.0}  {u'Mn': 16.0}
# Mn_beta_41775      {u'Mn': 12.0}             {}             {}  {u'Mn': 12.0}
# P_black_23836                 {}             {}             {}    {u'P': 3.0}
# Se_trigonal_23068             {}             {}             {}   {u'Se': 6.0}
# Sm_76031           {u'Sm': 12.0}             {}             {}  {u'Sm': 18.0}
# Sn_beta_106072                {}             {}             {}  {u'Sn': 18.0}
# U_alpha_16056                 {}             {}             {}   {u'U': 16.0}
# W_alpha_43667                 {}             {}             {}   {u'W': 14.0}
#
#                          EconNN1        EconNN2        EconNN3  \
# As_alpha_16518                {}             {}             {}
# C_diamond_52054               {}             {}             {}
# C_graphite_76767     {u'C': 3.0}             {}             {}
# Cu_52256                      {}             {}             {}
# Ga_12174                      {}             {}             {}
# Hg_alpha_104296               {}             {}             {}
# La_43573           {u'La': 18.0}             {}             {}
# Mg_52260                      {}             {}             {}
# Mn_alpha_42743     {u'Mn': 16.0}  {u'Mn': 15.0}  {u'Mn': 12.0}
# Mn_beta_41775      {u'Mn': 14.0}             {}             {}
# P_black_23836                 {}             {}             {}
# Se_trigonal_23068             {}             {}             {}
# Sm_76031           {u'Sm': 18.0}             {}             {}
# Sn_beta_106072                {}             {}             {}
# U_alpha_16056                 {}             {}             {}
# W_alpha_43667                 {}             {}             {}
#
#                       HumanInterpreter0 HumanInterpreter1 HumanInterpreter2  \
# As_alpha_16518             {u'As': 3.0}                {}                {}
# C_diamond_52054             {u'C': 4.0}                {}                {}
# C_graphite_76767            {u'C': 3.0}       {u'C': 3.0}                {}
# Cu_52256                  {u'Cu': 12.0}                {}                {}
# Ga_12174           {u'Ga': [4.0, 12.0]}                {}                {}
# Hg_alpha_104296            {u'Hg': 6.0}                {}                {}
# La_43573                  {u'La': 12.0}     {u'La': 12.0}                {}
# Mg_52260                  {u'Mg': 12.0}                {}                {}
# Mn_alpha_42743            {u'Mn': 16.0}     {u'Mn': 16.0}     {u'Mn': 13.0}
# Mn_beta_41775             {u'Mn': 12.0}     {u'Mn': 12.0}                {}
# P_black_23836               {u'P': 3.0}                {}                {}
# Se_trigonal_23068          {u'Se': 2.0}                {}                {}
# Sm_76031                  {u'Sm': 12.0}     {u'Sm': 12.0}                {}
# Sn_beta_106072             {u'Sn': 6.0}                {}                {}
# U_alpha_16056       {u'U': [4.0, 12.0]}                {}                {}
# W_alpha_43667               {u'W': 8.0}                {}                {}
#
#                   HumanInterpreter3        JmolNN0        JmolNN1  \
# As_alpha_16518                   {}   {u'As': 3.0}             {}
# C_diamond_52054                  {}    {u'C': 4.0}             {}
# C_graphite_76767                 {}    {u'C': 3.0}    {u'C': 3.0}
# Cu_52256                         {}  {u'Cu': 12.0}             {}
# Ga_12174                         {}  {u'Ga': 12.0}             {}
# Hg_alpha_104296                  {}  {u'Hg': 12.0}             {}
# La_43573                         {}  {u'La': 12.0}  {u'La': 12.0}
# Mg_52260                         {}             {}             {}
# Mn_alpha_42743        {u'Mn': 12.0}  {u'Mn': 16.0}  {u'Mn': 16.0}
# Mn_beta_41775                    {}  {u'Mn': 12.0}  {u'Mn': 12.0}
# P_black_23836                    {}             {}             {}
# Se_trigonal_23068                {}   {u'Se': 2.0}             {}
# Sm_76031                         {}  {u'Sm': 12.0}  {u'Sm': 12.0}
# Sn_beta_106072                   {}   {u'Sn': 6.0}             {}
# U_alpha_16056                    {}   {u'U': 12.0}             {}
# W_alpha_43667                    {}   {u'W': 14.0}             {}
#
#                          JmolNN2        JmolNN3 MinimumDistanceNN0  \
# As_alpha_16518                {}             {}       {u'As': 3.0}
# C_diamond_52054               {}             {}        {u'C': 4.0}
# C_graphite_76767              {}             {}        {u'C': 3.0}
# Cu_52256                      {}             {}      {u'Cu': 12.0}
# Ga_12174                      {}             {}      {u'Ga': 12.0}
# Hg_alpha_104296               {}             {}       {u'Hg': 6.0}
# La_43573                      {}             {}      {u'La': 12.0}
# Mg_52260                      {}             {}      {u'Mg': 12.0}
# Mn_alpha_42743     {u'Mn': 13.0}  {u'Mn': 12.0}      {u'Mn': 16.0}
# Mn_beta_41775                 {}             {}       {u'Mn': 6.0}
# P_black_23836                 {}             {}        {u'P': 3.0}
# Se_trigonal_23068             {}             {}       {u'Se': 2.0}
# Sm_76031                      {}             {}      {u'Sm': 12.0}
# Sn_beta_106072                {}             {}       {u'Sn': 6.0}
# U_alpha_16056                 {}             {}        {u'U': 4.0}
# W_alpha_43667                 {}             {}        {u'W': 8.0}
#
#                   MinimumDistanceNN1 MinimumDistanceNN2 MinimumDistanceNN3  \
# As_alpha_16518                    {}                 {}                 {}
# C_diamond_52054                   {}                 {}                 {}
# C_graphite_76767         {u'C': 3.0}                 {}                 {}
# Cu_52256                          {}                 {}                 {}
# Ga_12174                          {}                 {}                 {}
# Hg_alpha_104296                   {}                 {}                 {}
# La_43573               {u'La': 12.0}                 {}                 {}
# Mg_52260                          {}                 {}                 {}
# Mn_alpha_42743         {u'Mn': 10.0}       {u'Mn': 4.0}       {u'Mn': 4.0}
# Mn_beta_41775          {u'Mn': 12.0}                 {}                 {}
# P_black_23836                     {}                 {}                 {}
# Se_trigonal_23068                 {}                 {}                 {}
# Sm_76031               {u'Sm': 12.0}                 {}                 {}
# Sn_beta_106072                    {}                 {}                 {}
# U_alpha_16056                     {}                 {}                 {}
# W_alpha_43667                     {}                 {}                 {}
#
#                   MinimumOKeeffeNN0 MinimumOKeeffeNN1 MinimumOKeeffeNN2  \
# As_alpha_16518         {u'As': 3.0}                {}                {}
# C_diamond_52054         {u'C': 4.0}                {}                {}
# C_graphite_76767        {u'C': 3.0}       {u'C': 3.0}                {}
# Cu_52256              {u'Cu': 12.0}                {}                {}
# Ga_12174              {u'Ga': 12.0}                {}                {}
# Hg_alpha_104296        {u'Hg': 6.0}                {}                {}
# La_43573              {u'La': 12.0}     {u'La': 12.0}                {}
# Mg_52260              {u'Mg': 12.0}                {}                {}
# Mn_alpha_42743        {u'Mn': 16.0}     {u'Mn': 10.0}      {u'Mn': 4.0}
# Mn_beta_41775          {u'Mn': 6.0}     {u'Mn': 12.0}                {}
# P_black_23836           {u'P': 3.0}                {}                {}
# Se_trigonal_23068      {u'Se': 2.0}                {}                {}
# Sm_76031              {u'Sm': 12.0}     {u'Sm': 12.0}                {}
# Sn_beta_106072         {u'Sn': 6.0}                {}                {}
# U_alpha_16056           {u'U': 4.0}                {}                {}
# W_alpha_43667           {u'W': 8.0}                {}                {}
#
#                   MinimumOKeeffeNN3 MinimumVIRENN0 MinimumVIRENN1  \
# As_alpha_16518                   {}   {u'As': 3.0}             {}
# C_diamond_52054                  {}    {u'C': 4.0}             {}
# C_graphite_76767                 {}    {u'C': 3.0}    {u'C': 3.0}
# Cu_52256                         {}  {u'Cu': 12.0}             {}
# Ga_12174                         {}  {u'Ga': 12.0}             {}
# Hg_alpha_104296                  {}   {u'Hg': 6.0}             {}
# La_43573                         {}  {u'La': 12.0}  {u'La': 12.0}
# Mg_52260                         {}  {u'Mg': 12.0}             {}
# Mn_alpha_42743         {u'Mn': 4.0}  {u'Mn': 16.0}  {u'Mn': 10.0}
# Mn_beta_41775                    {}   {u'Mn': 6.0}  {u'Mn': 12.0}
# P_black_23836                    {}    {u'P': 3.0}             {}
# Se_trigonal_23068                {}   {u'Se': 2.0}             {}
# Sm_76031                         {}  {u'Sm': 12.0}  {u'Sm': 12.0}
# Sn_beta_106072                   {}   {u'Sn': 6.0}             {}
# U_alpha_16056                    {}    {u'U': 4.0}             {}
# W_alpha_43667                    {}    {u'W': 8.0}             {}
#
#                   MinimumVIRENN2 MinimumVIRENN3     VoronoiNN0     VoronoiNN1  \
# As_alpha_16518                {}             {}   {u'As': 6.0}             {}
# C_diamond_52054               {}             {}    {u'C': 4.0}             {}
# C_graphite_76767              {}             {}    {u'C': 3.0}    {u'C': 3.0}
# Cu_52256                      {}             {}  {u'Cu': 12.0}             {}
# Ga_12174                      {}             {}  {u'Ga': 12.0}             {}
# Hg_alpha_104296               {}             {}  {u'Hg': 12.0}             {}
# La_43573                      {}             {}  {u'La': 12.0}  {u'La': 12.0}
# Mg_52260                      {}             {}  {u'Mg': 12.0}             {}
# Mn_alpha_42743      {u'Mn': 4.0}   {u'Mn': 4.0}  {u'Mn': 16.0}  {u'Mn': 10.0}
# Mn_beta_41775                 {}             {}  {u'Mn': 12.0}  {u'Mn': 12.0}
# P_black_23836                 {}             {}    {u'P': 3.0}             {}
# Se_trigonal_23068             {}             {}   {u'Se': 6.0}             {}
# Sm_76031                      {}             {}  {u'Sm': 12.0}  {u'Sm': 12.0}
# Sn_beta_106072                {}             {}   {u'Sn': 6.0}             {}
# U_alpha_16056                 {}             {}    {u'U': 4.0}             {}
# W_alpha_43667                 {}             {}    {u'W': 8.0}             {}
#
#                       VoronoiNN2    VoronoiNN3
# As_alpha_16518                {}            {}
# C_diamond_52054               {}            {}
# C_graphite_76767              {}            {}
# Cu_52256                      {}            {}
# Ga_12174                      {}            {}
# Hg_alpha_104296               {}            {}
# La_43573                      {}            {}
# Mg_52260                      {}            {}
# Mn_alpha_42743     {u'Mn': 12.0}  {u'Mn': 6.0}
# Mn_beta_41775                 {}            {}
# P_black_23836                 {}            {}
# Se_trigonal_23068             {}            {}
# Sm_76031                      {}            {}
# Sn_beta_106072                {}            {}
# U_alpha_16056                 {}            {}
# W_alpha_43667                 {}            {}

# %%
df = preset.score(methods)
df
# Out:
#                    BrunnerNN_reciprocal  CrystalNN  EconNN  JmolNN  \
# As_alpha_16518                      0.0        0.0   9.000     0.0
# C_diamond_52054                     0.0        0.0   0.000     0.0
# C_graphite_76767                    0.0        0.0   0.000     0.0
# Cu_52256                            0.0        0.0   6.000     0.0
# Ga_12174                            0.0        0.0   4.000     0.0
# Hg_alpha_104296                     6.0        0.0   6.000     6.0
# La_43573                            0.0        0.0   6.000     0.0
# Mg_52260                            0.0        0.0   6.000    12.0
# Mn_alpha_42743                      0.0        0.0   0.828     0.0
# Mn_beta_41775                       0.0        0.0   1.200     0.0
# P_black_23836                       0.0        0.0   0.000     3.0
# Se_trigonal_23068                   0.0        0.0   4.000     0.0
# Sm_76031                            0.0        0.0   6.000     0.0
# Sn_beta_106072                      0.0        0.0  12.000     0.0
# U_alpha_16056                       4.0        0.0   4.000     0.0
# W_alpha_43667                       6.0        0.0   6.000     6.0
# Total                              16.0        0.0  71.028    27.0
#
#                    MinimumDistanceNN  MinimumOKeeffeNN  MinimumVIRENN  \
# As_alpha_16518                 0.000             0.000          0.000
# C_diamond_52054                0.000             0.000          0.000
# C_graphite_76767               0.000             0.000          0.000
# Cu_52256                       0.000             0.000          0.000
# Ga_12174                       0.000             0.000          0.000
# Hg_alpha_104296                0.000             0.000          0.000
# La_43573                       0.000             0.000          0.000
# Mg_52260                       0.000             0.000          0.000
# Mn_alpha_42743                 7.862             7.862          7.862
# Mn_beta_41775                  2.400             2.400          2.400
# P_black_23836                  0.000             0.000          0.000
# Se_trigonal_23068              0.000             0.000          0.000
# Sm_76031                       0.000             0.000          0.000
# Sn_beta_106072                 0.000             0.000          0.000
# U_alpha_16056                  0.000             0.000          0.000
# W_alpha_43667                  0.000             0.000          0.000
# Total                         10.262            10.262         10.262
#
#                    VoronoiNN
# As_alpha_16518         3.000
# C_diamond_52054        0.000
# C_graphite_76767       0.000
# Cu_52256               0.000
# Ga_12174               0.000
# Hg_alpha_104296        6.000
# La_43573               0.000
# Mg_52260               0.000
# Mn_alpha_42743         3.724
# Mn_beta_41775          0.000
# P_black_23836          0.000
# Se_trigonal_23068      4.000
# Sm_76031               0.000
# Sn_beta_106072         0.000
# U_alpha_16056          0.000
# W_alpha_43667          0.000
# Total                 16.724

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 10))

sns.set(font='Times New Roman')
sns.set(font_scale=1.5)

hm = sns.heatmap(df, annot=True, cmap="BuPu", vmax=10)

ax.set_xticklabels(df.columns.tolist(), rotation=60)
ax.set_yticklabels(df.index.tolist())

plt.savefig('cation_anion.png')
plt.show()

# %%
methods = [CrystalNN(distance_cutoffs=None, x_diff_weight=None), HumanInterpreter()]
structure_groups = ["elemental"]

preset = Benchmark.from_preset(preset_name=structure_groups)
preset.benchmark(methods=methods)

df = preset.score(methods)

fig, ax = plt.subplots(figsize=(20, 10))

sns.set(font='Times New Roman')
sns.set(font_scale=1.5)

hm = sns.heatmap(df, annot=True, cmap="BuPu", vmax=10)

ax.set_xticklabels(df.columns.tolist(), rotation=60)
ax.set_yticklabels(df.index.tolist())

plt.savefig('cation_anion.png')
plt.show()

# %%
methods = [BrunnerNN_reciprocal(), EconNN(), JmolNN(), CrystalNN(), VoronoiNN(tol=0.5),
           MinimumDistanceNN(), MinimumOKeeffeNN(), MinimumVIRENN(),
           HumanInterpreter()]
structure_groups = ["elemental"]

algos = ["BrunnerNN_reciprocal", "EconNN", "JmolNN", "CrystalNN", "VoronoiNN",
         "MinimumDistanceNN", "MinimumOKeeffeNN", "MinimumVIRENN"]

preset = Benchmark.from_preset(preset_name=structure_groups, perturb=True, perturb_sigma=0.01)
preset.benchmark(methods=methods)
df = preset.score(methods)

d={}    
for a in algos:
    total = df.iloc[-1][a]
    if a not in d:
        d[a] = [(sigma, total)]
    else:
        d[a].append((sigma, total))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8f78686ca634> in <module>()
#      15     total = df.iloc[-1][a]
#      16     if a not in d:
# ---> 17         d[a] = [(sigma, total)]
#      18     else:
#      19         d[a].append((sigma, total))
#
# NameError: name 'sigma' is not defined

# %%
df
# Out:
#                    BrunnerNN_reciprocal  CrystalNN  EconNN  JmolNN  \
# As_alpha_16518                      3.0        3.0    12.0     3.0
# C_diamond_52054                     4.0        4.0     4.0     4.0
# C_graphite_76767                    3.0        3.0     3.0     3.0
# Cu_52256                           12.0       12.0    18.0    12.0
# Ga_12174                           12.0       12.0    16.0    11.0
# Hg_alpha_104296                    12.0        6.0    12.0    12.0
# La_43573                           12.0       12.0    18.0    12.0
# Mg_52260                           12.0       12.0    18.0     NaN
# Mn_alpha_42743                     16.0       16.0    16.0    16.0
# Mn_beta_41775                      12.0       12.0    12.0    12.0
# P_black_23836                       3.0        3.0     3.0     NaN
# Se_trigonal_23068                   2.0        2.0     6.0     2.0
# Sm_76031                           12.0       12.0    18.0    12.0
# Sn_beta_106072                      6.0        6.0    18.0     6.0
# U_alpha_16056                      16.0       12.0    16.0    12.0
# W_alpha_43667                      14.0        8.0    14.0    14.0
# Total                             151.0      135.0   204.0   131.0
#
#                    MinimumDistanceNN  MinimumOKeeffeNN  MinimumVIRENN  \
# As_alpha_16518                 3.000             3.000          3.000
# C_diamond_52054                4.000             4.000          4.000
# C_graphite_76767               3.000             3.000          3.000
# Cu_52256                      12.000            12.000         12.000
# Ga_12174                      12.000            12.000         12.000
# Hg_alpha_104296                6.000             6.000          6.000
# La_43573                      12.000            12.000         12.000
# Mg_52260                      12.000            12.000         12.000
# Mn_alpha_42743                10.621            10.621         10.621
# Mn_beta_41775                  5.400             5.400          5.400
# P_black_23836                  3.000             3.000          3.000
# Se_trigonal_23068              2.000             2.000          2.000
# Sm_76031                      12.000            12.000         12.000
# Sn_beta_106072                 6.000             6.000          6.000
# U_alpha_16056                  4.000             4.000          4.000
# W_alpha_43667                  8.000             8.000          8.000
# Total                        115.021           115.021        115.021
#
#                    VoronoiNN
# As_alpha_16518         6.000
# C_diamond_52054        4.000
# C_graphite_76767       3.000
# Cu_52256              12.000
# Ga_12174              12.000
# Hg_alpha_104296       12.000
# La_43573              12.000
# Mg_52260              12.000
# Mn_alpha_42743        11.448
# Mn_beta_41775         12.000
# P_black_23836          3.000
# Se_trigonal_23068      6.000
# Sm_76031              12.000
# Sn_beta_106072         6.000
# U_alpha_16056          4.000
# W_alpha_43667          8.000
# Total                135.448

# %%
methods = [BrunnerNN_reciprocal(), EconNN(), JmolNN(), CrystalNN(), VoronoiNN(tol=0.5),
           MinimumDistanceNN(), MinimumOKeeffeNN(), MinimumVIRENN(),
           HumanInterpreter()]
structure_groups = ["elemental"]

algos = ["BrunnerNN_reciprocal", "EconNN", "JmolNN", "CrystalNN", "VoronoiNN",
         "MinimumDistanceNN", "MinimumOKeeffeNN", "MinimumVIRENN"]

preset = Benchmark.from_preset(preset_name=structure_groups, perturb=True, perturb_sigma=0.02)
preset.benchmark(methods=methods)
df = preset.score(methods)

# %%
df
# Out:
#                    BrunnerNN_reciprocal  CrystalNN  EconNN  JmolNN  \
# As_alpha_16518                      3.0        3.0     6.0     3.0
# C_diamond_52054                     4.0        4.0     4.0     4.0
# C_graphite_76767                    3.0        3.0     3.0     3.0
# Cu_52256                           12.0       12.0    18.0    12.0
# Ga_12174                           12.0       12.0    16.0     8.0
# Hg_alpha_104296                    12.0        6.0    12.0    12.0
# La_43573                           12.0       12.0    18.0    12.0
# Mg_52260                           12.0       12.0    18.0     NaN
# Mn_alpha_42743                     16.0       16.0    16.0    16.0
# Mn_beta_41775                      12.0       12.0    12.0    12.0
# P_black_23836                       3.0        3.0     3.0     NaN
# Se_trigonal_23068                   2.0        2.0     6.0     2.0
# Sm_76031                           12.0       12.0    18.0    12.0
# Sn_beta_106072                      6.0        6.0    18.0     6.0
# U_alpha_16056                      16.0       12.0    16.0    12.0
# W_alpha_43667                      14.0        8.0    14.0    14.0
# Total                             151.0      135.0   198.0   128.0
#
#                    MinimumDistanceNN  MinimumOKeeffeNN  MinimumVIRENN  \
# As_alpha_16518                 3.000             3.000          3.000
# C_diamond_52054                4.000             4.000          4.000
# C_graphite_76767               3.000             3.000          3.000
# Cu_52256                      12.000            12.000         12.000
# Ga_12174                      12.000            12.000         12.000
# Hg_alpha_104296                6.000             6.000          6.000
# La_43573                      12.000            12.000         12.000
# Mg_52260                      12.000            12.000         12.000
# Mn_alpha_42743                10.207            10.207         10.207
# Mn_beta_41775                  5.200             5.200          5.200
# P_black_23836                  3.000             3.000          3.000
# Se_trigonal_23068              2.000             2.000          2.000
# Sm_76031                      12.000            12.000         12.000
# Sn_beta_106072                 6.000             6.000          6.000
# U_alpha_16056                  4.000             4.000          4.000
# W_alpha_43667                  8.000             8.000          8.000
# Total                        114.407           114.407        114.407
#
#                    VoronoiNN
# As_alpha_16518         6.000
# C_diamond_52054        4.000
# C_graphite_76767       3.000
# Cu_52256              12.000
# Ga_12174              12.000
# Hg_alpha_104296        6.000
# La_43573              12.000
# Mg_52260              12.000
# Mn_alpha_42743        11.862
# Mn_beta_41775         12.000
# P_black_23836          3.000
# Se_trigonal_23068      6.000
# Sm_76031              12.000
# Sn_beta_106072         6.000
# U_alpha_16056          4.000
# W_alpha_43667          8.000
# Total                129.862
