# %%
# This notebook covers examples of how the MaterialsCoord infrastructure can be used to 
# test CN algorithms.

# %matplotlib inline
from materialscoord.cn_methods import TestVoronoiCoordFinder, TestECoN, \
                                    TestVoronoiCoordFinder_mod, TestBrunnerReciprocal
from materialscoord.core import Benchmark
import pandas as pd
pd.set_option('max_colwidth',100)

# Method specific parameters can be defined like this:
tvcf_params = {"cutoff": 10.0}
tecon_parmas = {"radius": 10.0}

# Prepare a list of CN methods we want to compare:
# Note we are passing the paras we defined above to respective CN methods.
methods = [TestVoronoiCoordFinder(params=tvcf_params), 
           TestECoN(params=tecon_parmas),
           TestVoronoiCoordFinder_mod(),
           TestBrunnerReciprocal()]

# Initialization of the Benchmark infrastructure
bm = Benchmark(methods, structure_groups=["common_binaries"], nround=1)

# Perform benchmark calculations with methods specified
bm.benchmark()
# Out:
# Initialization successful.

# %%
# Default report output. Returns a pandas dframe where for each structure, the output of the CN algorithms tested is
# given for each unique site.
# For example: [(Al, {u'Al': 0.0, u'O': 5.8}), (O, {u'Al': 3.9, u'O': 0.0})]
#              Here the first site is has an Al atom, which is coordinated by 0.0 Al atoms, and 5.8 O atoms.

bm.report()
# Out:
#                                                                                                   TestBrunnerReciprocal  \
# Al2O3_corundum                                                                   [(Al, {u'O': 6.0}), (O, {u'Al': 4.0})]
# CaF2_fluorite                                                         [(Ca, {u'F': 8.0}), (F, {u'Ca': 4.0, u'F': 6.0})]
# CsCl                                                   [(Cs, {u'Cs': 6.0, u'Cl': 8.0}), (Cl, {u'Cs': 8.0, u'Cl': 6.0})]
# Cu5Zn8_gamma_brass  [(Zn, {u'Zn': 6.0, u'Cu': 6.0}), (Zn, {u'Zn': 5.0, u'Cu': 6.0}), (Cu, {u'Zn': 9.0, u'Cu': 3.0}),...
# Fe3O4_spinel                                                  [(Fe, {u'O': 6.0}), (Fe, {u'O': 4.0}), (O, {u'Fe': 4.0})]
# MgAl2O4_spinel                                    [(Mg, {u'O': 4.0}), (Al, {u'O': 6.0}), (O, {u'Mg': 1.0, u'Al': 3.0})]
# NaCl_rocksalt                                                                  [(Na, {u'Cl': 6.0}), (Cl, {u'Na': 6.0})]
# TiO2_anatase                                                                     [(Ti, {u'O': 6.0}), (O, {u'Ti': 3.0})]
# ZnS_wurtzite                                                                     [(Zn, {u'S': 4.0}), (S, {u'Zn': 4.0})]
# ZnS_zincblende                                                                   [(Zn, {u'S': 4.0}), (S, {u'Zn': 4.0})]
#
#                                                                                                                TestECoN  \
# Al2O3_corundum                                            [(Al, {u'Al': 0.0, u'O': 5.8}), (O, {u'Al': 3.9, u'O': 0.0})]
# CaF2_fluorite                                             [(Ca, {u'Ca': 0.0, u'F': 8.0}), (F, {u'Ca': 5.0, u'F': 2.6})]
# CsCl                                                   [(Cs, {u'Cs': 2.1, u'Cl': 9.2}), (Cl, {u'Cs': 9.2, u'Cl': 2.1})]
# Cu5Zn8_gamma_brass  [(Zn, {u'Zn': 5.2, u'Cu': 6.6}), (Zn, {u'Zn': 5.2, u'Cu': 5.3}), (Cu, {u'Zn': 9.5, u'Cu': 2.4}),...
# Fe3O4_spinel               [(Fe, {u'Fe': 0.0, u'O': 6.0}), (Fe, {u'Fe': 0.0, u'O': 4.0}), (O, {u'Fe': 3.7, u'O': 0.0})]
# MgAl2O4_spinel      [(Mg, {u'Mg': 0.0, u'Al': 0.0, u'O': 4.0}), (Al, {u'Mg': 0.0, u'Al': 0.0, u'O': 6.0}), (O, {u'Mg...
# NaCl_rocksalt                                          [(Na, {u'Na': 0.0, u'Cl': 6.0}), (Cl, {u'Na': 6.0, u'Cl': 0.0})]
# TiO2_anatase                                              [(Ti, {u'O': 6.0, u'Ti': 0.0}), (O, {u'O': 0.1, u'Ti': 3.1})]
# ZnS_wurtzite                                              [(Zn, {u'Zn': 0.0, u'S': 4.0}), (S, {u'Zn': 4.0, u'S': 0.0})]
# ZnS_zincblende                                            [(Zn, {u'Zn': 0.0, u'S': 4.0}), (S, {u'Zn': 4.0, u'S': 0.0})]
#
#                                                                                                  TestVoronoiCoordFinder  \
# Al2O3_corundum                                            [(Al, {u'Al': 0.0, u'O': 5.3}), (O, {u'Al': 3.5, u'O': 1.8})]
# CaF2_fluorite                                                         [(Ca, {u'F': 8.0}), (F, {u'Ca': 4.0, u'F': 4.0})]
# CsCl                                                   [(Cs, {u'Cs': 2.2, u'Cl': 8.0}), (Cl, {u'Cs': 8.0, u'Cl': 2.2})]
# Cu5Zn8_gamma_brass  [(Zn, {u'Zn': 5.0, u'Cu': 5.5}), (Zn, {u'Zn': 5.0, u'Cu': 4.6}), (Cu, {u'Zn': 8.7, u'Cu': 2.2}),...
# Fe3O4_spinel                           [(Fe, {u'O': 6.0}), (Fe, {u'Fe': 0.2, u'O': 4.2}), (O, {u'Fe': 3.2, u'O': 1.1})]
# MgAl2O4_spinel             [(Mg, {u'Mg': 0.3, u'O': 4.3}), (Al, {u'O': 6.0}), (O, {u'Mg': 1.1, u'Al': 2.3, u'O': 1.2})]
# NaCl_rocksalt                                          [(Na, {u'Na': 0.0, u'Cl': 6.0}), (Cl, {u'Na': 6.0, u'Cl': 0.0})]
# TiO2_anatase                                                          [(Ti, {u'O': 5.8}), (O, {u'O': 2.9, u'Ti': 2.9})]
# ZnS_wurtzite                                              [(Zn, {u'Zn': 0.3, u'S': 4.0}), (S, {u'Zn': 4.0, u'S': 0.3})]
# ZnS_zincblende                                            [(Zn, {u'Zn': 0.5, u'S': 4.0}), (S, {u'Zn': 4.0, u'S': 0.5})]
#
#                                                                                              TestVoronoiCoordFinder_mod
# Al2O3_corundum                                                                   [(Al, {u'O': 6.0}), (O, {u'Al': 4.0})]
# CaF2_fluorite                                                         [(Ca, {u'F': 8.0}), (F, {u'Ca': 4.0, u'F': 6.0})]
# CsCl                                                                           [(Cs, {u'Cl': 8.0}), (Cl, {u'Cs': 8.0})]
# Cu5Zn8_gamma_brass  [(Zn, {u'Zn': 6.0, u'Cu': 6.0}), (Zn, {u'Zn': 5.0, u'Cu': 6.0}), (Cu, {u'Zn': 9.0, u'Cu': 3.0}),...
# Fe3O4_spinel                                                  [(Fe, {u'O': 6.0}), (Fe, {u'O': 4.0}), (O, {u'Fe': 4.0})]
# MgAl2O4_spinel                                    [(Mg, {u'O': 4.0}), (Al, {u'O': 6.0}), (O, {u'Mg': 1.0, u'Al': 3.0})]
# NaCl_rocksalt                                                                  [(Na, {u'Cl': 6.0}), (Cl, {u'Na': 6.0})]
# TiO2_anatase                                                                     [(Ti, {u'O': 6.0}), (O, {u'Ti': 3.0})]
# ZnS_wurtzite                                                                     [(Zn, {u'S': 4.0}), (S, {u'Zn': 4.0})]
# ZnS_zincblende                                                                   [(Zn, {u'S': 4.0}), (S, {u'Zn': 4.0})]

# %%
# We can instead ask to get only the total number of coordinating atoms around each unique site.
# For example: [(Al, 5.8), (O, 3.9)]
#               Here the first site is Al, and it has in total 5.8 coordinating atoms around.
bm.report(totals=True)
# Out:
#                                                TestBrunnerReciprocal  \
# Al2O3_corundum                                 [(Al, 6.0), (O, 4.0)]
# CaF2_fluorite                                 [(Ca, 8.0), (F, 10.0)]
# CsCl                                        [(Cs, 14.0), (Cl, 14.0)]
# Cu5Zn8_gamma_brass  [(Zn, 12.0), (Zn, 11.0), (Cu, 12.0), (Cu, 13.0)]
# Fe3O4_spinel                        [(Fe, 6.0), (Fe, 4.0), (O, 4.0)]
# MgAl2O4_spinel                      [(Mg, 4.0), (Al, 6.0), (O, 4.0)]
# NaCl_rocksalt                                 [(Na, 6.0), (Cl, 6.0)]
# TiO2_anatase                                   [(Ti, 6.0), (O, 3.0)]
# ZnS_wurtzite                                   [(Zn, 4.0), (S, 4.0)]
# ZnS_zincblende                                 [(Zn, 4.0), (S, 4.0)]
#
#                                                             TestECoN  \
# Al2O3_corundum                                 [(Al, 5.8), (O, 3.9)]
# CaF2_fluorite                                  [(Ca, 8.0), (F, 7.6)]
# CsCl                                        [(Cs, 11.3), (Cl, 11.3)]
# Cu5Zn8_gamma_brass  [(Zn, 11.8), (Zn, 10.5), (Cu, 11.9), (Cu, 11.7)]
# Fe3O4_spinel                        [(Fe, 6.0), (Fe, 4.0), (O, 3.7)]
# MgAl2O4_spinel                      [(Mg, 4.0), (Al, 6.0), (O, 4.1)]
# NaCl_rocksalt                                 [(Na, 6.0), (Cl, 6.0)]
# TiO2_anatase                                   [(Ti, 6.0), (O, 3.2)]
# ZnS_wurtzite                                   [(Zn, 4.0), (S, 4.0)]
# ZnS_zincblende                                 [(Zn, 4.0), (S, 4.0)]
#
#                                             TestVoronoiCoordFinder  \
# Al2O3_corundum                               [(Al, 5.3), (O, 5.3)]
# CaF2_fluorite                                [(Ca, 8.0), (F, 8.0)]
# CsCl                                      [(Cs, 10.2), (Cl, 10.2)]
# Cu5Zn8_gamma_brass  [(Zn, 10.5), (Zn, 9.6), (Cu, 10.9), (Cu, 9.6)]
# Fe3O4_spinel                      [(Fe, 6.0), (Fe, 4.4), (O, 4.3)]
# MgAl2O4_spinel                    [(Mg, 4.6), (Al, 6.0), (O, 4.6)]
# NaCl_rocksalt                               [(Na, 6.0), (Cl, 6.0)]
# TiO2_anatase                                 [(Ti, 5.8), (O, 5.8)]
# ZnS_wurtzite                                 [(Zn, 4.3), (S, 4.3)]
# ZnS_zincblende                               [(Zn, 4.5), (S, 4.5)]
#
#                                           TestVoronoiCoordFinder_mod
# Al2O3_corundum                                 [(Al, 6.0), (O, 4.0)]
# CaF2_fluorite                                 [(Ca, 8.0), (F, 10.0)]
# CsCl                                          [(Cs, 8.0), (Cl, 8.0)]
# Cu5Zn8_gamma_brass  [(Zn, 12.0), (Zn, 11.0), (Cu, 12.0), (Cu, 13.0)]
# Fe3O4_spinel                        [(Fe, 6.0), (Fe, 4.0), (O, 4.0)]
# MgAl2O4_spinel                      [(Mg, 4.0), (Al, 6.0), (O, 4.0)]
# NaCl_rocksalt                                 [(Na, 6.0), (Cl, 6.0)]
# TiO2_anatase                                   [(Ti, 6.0), (O, 3.0)]
# ZnS_wurtzite                                   [(Zn, 4.0), (S, 4.0)]
# ZnS_zincblende                                 [(Zn, 4.0), (S, 4.0)]

# %%
# The separate_columns option can be with totals=True if you want a dframe that rather prints the total CN of each
# site in a separate column, up to max_sites unique sites in the structure. Therefore the output will have
# max_sites columns for each CN method. Each column will be labeled as NameOfCNMethod-SiteIndex.
p = bm.report(totals=True, separate_columns=True, max_sites=4)
p
# Out:
#                     TestBrunnerReciprocal0  TestBrunnerReciprocal1  \
# Al2O3_corundum                         6.0                     4.0
# CaF2_fluorite                          8.0                    10.0
# CsCl                                  14.0                    14.0
# Cu5Zn8_gamma_brass                    12.0                    11.0
# Fe3O4_spinel                           6.0                     4.0
# MgAl2O4_spinel                         4.0                     6.0
# NaCl_rocksalt                          6.0                     6.0
# TiO2_anatase                           6.0                     3.0
# ZnS_wurtzite                           4.0                     4.0
# ZnS_zincblende                         4.0                     4.0
#
#                     TestBrunnerReciprocal2  TestBrunnerReciprocal3  TestECoN0  \
# Al2O3_corundum                         0.0                     0.0        5.8
# CaF2_fluorite                          0.0                     0.0        8.0
# CsCl                                   0.0                     0.0       11.3
# Cu5Zn8_gamma_brass                    12.0                    13.0       11.8
# Fe3O4_spinel                           4.0                     0.0        6.0
# MgAl2O4_spinel                         4.0                     0.0        4.0
# NaCl_rocksalt                          0.0                     0.0        6.0
# TiO2_anatase                           0.0                     0.0        6.0
# ZnS_wurtzite                           0.0                     0.0        4.0
# ZnS_zincblende                         0.0                     0.0        4.0
#
#                     TestECoN1  TestECoN2  TestECoN3  TestVoronoiCoordFinder0  \
# Al2O3_corundum            3.9        0.0        0.0                      5.3
# CaF2_fluorite             7.6        0.0        0.0                      8.0
# CsCl                     11.3        0.0        0.0                     10.2
# Cu5Zn8_gamma_brass       10.5       11.9       11.7                     10.5
# Fe3O4_spinel              4.0        3.7        0.0                      6.0
# MgAl2O4_spinel            6.0        4.1        0.0                      4.6
# NaCl_rocksalt             6.0        0.0        0.0                      6.0
# TiO2_anatase              3.2        0.0        0.0                      5.8
# ZnS_wurtzite              4.0        0.0        0.0                      4.3
# ZnS_zincblende            4.0        0.0        0.0                      4.5
#
#                     TestVoronoiCoordFinder1  TestVoronoiCoordFinder2  \
# Al2O3_corundum                          5.3                      0.0
# CaF2_fluorite                           8.0                      0.0
# CsCl                                   10.2                      0.0
# Cu5Zn8_gamma_brass                      9.6                     10.9
# Fe3O4_spinel                            4.4                      4.3
# MgAl2O4_spinel                          6.0                      4.6
# NaCl_rocksalt                           6.0                      0.0
# TiO2_anatase                            5.8                      0.0
# ZnS_wurtzite                            4.3                      0.0
# ZnS_zincblende                          4.5                      0.0
#
#                     TestVoronoiCoordFinder3  TestVoronoiCoordFinder_mod0  \
# Al2O3_corundum                          0.0                          6.0
# CaF2_fluorite                           0.0                          8.0
# CsCl                                    0.0                          8.0
# Cu5Zn8_gamma_brass                      9.6                         12.0
# Fe3O4_spinel                            0.0                          6.0
# MgAl2O4_spinel                          0.0                          4.0
# NaCl_rocksalt                           0.0                          6.0
# TiO2_anatase                            0.0                          6.0
# ZnS_wurtzite                            0.0                          4.0
# ZnS_zincblende                          0.0                          4.0
#
#                     TestVoronoiCoordFinder_mod1  TestVoronoiCoordFinder_mod2  \
# Al2O3_corundum                              4.0                          0.0
# CaF2_fluorite                              10.0                          0.0
# CsCl                                        8.0                          0.0
# Cu5Zn8_gamma_brass                         11.0                         12.0
# Fe3O4_spinel                                4.0                          4.0
# MgAl2O4_spinel                              6.0                          4.0
# NaCl_rocksalt                               6.0                          0.0
# TiO2_anatase                                3.0                          0.0
# ZnS_wurtzite                                4.0                          0.0
# ZnS_zincblende                              4.0                          0.0
#
#                     TestVoronoiCoordFinder_mod3
# Al2O3_corundum                              0.0
# CaF2_fluorite                               0.0
# CsCl                                        0.0
# Cu5Zn8_gamma_brass                         13.0
# Fe3O4_spinel                                0.0
# MgAl2O4_spinel                              0.0
# NaCl_rocksalt                               0.0
# TiO2_anatase                                0.0
# ZnS_wurtzite                                0.0
# ZnS_zincblende                              0.0

# %%
# Here is an example for plotting deviation of CNs for unique sites in our test structures 
# from the mean CN of that site among all methods.

ax = None
for i in range(4):
    a = p[ ["TestECoN"+str(i), "TestVoronoiCoordFinder"+str(i), 
            "TestVoronoiCoordFinder_mod"+str(i), "TestBrunnerReciprocal"+str(i)] ]
    if ax:
        a.sub(a.mean(axis=1), axis='rows').T.plot(legend=False, ax=ax)
    else:
        ax=a.sub(a.mean(axis=1), axis='rows').T.plot(legend=False)
ax.set_xlabel("CN method")
ax.set_ylabel("Deviation from mean CN")
labels = [item.get_text()[:-1] for item in ax.get_xticklabels()]
ax.set_xticklabels(labels, rotation=15)
# Out:
# [<matplotlib.text.Text at 0x11596de90>,
#  <matplotlib.text.Text at 0x11594ca10>,
#  <matplotlib.text.Text at 0x115a711d0>,
#  <matplotlib.text.Text at 0x115a71910>,
#  <matplotlib.text.Text at 0x115a7a090>,
#  <matplotlib.text.Text at 0x115a7a7d0>,
#  <matplotlib.text.Text at 0x115a7af10>]
